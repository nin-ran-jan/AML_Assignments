# %%
# !gdown https://drive.google.com/file/d/1Hv4RAltBumSfOkRacoX8qrfDYfd_NDss/view?usp=drive_link --fuzzy

# %%
# !unzip Dataset_AML_Assignment1_Part1.zip

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np
import torch
from torch import nn
from torch import optim
from torch.utils.data import Dataset, DataLoader, random_split, ConcatDataset
import torch.nn.functional as F
from IPython import display 
from tqdm.notebook import tqdm
import random
import math, time, os
from matplotlib import pyplot as plt
import pickle as pkl


device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')
print(device)
prefix = './data_dump_lstm_rerun'
# Out:
# cuda:1

# %%
class SinusodialDatasetSequential(Dataset):
    def __init__(self, df, mode='era', window_size=10):
        """ creating label columns of eras and targets """

        # df.sort_values(by=['day', 'row_num'], inplace=True)
        # self.eras = df['era_label']
        self.X = df.iloc[:, :26]
        self.y = df[f'{mode}']
        self.window_size = window_size

    def __len__(self):
        return self.X.shape[0]-self.window_size+1

    def __getitem__(self, idx):
        """ you are working on the sample idx+self.window_size = actual idx"""
        # if self.eras.iloc[idx] != self.eras.iloc[idx+self.window_size-1]:
        #     for i in range(idx, idx+self.window_size):
        #         if self.eras.iloc[idx] != self.eras.iloc[i]:
        #             break
        #     X = torch.tensor(self.X.iloc[idx:i].values, dtype=torch.float32)
        #     y = torch.tensor(int(self.y.iloc[i-1]), dtype=torch.long)
        #     return X, y
          
        X = torch.tensor(self.X.iloc[idx:idx+self.window_size].values, dtype=torch.float32)
        y = torch.tensor(int(self.y.iloc[idx+self.window_size-1]), dtype=torch.long)
        return X, y

# %%
def make_data_splits_sequential(df, mode, batch_size=32, train_perc=0.7, val_test_perc=0.5):

    def encode(v, class_values):
        return class_values.index(v)

    #adding new era_label column indexed 0, 1,...
    class_values = df[f'{mode}'].unique().tolist()
    df[f'{mode}'] = df[f'{mode}'].apply(lambda x: encode(x, class_values))
    df.reset_index(drop=True, inplace=True)

    train_dataset_list = []
    val_dataset_list = []
    test_dataset_list = []

    for era in df['era'].unique():
        condition = df['era'] == era
        df_era = df[condition]

        data = SinusodialDatasetSequential(df_era, mode=mode)
        
        train_samples = int(len(data)*train_perc)
        val_test_samples = len(data)-train_samples

        data_train, data_test = random_split(data, [train_samples, val_test_samples])

        val_samples = int(len(data_test)*val_test_perc)
        test_samples = len(data_test)-val_samples
        data_val, data_test = random_split(data_test, [val_samples, test_samples])

        train_dataset_list.append(data_train)
        val_dataset_list.append(data_val)
        test_dataset_list.append(data_test)
    
    dataset_train = ConcatDataset(train_dataset_list)
    dataset_val = ConcatDataset(val_dataset_list)
    dataset_test = ConcatDataset(test_dataset_list)

    print("Train-val-test lengths: ", len(dataset_train), len(dataset_val), len(dataset_test))

    loader_train = DataLoader(dataset_train, batch_size=batch_size, shuffle=True)
    loader_val = DataLoader(dataset_val, batch_size=batch_size, shuffle=False)
    loader_test = DataLoader(dataset_test, batch_size=batch_size, shuffle=False)

    return loader_train, loader_val, loader_test

# %% [markdown]
# #LSTM

# %%
import torch.nn.init as init

class LSTMClassifier(nn.Module):
    def __init__(self, input_dim, output_size, hidden_size = 64, num_layers = 4, lr=5e-4, weight_decay=1e-3):
        super(LSTMClassifier, self).__init__()
        self.lstm = nn.LSTM(input_dim, hidden_size, num_layers, batch_first=True)
        self.classifier = nn.Linear(hidden_size, output_size)
        self.log_softmax = nn.LogSoftmax(dim=1)
        self.optimizer = optim.Adam(self.parameters(), lr=lr, weight_decay=weight_decay)

        torch.nn.utils.clip_grad_norm_(self.parameters(), max_norm=1.0)
        for name, param in self.lstm.named_parameters():
            if 'weight' in name:
                init.xavier_normal_(param.data)
            if 'bias' in name:
                init.constant_(param.data, 0.0)

    def forward(self, x):
        x, _ = self.lstm(x)
        return self.log_softmax(self.classifier(x[:, -1, :]))

# %%
def accuracy(y_pred, y_test, verbose=True):
    m = y_test.shape[0]
    predicted = torch.max(y_pred, 1)[1]
    correct = (predicted == y_test).float().sum().item()
    if verbose:
        print(correct,m)
    accuracy = correct/m
    return accuracy, correct

# %%
def Test(net, loader_test, mode, noise_level, device='cpu', Loss=nn.NLLLoss(reduction='sum')):
    net.eval()
    total_samples = 0
    correct_samples = 0
    loss = 0.0
    for (X, y) in loader_test:
        X=X.to(device)
        y=y.to(device)
        total_samples += y.shape[0]
        y_out = net(X)
        _, i_cor_sam = accuracy(y_out,y,verbose=False)
        correct_samples += i_cor_sam
        loss += Loss(y_out, y).cpu().detach().item()
    acc = correct_samples / total_samples
    loss /= total_samples
    net.train()
    return loss, acc

# %%
def Train(Net, data, mode, noise_level, epochs=20, lr=5e-2, Loss=nn.NLLLoss(reduction='sum'), verbose=False, device='cpu',
          val_ds=None, plot_accs=False, plot_losses=False):
    model_save_time = time.time()
    losses = []
    accs = []
    val_losses=[]
    val_accL=[]
    Net.to(device)
    for e in range(epochs):
        Net.train()
        step=0
        tot_loss = 0.0
        start_time = time.time()
        correct_samples = 0
        total_samples = 0
        for (X,y) in data:
            X=X.to(device)
            y=y.to(device)
            total_samples += y.shape[0]
            y_out = Net(X)
            loss = Loss(y_out, y)
            Net.optimizer.zero_grad()
            loss.backward()
            Net.optimizer.step()
            step+=1
            tot_loss+=loss
            if verbose:
                _, i_cor_sam = accuracy(y_out,y,verbose=False)
                correct_samples += i_cor_sam
        end_time = time.time()
        t = end_time-start_time
        l = tot_loss.item()/total_samples
        losses += [l]
        if verbose:
            a = correct_samples/total_samples
            accs += [a]
            print('Epoch %2d Loss: %2.5e Accuracy: %2.5f Epoch Time: %2.5f' %(e,l,a,t))

        val_loss, val_acc = Test(Net, val_ds, mode, noise_level, device)
        val_losses.append(val_loss)
        val_accL.append(val_acc)

        torch.save(Net.state_dict(), f'{prefix}/net_{noise_level}_{mode}_{str(model_save_time)}.pth')

    return Net, losses, accs, val_losses, val_accL

# %%
def plot_loss_acc(losses, accs, val_losses, val_accs, mode, noise_level):

    plt.plot(np.array(accs),color='red', label='Train accuracy')
    plt.plot(np.array(val_accs),color='blue', label='Val accuracy')
    plt.legend()
    plt.savefig(f'{prefix}/acc_{mode}_{noise_level}.png')
    plt.clf()

    plt.plot(np.array(losses),color='red', label='Train loss')
    plt.plot(np.array(val_losses),color='blue', label='Val loss')
    plt.legend()
    plt.savefig(f'{prefix}/loss_{mode}_{noise_level}.png')
    plt.clf()
    return

# %%
device = "cuda:2"

# %%
df_paths = ['../Datasets/df_syn_train_0_0_.csv',
            # '../Datasets/df_synA_train_shuffled.csv',
            # '../Datasets/df_synA_test_hard_shuffled_sample.csv'
            ]

# modes = ['era', 'target_5_val', 'target_10_val']
modes = ['era', 'target_5_val', 'target_10_val']
noise_levels = ['none', 'low', 'high']
epoch_num = [30, 30, 30]
# epoch_num = [50, 10, 10]
batch_sizes = [32, 128, 128]
# lrs = [1e-4, 1e-3, 5e-3]

losses_arr = []
accs_arr = []

for i in range(1):
    df = pd.read_csv(df_paths[i])
    df.sort_values(by=['era', 'day', 'row_num'], inplace=True)    

    loss_per_mode = []
    acc_per_mode = []

    for j in range(len(modes)):
        mode = modes[j]
        noise_level = noise_levels[i]
        epochs = epoch_num[j]
        # lr = lrs[j]
        print("Noise Level:", noise_level, "Mode:", mode)
        loader_train, loader_val, loader_test = make_data_splits_sequential(df, mode=mode, \
                                                                       batch_size=batch_sizes[i])
        
        #one-vs-all

        net = LSTMClassifier(26, len(df[f'{mode}'].unique()), lr = 1e-4)
        
        mode += '_lstm'
        net, losses, accs, val_losses, val_accL = Train(net, loader_train, mode, noise_level, \
                                      epochs=epochs, verbose=True, device=device, val_ds=loader_val, \
                                      plot_accs=True, plot_losses=True)
        plot_loss_acc(losses, accs, val_losses, val_accL, mode, noise_levels[i])
        
        ###########Testing code
        test_loss, test_acc = Test(net, loader_test, mode, noise_level, device=device)
        print("Noise Level:", noise_level, "Mode:", mode, "Test Acc:", test_acc)
        loss_per_mode.append(test_loss)
        acc_per_mode.append(test_acc)

    losses_arr.append(loss_per_mode)
    accs_arr.append(acc_per_mode)
# Out:
# Noise Level: none Mode: era
# Train-val-test lengths:  5376 1152 1164
# Epoch  0 Loss: 2.48660e+00 Accuracy: 0.08333 Epoch Time: 1.59145
# Epoch  1 Loss: 2.48596e+00 Accuracy: 0.08333 Epoch Time: 1.54746
# Epoch  2 Loss: 2.48566e+00 Accuracy: 0.08333 Epoch Time: 1.50343
# Epoch  3 Loss: 2.48548e+00 Accuracy: 0.08333 Epoch Time: 1.56626
# Epoch  4 Loss: 2.48532e+00 Accuracy: 0.07812 Epoch Time: 1.54669
# Epoch  5 Loss: 2.48518e+00 Accuracy: 0.08333 Epoch Time: 1.43904
# Epoch  6 Loss: 2.48494e+00 Accuracy: 0.07943 Epoch Time: 1.60418
# Epoch  7 Loss: 2.48271e+00 Accuracy: 0.09877 Epoch Time: 1.54509
# Epoch  8 Loss: 2.39782e+00 Accuracy: 0.16778 Epoch Time: 1.49032
# Epoch  9 Loss: 2.21412e+00 Accuracy: 0.22526 Epoch Time: 1.53412
# Epoch 10 Loss: 2.10641e+00 Accuracy: 0.25502 Epoch Time: 1.46828
# Epoch 11 Loss: 2.04188e+00 Accuracy: 0.26451 Epoch Time: 1.58715
# Epoch 12 Loss: 1.98598e+00 Accuracy: 0.27679 Epoch Time: 1.55588
# Epoch 13 Loss: 1.92521e+00 Accuracy: 0.28330 Epoch Time: 1.52156
# Epoch 14 Loss: 1.87457e+00 Accuracy: 0.29594 Epoch Time: 1.56763
# Epoch 15 Loss: 1.76313e+00 Accuracy: 0.34542 Epoch Time: 1.59770
# Epoch 16 Loss: 1.75005e+00 Accuracy: 0.34338 Epoch Time: 1.55608
# Epoch 17 Loss: 1.67829e+00 Accuracy: 0.36607 Epoch Time: 1.53800
# Epoch 18 Loss: 1.67324e+00 Accuracy: 0.35938 Epoch Time: 1.43496
# Epoch 19 Loss: 1.62029e+00 Accuracy: 0.37816 Epoch Time: 1.58736
# Epoch 20 Loss: 1.59788e+00 Accuracy: 0.38170 Epoch Time: 1.57490
# Epoch 21 Loss: 1.58773e+00 Accuracy: 0.38616 Epoch Time: 1.53312
# Epoch 22 Loss: 1.57024e+00 Accuracy: 0.39342 Epoch Time: 1.44212
# Epoch 23 Loss: 1.57410e+00 Accuracy: 0.38411 Epoch Time: 1.54874
# Epoch 24 Loss: 1.57071e+00 Accuracy: 0.38225 Epoch Time: 1.48474
# Epoch 25 Loss: 1.50899e+00 Accuracy: 0.41574 Epoch Time: 1.52901
# Epoch 26 Loss: 1.48265e+00 Accuracy: 0.42336 Epoch Time: 1.54294
# Epoch 27 Loss: 1.47762e+00 Accuracy: 0.42281 Epoch Time: 1.51449
# Epoch 28 Loss: 1.48753e+00 Accuracy: 0.41555 Epoch Time: 1.52868
# Epoch 29 Loss: 1.45208e+00 Accuracy: 0.43248 Epoch Time: 1.54974
# Noise Level: none Mode: era_lstm Test Acc: 0.4261168384879725
# Noise Level: none Mode: target_5_val
# Train-val-test lengths:  5376 1152 1164
# Epoch  0 Loss: 1.54051e+00 Accuracy: 0.24200 Epoch Time: 1.42103
# Epoch  1 Loss: 1.47416e+00 Accuracy: 0.24182 Epoch Time: 1.52791
# Epoch  2 Loss: 1.47359e+00 Accuracy: 0.23828 Epoch Time: 1.55286
# Epoch  3 Loss: 1.47299e+00 Accuracy: 0.25037 Epoch Time: 1.60110
# Epoch  4 Loss: 1.47371e+00 Accuracy: 0.24833 Epoch Time: 1.52680
# Epoch  5 Loss: 1.47278e+00 Accuracy: 0.24200 Epoch Time: 1.55269
# Epoch  6 Loss: 1.47221e+00 Accuracy: 0.24070 Epoch Time: 1.52396
# Epoch  7 Loss: 1.44088e+00 Accuracy: 0.32013 Epoch Time: 1.52649
# Epoch  8 Loss: 1.38686e+00 Accuracy: 0.35472 Epoch Time: 1.61920
# Epoch  9 Loss: 1.32677e+00 Accuracy: 0.39025 Epoch Time: 1.54880
# Epoch 10 Loss: 1.30606e+00 Accuracy: 0.39193 Epoch Time: 1.51942
# Epoch 11 Loss: 1.28565e+00 Accuracy: 0.41871 Epoch Time: 1.48115
# Epoch 12 Loss: 1.25482e+00 Accuracy: 0.45164 Epoch Time: 1.57148
# Epoch 13 Loss: 1.18490e+00 Accuracy: 0.49907 Epoch Time: 1.44040
# Epoch 14 Loss: 1.13567e+00 Accuracy: 0.54055 Epoch Time: 1.60323
# Epoch 15 Loss: 1.08776e+00 Accuracy: 0.56455 Epoch Time: 1.58397
# Epoch 16 Loss: 1.01925e+00 Accuracy: 0.60863 Epoch Time: 1.50789
# Epoch 17 Loss: 9.68109e-01 Accuracy: 0.63300 Epoch Time: 1.49033
# Epoch 18 Loss: 8.98079e-01 Accuracy: 0.66220 Epoch Time: 1.57384
# Epoch 19 Loss: 8.58924e-01 Accuracy: 0.67225 Epoch Time: 1.50879
# Epoch 20 Loss: 8.34088e-01 Accuracy: 0.67969 Epoch Time: 1.50885
# Epoch 21 Loss: 8.03603e-01 Accuracy: 0.69643 Epoch Time: 1.52805
# Epoch 22 Loss: 7.65285e-01 Accuracy: 0.71168 Epoch Time: 1.46769
# Epoch 23 Loss: 7.39661e-01 Accuracy: 0.71652 Epoch Time: 1.56440
# Epoch 24 Loss: 7.13697e-01 Accuracy: 0.72452 Epoch Time: 1.52564
# Epoch 25 Loss: 6.86979e-01 Accuracy: 0.73661 Epoch Time: 1.56475
# Epoch 26 Loss: 6.71220e-01 Accuracy: 0.74591 Epoch Time: 1.46580
# Epoch 27 Loss: 7.01536e-01 Accuracy: 0.73140 Epoch Time: 1.53740
# Epoch 28 Loss: 6.54080e-01 Accuracy: 0.74944 Epoch Time: 1.52169
# Epoch 29 Loss: 6.39979e-01 Accuracy: 0.75391 Epoch Time: 1.56431
# Noise Level: none Mode: target_5_val_lstm Test Acc: 0.7353951890034365
# Noise Level: none Mode: target_10_val
# Train-val-test lengths:  5376 1152 1164
# Epoch  0 Loss: 1.51847e+00 Accuracy: 0.24070 Epoch Time: 1.46511
# Epoch  1 Loss: 1.44776e+00 Accuracy: 0.24163 Epoch Time: 1.54259
# Epoch  2 Loss: 1.44648e+00 Accuracy: 0.24628 Epoch Time: 1.48399
# Epoch  3 Loss: 1.44616e+00 Accuracy: 0.24926 Epoch Time: 1.50659
# Epoch  4 Loss: 1.44592e+00 Accuracy: 0.24795 Epoch Time: 1.33803
# Epoch  5 Loss: 1.44542e+00 Accuracy: 0.24237 Epoch Time: 1.52238
# Epoch  6 Loss: 1.44336e+00 Accuracy: 0.25632 Epoch Time: 1.47859
# Epoch  7 Loss: 1.43892e+00 Accuracy: 0.26581 Epoch Time: 1.50393
# Epoch  8 Loss: 1.43380e+00 Accuracy: 0.28460 Epoch Time: 1.56053
# Epoch  9 Loss: 1.42016e+00 Accuracy: 0.30041 Epoch Time: 1.45713
# Epoch 10 Loss: 1.40291e+00 Accuracy: 0.32645 Epoch Time: 1.57626
# Epoch 11 Loss: 1.33352e+00 Accuracy: 0.38523 Epoch Time: 1.54158
# Epoch 12 Loss: 1.28810e+00 Accuracy: 0.42541 Epoch Time: 1.55967
# Epoch 13 Loss: 1.24635e+00 Accuracy: 0.47582 Epoch Time: 1.46507
# Epoch 14 Loss: 1.19118e+00 Accuracy: 0.50167 Epoch Time: 1.66481
# Epoch 15 Loss: 1.12098e+00 Accuracy: 0.54836 Epoch Time: 1.56589
# Epoch 16 Loss: 1.05944e+00 Accuracy: 0.57385 Epoch Time: 1.52823
# Epoch 17 Loss: 1.02044e+00 Accuracy: 0.59784 Epoch Time: 1.43508
# Epoch 18 Loss: 9.64190e-01 Accuracy: 0.62835 Epoch Time: 1.62218
# Epoch 19 Loss: 9.21209e-01 Accuracy: 0.65179 Epoch Time: 1.58434
# Epoch 20 Loss: 8.92370e-01 Accuracy: 0.65904 Epoch Time: 1.54647
# Epoch 21 Loss: 8.80511e-01 Accuracy: 0.66388 Epoch Time: 1.45799
# Epoch 22 Loss: 8.29013e-01 Accuracy: 0.69048 Epoch Time: 1.66073
# Epoch 23 Loss: 8.31496e-01 Accuracy: 0.68750 Epoch Time: 1.52914
# Epoch 24 Loss: 8.08683e-01 Accuracy: 0.69159 Epoch Time: 1.57748
# Epoch 25 Loss: 7.95110e-01 Accuracy: 0.70071 Epoch Time: 1.51903
# Epoch 26 Loss: 7.68666e-01 Accuracy: 0.71243 Epoch Time: 1.47096
# Epoch 27 Loss: 7.87291e-01 Accuracy: 0.69624 Epoch Time: 1.54329
# Epoch 28 Loss: 7.50556e-01 Accuracy: 0.71652 Epoch Time: 1.58743
# Epoch 29 Loss: 7.40193e-01 Accuracy: 0.71782 Epoch Time: 1.56482
# Noise Level: none Mode: target_10_val_lstm Test Acc: 0.729381443298969

# %%
df_paths = ['../Datasets/df_syn_train_0_0_.csv',
            # '../Datasets/df_synA_train_shuffled.csv',
            # '../Datasets/df_synA_test_hard_shuffled_sample.csv'
            ]

# modes = ['era', 'target_5_val', 'target_10_val']
modes = ['era', 'target_5_val', 'target_10_val']
noise_levels = ['none', 'low', 'high']
epoch_num = [30, 30, 30]
# epoch_num = [50, 10, 10]
batch_sizes = [32, 128, 128]
# lrs = [1e-4, 1e-3, 5e-3]

losses_arr = []
accs_arr = []

for i in range(1):
    df = pd.read_csv(df_paths[i])
    df.sort_values(by=['era', 'day', 'row_num'], inplace=True)    

    loss_per_mode = []
    acc_per_mode = []

    for j in range(len(modes)):
        mode = modes[j]
        noise_level = noise_levels[i]
        epochs = epoch_num[j]
        # lr = lrs[j]
        print("Noise Level:", noise_level, "Mode:", mode)
        loader_train, loader_val, loader_test = make_data_splits_sequential(df, mode=mode, \
                                                                       batch_size=batch_sizes[i])
        
        #one-vs-all

        net = LSTMClassifier(26, len(df[f'{mode}'].unique()), lr = 1e-6)
        
        mode += '_lstm'
        net, losses, accs, val_losses, val_accL = Train(net, loader_train, mode, noise_level, \
                                      epochs=epochs, verbose=True, device=device, val_ds=loader_val, \
                                      plot_accs=True, plot_losses=True)
        plot_loss_acc(losses, accs, val_losses, val_accL, mode, noise_levels[i])
        
        ###########Testing code
        test_loss, test_acc = Test(net, loader_test, mode, noise_level, device=device)
        print("Noise Level:", noise_level, "Mode:", mode, "Test Acc:", test_acc)
        loss_per_mode.append(test_loss)
        acc_per_mode.append(test_acc)

    losses_arr.append(loss_per_mode)
    accs_arr.append(acc_per_mode)
# Out:
# Noise Level: none Mode: era
# Train-val-test lengths:  5376 1152 1164
# Epoch  0 Loss: 2.48633e+00 Accuracy: 0.08333 Epoch Time: 1.13366
# Epoch  1 Loss: 2.48627e+00 Accuracy: 0.08333 Epoch Time: 1.02789
# Epoch  2 Loss: 2.48621e+00 Accuracy: 0.08333 Epoch Time: 1.11677
# Epoch  3 Loss: 2.48615e+00 Accuracy: 0.08333 Epoch Time: 1.09451
# Epoch  4 Loss: 2.48608e+00 Accuracy: 0.08333 Epoch Time: 1.10065
# Epoch  5 Loss: 2.48604e+00 Accuracy: 0.08333 Epoch Time: 1.04029
# Epoch  6 Loss: 2.48598e+00 Accuracy: 0.08333 Epoch Time: 1.04676
# Epoch  7 Loss: 2.48591e+00 Accuracy: 0.08333 Epoch Time: 1.02317
# Epoch  8 Loss: 2.48586e+00 Accuracy: 0.08333 Epoch Time: 0.95467
# Epoch  9 Loss: 2.48580e+00 Accuracy: 0.08333 Epoch Time: 0.86529
# Epoch 10 Loss: 2.48575e+00 Accuracy: 0.08333 Epoch Time: 0.89431
# Epoch 11 Loss: 2.48570e+00 Accuracy: 0.08333 Epoch Time: 0.93223
# Epoch 12 Loss: 2.48563e+00 Accuracy: 0.08333 Epoch Time: 0.88663
# Epoch 13 Loss: 2.48558e+00 Accuracy: 0.08333 Epoch Time: 0.91788
# Epoch 14 Loss: 2.48552e+00 Accuracy: 0.08333 Epoch Time: 1.00636
# Epoch 15 Loss: 2.48547e+00 Accuracy: 0.08333 Epoch Time: 0.98712
# Epoch 16 Loss: 2.48542e+00 Accuracy: 0.08333 Epoch Time: 1.00947
# Epoch 17 Loss: 2.48536e+00 Accuracy: 0.08333 Epoch Time: 1.00936
# Epoch 18 Loss: 2.48531e+00 Accuracy: 0.08333 Epoch Time: 0.97510
# Epoch 19 Loss: 2.48527e+00 Accuracy: 0.08333 Epoch Time: 0.94794
# Epoch 20 Loss: 2.48521e+00 Accuracy: 0.08333 Epoch Time: 1.00510
# Epoch 21 Loss: 2.48515e+00 Accuracy: 0.08333 Epoch Time: 0.96257
# Epoch 22 Loss: 2.48504e+00 Accuracy: 0.08333 Epoch Time: 0.98073
# Epoch 23 Loss: 2.48493e+00 Accuracy: 0.08333 Epoch Time: 0.99079
# Epoch 24 Loss: 2.48484e+00 Accuracy: 0.08333 Epoch Time: 0.97253
# Epoch 25 Loss: 2.48476e+00 Accuracy: 0.08482 Epoch Time: 0.97746
# Epoch 26 Loss: 2.48465e+00 Accuracy: 0.08538 Epoch Time: 0.94204
# Epoch 27 Loss: 2.48455e+00 Accuracy: 0.09022 Epoch Time: 0.91477
# Epoch 28 Loss: 2.48445e+00 Accuracy: 0.08854 Epoch Time: 0.93361
# Epoch 29 Loss: 2.48431e+00 Accuracy: 0.09282 Epoch Time: 0.92804
# Noise Level: none Mode: era_lstm Test Acc: 0.09192439862542956
# Noise Level: none Mode: target_5_val
# Train-val-test lengths:  5376 1152 1164
# Epoch  0 Loss: 1.58975e+00 Accuracy: 0.25037 Epoch Time: 0.97139
# Epoch  1 Loss: 1.58255e+00 Accuracy: 0.25037 Epoch Time: 1.06618
# Epoch  2 Loss: 1.56845e+00 Accuracy: 0.25037 Epoch Time: 0.98134
# Epoch  3 Loss: 1.53717e+00 Accuracy: 0.25037 Epoch Time: 0.94600
# Epoch  4 Loss: 1.49837e+00 Accuracy: 0.25037 Epoch Time: 0.97817
# Epoch  5 Loss: 1.48150e+00 Accuracy: 0.24256 Epoch Time: 0.97201
# Epoch  6 Loss: 1.47705e+00 Accuracy: 0.24833 Epoch Time: 1.01824
# Epoch  7 Loss: 1.47561e+00 Accuracy: 0.24033 Epoch Time: 1.00148
# Epoch  8 Loss: 1.47503e+00 Accuracy: 0.24572 Epoch Time: 0.94797
# Epoch  9 Loss: 1.47481e+00 Accuracy: 0.25037 Epoch Time: 0.96996
# Epoch 10 Loss: 1.47463e+00 Accuracy: 0.25037 Epoch Time: 0.87971
# Epoch 11 Loss: 1.47453e+00 Accuracy: 0.25056 Epoch Time: 0.95895
# Epoch 12 Loss: 1.47454e+00 Accuracy: 0.25037 Epoch Time: 0.98605
# Epoch 13 Loss: 1.47444e+00 Accuracy: 0.25037 Epoch Time: 0.93241
# Epoch 14 Loss: 1.47442e+00 Accuracy: 0.25037 Epoch Time: 1.00532
# Epoch 15 Loss: 1.47447e+00 Accuracy: 0.25037 Epoch Time: 0.88718
# Epoch 16 Loss: 1.47441e+00 Accuracy: 0.25037 Epoch Time: 0.96104
# Epoch 17 Loss: 1.47435e+00 Accuracy: 0.25037 Epoch Time: 0.93551
# Epoch 18 Loss: 1.47440e+00 Accuracy: 0.25037 Epoch Time: 0.93578
# Epoch 19 Loss: 1.47434e+00 Accuracy: 0.25037 Epoch Time: 0.93231
# Epoch 20 Loss: 1.47435e+00 Accuracy: 0.25037 Epoch Time: 1.01166
# Epoch 21 Loss: 1.47424e+00 Accuracy: 0.25037 Epoch Time: 1.00582
# Epoch 22 Loss: 1.47400e+00 Accuracy: 0.25037 Epoch Time: 0.93913
# Epoch 23 Loss: 1.47388e+00 Accuracy: 0.25037 Epoch Time: 0.96952
# Epoch 24 Loss: 1.47377e+00 Accuracy: 0.25037 Epoch Time: 0.87558
# Epoch 25 Loss: 1.47364e+00 Accuracy: 0.25037 Epoch Time: 0.95039
# Epoch 26 Loss: 1.47353e+00 Accuracy: 0.25037 Epoch Time: 0.95168
# Epoch 27 Loss: 1.47346e+00 Accuracy: 0.25037 Epoch Time: 0.95501
# Epoch 28 Loss: 1.47329e+00 Accuracy: 0.25037 Epoch Time: 1.04673
# Epoch 29 Loss: 1.47312e+00 Accuracy: 0.25037 Epoch Time: 0.90006
# Noise Level: none Mode: target_5_val_lstm Test Acc: 0.24140893470790378
# Noise Level: none Mode: target_10_val
# Train-val-test lengths:  5376 1152 1164
# Epoch  0 Loss: 1.59439e+00 Accuracy: 0.24628 Epoch Time: 0.97967
# Epoch  1 Loss: 1.58437e+00 Accuracy: 0.26246 Epoch Time: 0.91715
# Epoch  2 Loss: 1.56563e+00 Accuracy: 0.25019 Epoch Time: 0.93744
# Epoch  3 Loss: 1.52644e+00 Accuracy: 0.24888 Epoch Time: 0.96097
# Epoch  4 Loss: 1.47721e+00 Accuracy: 0.24870 Epoch Time: 0.94159
# Epoch  5 Loss: 1.45437e+00 Accuracy: 0.24795 Epoch Time: 0.93046
# Epoch  6 Loss: 1.44721e+00 Accuracy: 0.24795 Epoch Time: 0.95545
# Epoch  7 Loss: 1.44435e+00 Accuracy: 0.24795 Epoch Time: 0.95800
# Epoch  8 Loss: 1.44309e+00 Accuracy: 0.23865 Epoch Time: 1.00132
# Epoch  9 Loss: 1.44238e+00 Accuracy: 0.24330 Epoch Time: 1.01632
# Epoch 10 Loss: 1.44193e+00 Accuracy: 0.24833 Epoch Time: 0.94855
# Epoch 11 Loss: 1.44171e+00 Accuracy: 0.24461 Epoch Time: 0.99376
# Epoch 12 Loss: 1.44149e+00 Accuracy: 0.24647 Epoch Time: 0.95259
# Epoch 13 Loss: 1.44144e+00 Accuracy: 0.24628 Epoch Time: 0.98012
# Epoch 14 Loss: 1.44133e+00 Accuracy: 0.25037 Epoch Time: 0.95889
# Epoch 15 Loss: 1.44125e+00 Accuracy: 0.24349 Epoch Time: 1.00166
# Epoch 16 Loss: 1.44115e+00 Accuracy: 0.25037 Epoch Time: 0.95366
# Epoch 17 Loss: 1.44109e+00 Accuracy: 0.25037 Epoch Time: 0.93227
# Epoch 18 Loss: 1.44107e+00 Accuracy: 0.24256 Epoch Time: 0.95186
# Epoch 19 Loss: 1.44096e+00 Accuracy: 0.24926 Epoch Time: 0.96272
# Epoch 20 Loss: 1.44090e+00 Accuracy: 0.24721 Epoch Time: 0.95509
# Epoch 21 Loss: 1.44077e+00 Accuracy: 0.24888 Epoch Time: 1.09015
# Epoch 22 Loss: 1.44070e+00 Accuracy: 0.24665 Epoch Time: 0.86933
# Epoch 23 Loss: 1.44054e+00 Accuracy: 0.25056 Epoch Time: 0.98365
# Epoch 24 Loss: 1.44042e+00 Accuracy: 0.24330 Epoch Time: 0.95195
# Epoch 25 Loss: 1.44021e+00 Accuracy: 0.24944 Epoch Time: 0.96732
# Epoch 26 Loss: 1.43994e+00 Accuracy: 0.25056 Epoch Time: 0.93874
# Epoch 27 Loss: 1.43966e+00 Accuracy: 0.25558 Epoch Time: 0.95919
# Epoch 28 Loss: 1.43925e+00 Accuracy: 0.24628 Epoch Time: 0.95726
# Epoch 29 Loss: 1.43890e+00 Accuracy: 0.25577 Epoch Time: 1.01835
# Noise Level: none Mode: target_10_val_lstm Test Acc: 0.2766323024054983
# Noise Level: low Mode: era
# Train-val-test lengths:  218316 46788 46788
# Epoch  0 Loss: 2.48606e+00 Accuracy: 0.08330 Epoch Time: 25.11696
# Epoch  1 Loss: 2.47805e+00 Accuracy: 0.09952 Epoch Time: 25.27011
# Epoch  2 Loss: 2.13713e+00 Accuracy: 0.22967 Epoch Time: 25.24445
# Epoch  3 Loss: 1.94762e+00 Accuracy: 0.30487 Epoch Time: 25.25570
# Epoch  4 Loss: 1.86461e+00 Accuracy: 0.32196 Epoch Time: 24.96486
# Epoch  5 Loss: 1.81265e+00 Accuracy: 0.33247 Epoch Time: 25.13130
# Epoch  6 Loss: 1.77378e+00 Accuracy: 0.34019 Epoch Time: 25.17116
# Epoch  7 Loss: 1.74164e+00 Accuracy: 0.34684 Epoch Time: 25.23335
# Epoch  8 Loss: 1.71575e+00 Accuracy: 0.35112 Epoch Time: 24.93603
# Epoch  9 Loss: 1.69282e+00 Accuracy: 0.35387 Epoch Time: 24.98067
# Epoch 10 Loss: 1.67272e+00 Accuracy: 0.35672 Epoch Time: 25.03386
# Epoch 11 Loss: 1.65485e+00 Accuracy: 0.36043 Epoch Time: 24.58081
# Epoch 12 Loss: 1.63914e+00 Accuracy: 0.36350 Epoch Time: 24.83747
# Epoch 13 Loss: 1.62434e+00 Accuracy: 0.36729 Epoch Time: 24.84440
# Epoch 14 Loss: 1.61051e+00 Accuracy: 0.37076 Epoch Time: 24.97535
# Epoch 15 Loss: 1.59670e+00 Accuracy: 0.37350 Epoch Time: 25.01760
# Epoch 16 Loss: 1.58103e+00 Accuracy: 0.37813 Epoch Time: 25.00186
# Epoch 17 Loss: 1.56236e+00 Accuracy: 0.38377 Epoch Time: 24.82871
# Epoch 18 Loss: 1.53925e+00 Accuracy: 0.39233 Epoch Time: 24.92607
# Epoch 19 Loss: 1.51080e+00 Accuracy: 0.40418 Epoch Time: 25.00519
# Epoch 20 Loss: 1.48132e+00 Accuracy: 0.41551 Epoch Time: 24.89770
# Epoch 21 Loss: 1.45270e+00 Accuracy: 0.42741 Epoch Time: 25.09066
# Epoch 22 Loss: 1.42651e+00 Accuracy: 0.43923 Epoch Time: 25.29299
# Epoch 23 Loss: 1.40313e+00 Accuracy: 0.44843 Epoch Time: 25.34935
# Epoch 24 Loss: 1.38351e+00 Accuracy: 0.45623 Epoch Time: 25.25922
# Epoch 25 Loss: 1.36630e+00 Accuracy: 0.46266 Epoch Time: 24.99542
# Epoch 26 Loss: 1.34975e+00 Accuracy: 0.46872 Epoch Time: 24.87026
# Epoch 27 Loss: 1.33499e+00 Accuracy: 0.47363 Epoch Time: 24.99470
# Epoch 28 Loss: 1.31948e+00 Accuracy: 0.47806 Epoch Time: 25.52179
# Epoch 29 Loss: 1.30463e+00 Accuracy: 0.48352 Epoch Time: 25.32813
# Noise Level: low Mode: era_lstm Test Acc: 0.48506027186458067
# Noise Level: low Mode: target_5_val
# Train-val-test lengths:  218316 46788 46788
# Epoch  0 Loss: 1.56217e+00 Accuracy: 0.19587 Epoch Time: 25.49301
# Epoch  1 Loss: 1.52982e+00 Accuracy: 0.23482 Epoch Time: 25.35158
# Epoch  2 Loss: 1.52973e+00 Accuracy: 0.23594 Epoch Time: 25.15827
# Epoch  3 Loss: 1.52752e+00 Accuracy: 0.26009 Epoch Time: 25.42450
# Epoch  4 Loss: 1.45606e+00 Accuracy: 0.35867 Epoch Time: 25.47778
# Epoch  5 Loss: 1.33851e+00 Accuracy: 0.42475 Epoch Time: 25.33504
# Epoch  6 Loss: 1.28234e+00 Accuracy: 0.45363 Epoch Time: 25.68855
# Epoch  7 Loss: 1.24536e+00 Accuracy: 0.48030 Epoch Time: 25.68515
# Epoch  8 Loss: 1.22349e+00 Accuracy: 0.49366 Epoch Time: 25.43913
# Epoch  9 Loss: 1.21187e+00 Accuracy: 0.49546 Epoch Time: 25.44183
# Epoch 10 Loss: 1.20255e+00 Accuracy: 0.49562 Epoch Time: 25.39194
# Epoch 11 Loss: 1.19411e+00 Accuracy: 0.49434 Epoch Time: 25.76336
# Epoch 12 Loss: 1.18757e+00 Accuracy: 0.49421 Epoch Time: 25.63654
# Epoch 13 Loss: 1.18211e+00 Accuracy: 0.49518 Epoch Time: 25.67713
# Epoch 14 Loss: 1.17718e+00 Accuracy: 0.49601 Epoch Time: 25.45042
# Epoch 15 Loss: 1.17270e+00 Accuracy: 0.49957 Epoch Time: 25.28830
# Epoch 16 Loss: 1.16774e+00 Accuracy: 0.50350 Epoch Time: 25.62818
# Epoch 17 Loss: 1.16173e+00 Accuracy: 0.50809 Epoch Time: 25.44729
# Epoch 18 Loss: 1.15479e+00 Accuracy: 0.51352 Epoch Time: 25.47941
# Epoch 19 Loss: 1.14708e+00 Accuracy: 0.52034 Epoch Time: 25.49373
# Epoch 20 Loss: 1.13703e+00 Accuracy: 0.52783 Epoch Time: 25.34224
# Epoch 21 Loss: 1.12542e+00 Accuracy: 0.53408 Epoch Time: 25.40144
# Epoch 22 Loss: 1.11621e+00 Accuracy: 0.53870 Epoch Time: 25.55913
# Epoch 23 Loss: 1.10918e+00 Accuracy: 0.54180 Epoch Time: 25.34875
# Epoch 24 Loss: 1.10375e+00 Accuracy: 0.54503 Epoch Time: 25.13524
# Epoch 25 Loss: 1.09819e+00 Accuracy: 0.54809 Epoch Time: 25.55777
# Epoch 26 Loss: 1.09354e+00 Accuracy: 0.55056 Epoch Time: 25.56783
# Epoch 27 Loss: 1.08855e+00 Accuracy: 0.55167 Epoch Time: 25.67791
# Epoch 28 Loss: 1.08540e+00 Accuracy: 0.55427 Epoch Time: 25.22155
# Epoch 29 Loss: 1.08109e+00 Accuracy: 0.55554 Epoch Time: 25.56735
# Noise Level: low Mode: target_5_val_lstm Test Acc: 0.5544797811404634
# Noise Level: low Mode: target_10_val
# Train-val-test lengths:  218316 46788 46788
# Epoch  0 Loss: 1.49254e+00 Accuracy: 0.27146 Epoch Time: 25.58180
# Epoch  1 Loss: 1.44118e+00 Accuracy: 0.27146 Epoch Time: 25.64235
# Epoch  2 Loss: 1.44106e+00 Accuracy: 0.27146 Epoch Time: 25.59351
# Epoch  3 Loss: 1.40973e+00 Accuracy: 0.31802 Epoch Time: 25.72993
# Epoch  4 Loss: 1.29736e+00 Accuracy: 0.45485 Epoch Time: 25.70818
# Epoch  5 Loss: 1.22175e+00 Accuracy: 0.48992 Epoch Time: 25.55671
# Epoch  6 Loss: 1.16570e+00 Accuracy: 0.50759 Epoch Time: 25.45290
# Epoch  7 Loss: 1.13577e+00 Accuracy: 0.51488 Epoch Time: 25.52544
# Epoch  8 Loss: 1.11334e+00 Accuracy: 0.52189 Epoch Time: 25.60621
# Epoch  9 Loss: 1.09181e+00 Accuracy: 0.53461 Epoch Time: 25.94947
# Epoch 10 Loss: 1.07386e+00 Accuracy: 0.54107 Epoch Time: 25.82718
# Epoch 11 Loss: 1.06306e+00 Accuracy: 0.54395 Epoch Time: 25.67398
# Epoch 12 Loss: 1.05571e+00 Accuracy: 0.54685 Epoch Time: 25.58088
# Epoch 13 Loss: 1.04927e+00 Accuracy: 0.54979 Epoch Time: 25.44186
# Epoch 14 Loss: 1.04447e+00 Accuracy: 0.55436 Epoch Time: 25.59961
# Epoch 15 Loss: 1.03966e+00 Accuracy: 0.55909 Epoch Time: 25.56697
# Epoch 16 Loss: 1.03509e+00 Accuracy: 0.56497 Epoch Time: 25.51276
# Epoch 17 Loss: 1.03036e+00 Accuracy: 0.57014 Epoch Time: 25.56020
# Epoch 18 Loss: 1.02604e+00 Accuracy: 0.57455 Epoch Time: 25.80930
# Epoch 19 Loss: 1.02135e+00 Accuracy: 0.57758 Epoch Time: 25.54766
# Epoch 20 Loss: 1.01619e+00 Accuracy: 0.58198 Epoch Time: 25.69240
# Epoch 21 Loss: 1.01279e+00 Accuracy: 0.58553 Epoch Time: 25.46922
# Epoch 22 Loss: 1.00855e+00 Accuracy: 0.58916 Epoch Time: 25.48189
# Epoch 23 Loss: 1.00480e+00 Accuracy: 0.59196 Epoch Time: 25.74733
# Epoch 24 Loss: 1.00094e+00 Accuracy: 0.59397 Epoch Time: 25.89161
# Epoch 25 Loss: 9.97050e-01 Accuracy: 0.59662 Epoch Time: 25.51500
# Epoch 26 Loss: 9.93962e-01 Accuracy: 0.59783 Epoch Time: 25.74601
# Epoch 27 Loss: 9.89965e-01 Accuracy: 0.59941 Epoch Time: 25.64324
# Epoch 28 Loss: 9.86813e-01 Accuracy: 0.60114 Epoch Time: 25.34162
# Epoch 29 Loss: 9.82529e-01 Accuracy: 0.60319 Epoch Time: 25.54509
# Noise Level: low Mode: target_10_val_lstm Test Acc: 0.6010942976831666
# Noise Level: high Mode: era
# Train-val-test lengths:  174640 37422 37430
# Epoch  0 Loss: 2.48675e+00 Accuracy: 0.08338 Epoch Time: 20.58204
# Epoch  1 Loss: 2.48520e+00 Accuracy: 0.08301 Epoch Time: 20.43417
# Epoch  2 Loss: 2.48492e+00 Accuracy: 0.08457 Epoch Time: 20.42409
# Epoch  3 Loss: 2.48484e+00 Accuracy: 0.08574 Epoch Time: 20.27775
# Epoch  4 Loss: 2.48476e+00 Accuracy: 0.08504 Epoch Time: 20.46008
# Epoch  5 Loss: 2.48445e+00 Accuracy: 0.09031 Epoch Time: 20.37738
# Epoch  6 Loss: 2.38738e+00 Accuracy: 0.15722 Epoch Time: 20.25618
# Epoch  7 Loss: 2.17086e+00 Accuracy: 0.21651 Epoch Time: 20.22063
# Epoch  8 Loss: 2.09108e+00 Accuracy: 0.23857 Epoch Time: 20.36151
# Epoch  9 Loss: 2.04431e+00 Accuracy: 0.24557 Epoch Time: 20.39514
# Epoch 10 Loss: 2.01376e+00 Accuracy: 0.25063 Epoch Time: 20.54537
# Epoch 11 Loss: 1.99428e+00 Accuracy: 0.25555 Epoch Time: 20.55592
# Epoch 12 Loss: 1.97803e+00 Accuracy: 0.26006 Epoch Time: 20.30967
# Epoch 13 Loss: 1.96397e+00 Accuracy: 0.26234 Epoch Time: 20.55452
# Epoch 14 Loss: 1.95218e+00 Accuracy: 0.26567 Epoch Time: 20.26126
# Epoch 15 Loss: 1.94234e+00 Accuracy: 0.26714 Epoch Time: 20.23134
# Epoch 16 Loss: 1.93188e+00 Accuracy: 0.26892 Epoch Time: 20.40729
# Epoch 17 Loss: 1.92276e+00 Accuracy: 0.27114 Epoch Time: 20.37191
# Epoch 18 Loss: 1.91395e+00 Accuracy: 0.27333 Epoch Time: 20.37985
# Epoch 19 Loss: 1.90592e+00 Accuracy: 0.27448 Epoch Time: 20.51847
# Epoch 20 Loss: 1.89719e+00 Accuracy: 0.27548 Epoch Time: 20.35101
# Epoch 21 Loss: 1.88539e+00 Accuracy: 0.27960 Epoch Time: 20.27883
# Epoch 22 Loss: 1.87110e+00 Accuracy: 0.28378 Epoch Time: 20.45631
# Epoch 23 Loss: 1.85304e+00 Accuracy: 0.29269 Epoch Time: 20.35419
# Epoch 24 Loss: 1.82963e+00 Accuracy: 0.30356 Epoch Time: 20.45019
# Epoch 25 Loss: 1.80517e+00 Accuracy: 0.31774 Epoch Time: 20.37119
# Epoch 26 Loss: 1.78092e+00 Accuracy: 0.32946 Epoch Time: 20.53494
# Epoch 27 Loss: 1.75677e+00 Accuracy: 0.33857 Epoch Time: 20.47112
# Epoch 28 Loss: 1.73557e+00 Accuracy: 0.34565 Epoch Time: 20.63044
# Epoch 29 Loss: 1.71388e+00 Accuracy: 0.35361 Epoch Time: 20.42320
# Noise Level: high Mode: era_lstm Test Acc: 0.3556772642265562
# Noise Level: high Mode: target_5_val
# Train-val-test lengths:  174640 37422 37430
# Epoch  0 Loss: 1.53206e+00 Accuracy: 0.24049 Epoch Time: 20.66694
# Epoch  1 Loss: 1.48845e+00 Accuracy: 0.24045 Epoch Time: 20.33228
# Epoch  2 Loss: 1.48848e+00 Accuracy: 0.24107 Epoch Time: 20.35268
# Epoch  3 Loss: 1.48846e+00 Accuracy: 0.24183 Epoch Time: 20.39722
# Epoch  4 Loss: 1.48846e+00 Accuracy: 0.24160 Epoch Time: 20.43695
# Epoch  5 Loss: 1.48847e+00 Accuracy: 0.24063 Epoch Time: 20.59279
# Epoch  6 Loss: 1.48845e+00 Accuracy: 0.24105 Epoch Time: 20.42453
# Epoch  7 Loss: 1.48845e+00 Accuracy: 0.24017 Epoch Time: 20.30401
# Epoch  8 Loss: 1.48843e+00 Accuracy: 0.24221 Epoch Time: 20.44382
# Epoch  9 Loss: 1.48843e+00 Accuracy: 0.24145 Epoch Time: 20.21159
# Epoch 10 Loss: 1.48842e+00 Accuracy: 0.24167 Epoch Time: 20.30524
# Epoch 11 Loss: 1.48839e+00 Accuracy: 0.24202 Epoch Time: 20.36396
# Epoch 12 Loss: 1.48837e+00 Accuracy: 0.24229 Epoch Time: 20.35418
# Epoch 13 Loss: 1.48830e+00 Accuracy: 0.24414 Epoch Time: 20.16930
# Epoch 14 Loss: 1.48811e+00 Accuracy: 0.24575 Epoch Time: 20.30319
# Epoch 15 Loss: 1.48779e+00 Accuracy: 0.25194 Epoch Time: 20.27841
# Epoch 16 Loss: 1.48642e+00 Accuracy: 0.26633 Epoch Time: 20.17664
# Epoch 17 Loss: 1.47843e+00 Accuracy: 0.28667 Epoch Time: 20.26658
# Epoch 18 Loss: 1.47014e+00 Accuracy: 0.29783 Epoch Time: 20.51113
# Epoch 19 Loss: 1.46538e+00 Accuracy: 0.30873 Epoch Time: 20.31275
# Epoch 20 Loss: 1.46077e+00 Accuracy: 0.31553 Epoch Time: 20.07140
# Epoch 21 Loss: 1.45614e+00 Accuracy: 0.32052 Epoch Time: 20.45824
# Epoch 22 Loss: 1.45137e+00 Accuracy: 0.32430 Epoch Time: 20.45112
# Epoch 23 Loss: 1.44728e+00 Accuracy: 0.32787 Epoch Time: 20.23062
# Epoch 24 Loss: 1.44413e+00 Accuracy: 0.32883 Epoch Time: 20.34014
# Epoch 25 Loss: 1.44148e+00 Accuracy: 0.33113 Epoch Time: 20.35549
# Epoch 26 Loss: 1.43893e+00 Accuracy: 0.33259 Epoch Time: 20.23844
# Epoch 27 Loss: 1.43620e+00 Accuracy: 0.33549 Epoch Time: 20.15735
# Epoch 28 Loss: 1.43452e+00 Accuracy: 0.33755 Epoch Time: 20.43170
# Epoch 29 Loss: 1.43317e+00 Accuracy: 0.33765 Epoch Time: 20.37860
# Noise Level: high Mode: target_5_val_lstm Test Acc: 0.3442693026983703
# Noise Level: high Mode: target_10_val
# Train-val-test lengths:  174640 37422 37430
# Epoch  0 Loss: 1.50627e+00 Accuracy: 0.20736 Epoch Time: 20.27488
# Epoch  1 Loss: 1.43284e+00 Accuracy: 0.25937 Epoch Time: 20.45243
# Epoch  2 Loss: 1.43282e+00 Accuracy: 0.25937 Epoch Time: 20.34444
# Epoch  3 Loss: 1.43279e+00 Accuracy: 0.25937 Epoch Time: 20.41209
# Epoch  4 Loss: 1.43280e+00 Accuracy: 0.25937 Epoch Time: 20.53450
# Epoch  5 Loss: 1.43279e+00 Accuracy: 0.25937 Epoch Time: 20.36999
# Epoch  6 Loss: 1.43277e+00 Accuracy: 0.25937 Epoch Time: 20.61189
# Epoch  7 Loss: 1.43278e+00 Accuracy: 0.25937 Epoch Time: 20.46391
# Epoch  8 Loss: 1.43278e+00 Accuracy: 0.25937 Epoch Time: 20.59537
# Epoch  9 Loss: 1.43271e+00 Accuracy: 0.25937 Epoch Time: 20.38513
# Epoch 10 Loss: 1.43254e+00 Accuracy: 0.25937 Epoch Time: 20.37003
# Epoch 11 Loss: 1.43096e+00 Accuracy: 0.26582 Epoch Time: 20.56662
# Epoch 12 Loss: 1.42217e+00 Accuracy: 0.30709 Epoch Time: 20.45399
# Epoch 13 Loss: 1.41713e+00 Accuracy: 0.31390 Epoch Time: 20.24288
# Epoch 14 Loss: 1.41363e+00 Accuracy: 0.32147 Epoch Time: 20.42422
# Epoch 15 Loss: 1.40954e+00 Accuracy: 0.32691 Epoch Time: 20.38475
# Epoch 16 Loss: 1.40365e+00 Accuracy: 0.33404 Epoch Time: 20.42746
# Epoch 17 Loss: 1.39656e+00 Accuracy: 0.34111 Epoch Time: 20.51031
# Epoch 18 Loss: 1.38874e+00 Accuracy: 0.34745 Epoch Time: 20.45597
# Epoch 19 Loss: 1.37789e+00 Accuracy: 0.35640 Epoch Time: 20.29734
# Epoch 20 Loss: 1.36886e+00 Accuracy: 0.36188 Epoch Time: 20.25234
# Epoch 21 Loss: 1.36232e+00 Accuracy: 0.36490 Epoch Time: 20.26577
# Epoch 22 Loss: 1.35700e+00 Accuracy: 0.36987 Epoch Time: 20.33945
# Epoch 23 Loss: 1.35325e+00 Accuracy: 0.37582 Epoch Time: 20.30988
# Epoch 24 Loss: 1.35039e+00 Accuracy: 0.37932 Epoch Time: 19.77889
# Epoch 25 Loss: 1.34741e+00 Accuracy: 0.38244 Epoch Time: 19.79237
# Epoch 26 Loss: 1.34537e+00 Accuracy: 0.38373 Epoch Time: 19.81581
# Epoch 27 Loss: 1.34300e+00 Accuracy: 0.38602 Epoch Time: 19.84096
# Epoch 28 Loss: 1.34110e+00 Accuracy: 0.38722 Epoch Time: 19.69127
# Epoch 29 Loss: 1.33908e+00 Accuracy: 0.38866 Epoch Time: 20.29135
# Noise Level: high Mode: target_10_val_lstm Test Acc: 0.3907026449372161

# %%
with open(f'{prefix}/losses_dump.pkl', 'wb') as f:
    pkl.dump(losses_arr, f)

with open(f'{prefix}/accs_dump.pkl', 'wb') as f:
    pkl.dump(accs_arr, f)
