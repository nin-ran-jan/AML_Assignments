# %%
# !gdown https://drive.google.com/file/d/1Hv4RAltBumSfOkRacoX8qrfDYfd_NDss/view?usp=drive_link --fuzzy

# %%
# !unzip Dataset_AML_Assignment1_Part1.zip

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np
import torch
from torch import nn
from torch import optim
from torch.utils.data import Dataset, DataLoader, random_split, ConcatDataset
import torch.nn.functional as F
from IPython import display 
from tqdm.notebook import tqdm
import random
import math, time, os
from matplotlib import pyplot as plt
import pickle as pkl


device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')
print(device)
prefix = './data_dump_lstm_ensemble_rerun'
# Out:
# cuda:1

# %%
class SinusodialDatasetSequential(Dataset):
    def __init__(self, df, mode='era', window_size=10):
        """ creating label columns of eras and targets """

        # df.sort_values(by=['day', 'row_num'], inplace=True)
        # self.eras = df['era_label']
        self.X = df.iloc[:, :26]
        self.y = df[f'{mode}']
        self.window_size = window_size

    def __len__(self):
        return self.X.shape[0]-self.window_size+1

    def __getitem__(self, idx):
        """ you are working on the sample idx+self.window_size = actual idx"""
        # if self.eras.iloc[idx] != self.eras.iloc[idx+self.window_size-1]:
        #     for i in range(idx, idx+self.window_size):
        #         if self.eras.iloc[idx] != self.eras.iloc[i]:
        #             break
        #     X = torch.tensor(self.X.iloc[idx:i].values, dtype=torch.float32)
        #     y = torch.tensor(int(self.y.iloc[i-1]), dtype=torch.long)
        #     return X, y
          
        X = torch.tensor(self.X.iloc[idx:idx+self.window_size].values, dtype=torch.float32)
        y = torch.tensor(int(self.y.iloc[idx+self.window_size-1]), dtype=torch.long)
        return X, y

# %%
def make_data_splits_sequential(df, mode, batch_size=32, train_perc=0.7, val_test_perc=0.5):

    def encode(v, class_values):
        return class_values.index(v)

    #adding new era_label column indexed 0, 1,...
    class_values = df[f'{mode}'].unique().tolist()
    df[f'{mode}'] = df[f'{mode}'].apply(lambda x: encode(x, class_values))
    df.reset_index(drop=True, inplace=True)

    train_dataset_list = []
    val_dataset_list = []
    test_dataset_list = []

    for era in df['era'].unique():
        condition = df['era'] == era
        df_era = df[condition]

        data = SinusodialDatasetSequential(df_era, mode=mode)
        
        train_samples = int(len(data)*train_perc)
        val_test_samples = len(data)-train_samples

        data_train, data_test = random_split(data, [train_samples, val_test_samples])

        val_samples = int(len(data_test)*val_test_perc)
        test_samples = len(data_test)-val_samples
        data_val, data_test = random_split(data_test, [val_samples, test_samples])

        train_dataset_list.append(data_train)
        val_dataset_list.append(data_val)
        test_dataset_list.append(data_test)
    
    dataset_train = ConcatDataset(train_dataset_list)
    dataset_val = ConcatDataset(val_dataset_list)
    dataset_test = ConcatDataset(test_dataset_list)

    print("Train-val-test lengths: ", len(dataset_train), len(dataset_val), len(dataset_test))

    loader_train = DataLoader(dataset_train, batch_size=batch_size, shuffle=True)
    loader_val = DataLoader(dataset_val, batch_size=batch_size, shuffle=False)
    loader_test = DataLoader(dataset_test, batch_size=batch_size, shuffle=False)

    return loader_train, loader_val, loader_test

# %% [markdown]
# #LSTM

# %%
import torch.nn.init as init

class LSTMClassifier(nn.Module):
    def __init__(self, input_dim, output_size, hidden_size = 64, num_layers = 4, lr=5e-4, weight_decay=1e-3):
        super(LSTMClassifier, self).__init__()
        self.lstm = nn.LSTM(input_dim, hidden_size, num_layers, batch_first=True)
        self.classifier = nn.Linear(hidden_size, output_size)
        self.log_softmax = nn.LogSoftmax(dim=1)
        self.optimizer = optim.Adam(self.parameters(), lr=lr, weight_decay=weight_decay)

        torch.nn.utils.clip_grad_norm_(self.parameters(), max_norm=1.0)
        for name, param in self.lstm.named_parameters():
            if 'weight' in name:
                init.xavier_normal_(param.data)
            if 'bias' in name:
                init.constant_(param.data, 0.0)

    def forward(self, x):
        x, _ = self.lstm(x)
        return self.log_softmax(self.classifier(x[:, -1, :]))

# %%
def accuracy(y_pred, y_test, verbose=True):
    m = y_test.shape[0]
    predicted = torch.max(y_pred, 1)[1]
    correct = (predicted == y_test).float().sum().item()
    if verbose:
        print(correct,m)
    accuracy = correct/m
    return accuracy, correct

# %%
def Test(net, loader_test, mode, noise_level, device='cpu', Loss=nn.NLLLoss(reduction='sum')):
    net.eval()
    total_samples = 0
    correct_samples = 0
    loss = 0.0
    for (X, y) in loader_test:
        X=X.to(device)
        y=y.to(device)
        total_samples += y.shape[0]
        y_out = net(X)
        _, i_cor_sam = accuracy(y_out,y,verbose=False)
        correct_samples += i_cor_sam
        loss += Loss(y_out, y).cpu().detach().item()
    acc = correct_samples / total_samples
    loss /= total_samples
    net.train()
    return loss, acc

# %%
def Train(Net, data, mode, noise_level, epochs=20, lr=5e-2, Loss=nn.NLLLoss(reduction='sum'), verbose=False, device='cpu',
          val_ds=None, plot_accs=False, plot_losses=False):
    model_save_time = time.time()
    losses = []
    accs = []
    val_losses=[]
    val_accL=[]
    Net.to(device)
    for e in range(epochs):
        Net.train()
        step=0
        tot_loss = 0.0
        start_time = time.time()
        correct_samples = 0
        total_samples = 0
        for (X,y) in data:
            X=X.to(device)
            y=y.to(device)
            total_samples += y.shape[0]
            y_out = Net(X)
            loss = Loss(y_out, y)
            Net.optimizer.zero_grad()
            loss.backward()
            Net.optimizer.step()
            step+=1
            tot_loss+=loss
            if verbose:
                _, i_cor_sam = accuracy(y_out,y,verbose=False)
                correct_samples += i_cor_sam
        end_time = time.time()
        t = end_time-start_time
        l = tot_loss.item()/total_samples
        losses += [l]
        if verbose:
            a = correct_samples/total_samples
            accs += [a]
            print('Epoch %2d Loss: %2.5e Accuracy: %2.5f Epoch Time: %2.5f' %(e,l,a,t))

        val_loss, val_acc = Test(Net, val_ds, mode, noise_level, device)
        val_losses.append(val_loss)
        val_accL.append(val_acc)

        torch.save(Net.state_dict(), f'{prefix}/net_{noise_level}_{mode}_{str(model_save_time)}.pth')

    return Net, losses, accs, val_losses, val_accL

# %%
def plot_loss_acc(losses, accs, val_losses, val_accs, mode, noise_level):

    plt.plot(np.array(accs),color='red', label='Train accuracy')
    plt.plot(np.array(val_accs),color='blue', label='Val accuracy')
    plt.legend()
    plt.savefig(f'{prefix}/acc_{mode}_{noise_level}.png')
    plt.clf()

    plt.plot(np.array(losses),color='red', label='Train loss')
    plt.plot(np.array(val_losses),color='blue', label='Val loss')
    plt.legend()
    plt.savefig(f'{prefix}/loss_{mode}_{noise_level}.png')
    plt.clf()
    return

# %%
def TestEnsemble(nets, loader_test, mode, noise_level, \
         device='cpu', Loss=nn.NLLLoss(reduction='sum')):
    total_samples = 0
    correct_samples = 0

    for (X, y) in loader_test:
        X=X.to(device)
        y=y.to(device)
        sample_size = y.shape[0]
        total_samples += sample_size

        y_preds = []
        all_classes = 0

        for net in nets:
          net.eval()
          __y_pred = net(X)
          all_classes = __y_pred.shape[-1]
          predicted = torch.max(__y_pred, 1)[1]
          y_preds.append(predicted.cpu().detach().numpy())


        predicted = []

        for i in range(sample_size):
          voting_array = [0] * all_classes
          for model_num in range(len(nets)):
            voting_array[y_preds[model_num][i]] += 1
          max_val = -1
          max_ind = -1
          for ind in range(len(voting_array)):
            if voting_array[ind] > max_val:
              max_val = voting_array[ind]
              max_ind = ind

          predicted.append(max_ind)

        predicted = torch.tensor(predicted).to(device)
        i_cor_sam = (predicted == y).float().sum().item()
        correct_samples += i_cor_sam

    acc = correct_samples / total_samples
    return acc

# %%
device = "cuda:2"

# %%
df_paths = ['../Datasets/df_syn_train_0_0_.csv',
            # '../Datasets/df_synA_train_shuffled.csv',
            # '../Datasets/df_synA_test_hard_shuffled_sample.csv'
            ]

# modes = ['era', 'target_5_val', 'target_10_val']
modes = ['era', 'target_5_val', 'target_10_val']
noise_levels = ['none', 'low', 'high']
epoch_num = [30, 30, 30]
batch_sizes = [16, 128, 128]

losses_arr = []
accs_arr = []

for i in range(1):
    df = pd.read_csv(df_paths[i])
    df.sort_values(by=['era', 'day', 'row_num'], inplace=True)
    
    loss_per_mode = []
    acc_per_mode = []

    for j in range(len(modes)):
        mode = modes[j]
        noise_level = noise_levels[i]
        epochs = epoch_num[j]
        # lr = lrs[j]
        print("Noise Level:", noise_level, "Mode:", mode)
        loader_train, loader_val, loader_test = make_data_splits_sequential(df, mode=mode, \
                                                                       batch_size=batch_sizes[i])
        

        nets = [LSTMClassifier(26, len(df[f'{mode}'].unique())),
            LSTMClassifier(26, len(df[f'{mode}'].unique()), hidden_size= 32, num_layers= 4),
            LSTMClassifier(26, len(df[f'{mode}'].unique()), hidden_size= 64, num_layers= 3)
            ]
        
        mode += '_ensemble_lstm'
        
        for n in range(len(nets)):
            net, losses, accs, val_losses, val_accL = Train(nets[n], loader_train, mode, noise_level, \
                                      epochs=epochs, verbose=True, device=device, val_ds=loader_val, \
                                      plot_accs=True, plot_losses=True, lr=1e-4)
            plot_loss_acc(losses, accs, val_losses, val_accL, mode, noise_levels[i])
            nets[n] = net
            print(f'Model {n} acc: {accs[-1]}')

        ensemble_acc = TestEnsemble(nets, loader_test, mode, noise_level, device=device)
        print(f'"Noise Level: {noise_level} | Mode: {mode} | Ensemble model acc: {ensemble_acc}')

    # loss_per_mode.append(test_loss)
    acc_per_mode.append(ensemble_acc)

# losses_arr.append(loss_per_mode)
accs_arr.append(acc_per_mode)
# Out:
# Noise Level: none Mode: era
# Train-val-test lengths:  5376 1152 1164
# Epoch  0 Loss: 2.48705e+00 Accuracy: 0.08166 Epoch Time: 2.61453
# Epoch  1 Loss: 2.48614e+00 Accuracy: 0.08036 Epoch Time: 2.68440
# Epoch  2 Loss: 2.47887e+00 Accuracy: 0.09635 Epoch Time: 2.59638
# Epoch  3 Loss: 2.32626e+00 Accuracy: 0.17001 Epoch Time: 2.44845
# Epoch  4 Loss: 2.19561e+00 Accuracy: 0.21726 Epoch Time: 2.64661
# Epoch  5 Loss: 1.99946e+00 Accuracy: 0.26153 Epoch Time: 2.63929
# Epoch  6 Loss: 1.79924e+00 Accuracy: 0.31120 Epoch Time: 2.42252
# Epoch  7 Loss: 1.70895e+00 Accuracy: 0.33780 Epoch Time: 2.65675
# Epoch  8 Loss: 1.59028e+00 Accuracy: 0.36607 Epoch Time: 2.52117
# Epoch  9 Loss: 1.49289e+00 Accuracy: 0.39676 Epoch Time: 2.79501
# Epoch 10 Loss: 1.45580e+00 Accuracy: 0.41406 Epoch Time: 2.61184
# Epoch 11 Loss: 1.33366e+00 Accuracy: 0.45759 Epoch Time: 2.52123
# Epoch 12 Loss: 1.29259e+00 Accuracy: 0.47080 Epoch Time: 2.65285
# Epoch 13 Loss: 1.19583e+00 Accuracy: 0.51749 Epoch Time: 2.52560
# Epoch 14 Loss: 1.22102e+00 Accuracy: 0.51172 Epoch Time: 2.64228
# Epoch 15 Loss: 1.10292e+00 Accuracy: 0.56343 Epoch Time: 2.64866
# Epoch 16 Loss: 1.04309e+00 Accuracy: 0.59394 Epoch Time: 2.71918
# Epoch 17 Loss: 1.02860e+00 Accuracy: 0.60045 Epoch Time: 2.63540
# Epoch 18 Loss: 9.16293e-01 Accuracy: 0.64379 Epoch Time: 2.37772
# Epoch 19 Loss: 8.86857e-01 Accuracy: 0.64825 Epoch Time: 2.60524
# Epoch 20 Loss: 8.27223e-01 Accuracy: 0.67076 Epoch Time: 2.67642
# Epoch 21 Loss: 8.08239e-01 Accuracy: 0.68211 Epoch Time: 2.63009
# Epoch 22 Loss: 7.35141e-01 Accuracy: 0.70740 Epoch Time: 2.45621
# Epoch 23 Loss: 6.81061e-01 Accuracy: 0.72824 Epoch Time: 2.56054
# Epoch 24 Loss: 6.33103e-01 Accuracy: 0.74442 Epoch Time: 2.62336
# Epoch 25 Loss: 6.15402e-01 Accuracy: 0.75130 Epoch Time: 2.49128
# Epoch 26 Loss: 6.51458e-01 Accuracy: 0.73512 Epoch Time: 2.62890
# Epoch 27 Loss: 5.49367e-01 Accuracy: 0.78013 Epoch Time: 2.54242
# Epoch 28 Loss: 5.04550e-01 Accuracy: 0.79650 Epoch Time: 2.71507
# Epoch 29 Loss: 5.78038e-01 Accuracy: 0.76004 Epoch Time: 2.52741
# Model 0 acc: 0.7600446428571429
# Epoch  0 Loss: 2.48753e+00 Accuracy: 0.07887 Epoch Time: 2.66615
# Epoch  1 Loss: 2.48635e+00 Accuracy: 0.08092 Epoch Time: 2.64324
# Epoch  2 Loss: 2.48623e+00 Accuracy: 0.07682 Epoch Time: 2.50438
# Epoch  3 Loss: 2.48557e+00 Accuracy: 0.08315 Epoch Time: 2.70173
# Epoch  4 Loss: 2.48577e+00 Accuracy: 0.08036 Epoch Time: 2.51456
# Epoch  5 Loss: 2.48580e+00 Accuracy: 0.07757 Epoch Time: 2.64285
# Epoch  6 Loss: 2.48566e+00 Accuracy: 0.07738 Epoch Time: 2.73995
# Epoch  7 Loss: 2.48554e+00 Accuracy: 0.07682 Epoch Time: 2.58781
# Epoch  8 Loss: 2.48552e+00 Accuracy: 0.07589 Epoch Time: 2.66504
# Epoch  9 Loss: 2.48557e+00 Accuracy: 0.07961 Epoch Time: 2.45892
# Epoch 10 Loss: 2.48556e+00 Accuracy: 0.07273 Epoch Time: 2.64653
# Epoch 11 Loss: 2.48547e+00 Accuracy: 0.07292 Epoch Time: 2.49041
# Epoch 12 Loss: 2.48545e+00 Accuracy: 0.08147 Epoch Time: 2.80290
# Epoch 13 Loss: 2.48539e+00 Accuracy: 0.07347 Epoch Time: 2.66323
# Epoch 14 Loss: 2.48551e+00 Accuracy: 0.07775 Epoch Time: 2.38614
# Epoch 15 Loss: 2.48540e+00 Accuracy: 0.07738 Epoch Time: 2.74014
# Epoch 16 Loss: 2.48540e+00 Accuracy: 0.07701 Epoch Time: 2.37287
# Epoch 17 Loss: 2.48532e+00 Accuracy: 0.08054 Epoch Time: 2.77808
# Epoch 18 Loss: 2.48542e+00 Accuracy: 0.07775 Epoch Time: 2.72912
# Epoch 19 Loss: 2.48540e+00 Accuracy: 0.07515 Epoch Time: 2.37026
# Epoch 20 Loss: 2.48538e+00 Accuracy: 0.07924 Epoch Time: 2.57499
# Epoch 21 Loss: 2.48534e+00 Accuracy: 0.07943 Epoch Time: 2.57423
# Epoch 22 Loss: 2.48534e+00 Accuracy: 0.07738 Epoch Time: 2.56645
# Epoch 23 Loss: 2.48533e+00 Accuracy: 0.08185 Epoch Time: 2.52935
# Epoch 24 Loss: 2.48541e+00 Accuracy: 0.07310 Epoch Time: 2.15714
# Epoch 25 Loss: 2.48530e+00 Accuracy: 0.07478 Epoch Time: 2.67598
# Epoch 26 Loss: 2.48527e+00 Accuracy: 0.07571 Epoch Time: 2.53979
# Epoch 27 Loss: 2.48531e+00 Accuracy: 0.07887 Epoch Time: 2.35346
# Epoch 28 Loss: 2.48534e+00 Accuracy: 0.07403 Epoch Time: 2.56781
# Epoch 29 Loss: 2.48524e+00 Accuracy: 0.07943 Epoch Time: 2.43916
# Model 1 acc: 0.07942708333333333
# Epoch  0 Loss: 2.48701e+00 Accuracy: 0.08259 Epoch Time: 2.61837
# Epoch  1 Loss: 2.48653e+00 Accuracy: 0.07589 Epoch Time: 2.59220
# Epoch  2 Loss: 2.48587e+00 Accuracy: 0.08445 Epoch Time: 2.34916
# Epoch  3 Loss: 2.48582e+00 Accuracy: 0.07757 Epoch Time: 2.61642
# Epoch  4 Loss: 2.41847e+00 Accuracy: 0.14453 Epoch Time: 2.56526
# Epoch  5 Loss: 2.19995e+00 Accuracy: 0.21912 Epoch Time: 2.63882
# Epoch  6 Loss: 2.08690e+00 Accuracy: 0.24275 Epoch Time: 2.60812
# Epoch  7 Loss: 1.92802e+00 Accuracy: 0.27790 Epoch Time: 2.36100
# Epoch  8 Loss: 1.82088e+00 Accuracy: 0.28776 Epoch Time: 2.61038
# Epoch  9 Loss: 1.70190e+00 Accuracy: 0.32273 Epoch Time: 2.59588
# Epoch 10 Loss: 1.65188e+00 Accuracy: 0.33538 Epoch Time: 2.58284
# Epoch 11 Loss: 1.56993e+00 Accuracy: 0.36384 Epoch Time: 2.55849
# Epoch 12 Loss: 1.54871e+00 Accuracy: 0.37091 Epoch Time: 2.34565
# Epoch 13 Loss: 1.44776e+00 Accuracy: 0.40086 Epoch Time: 2.57108
# Epoch 14 Loss: 1.41707e+00 Accuracy: 0.41499 Epoch Time: 2.57082
# Epoch 15 Loss: 1.37970e+00 Accuracy: 0.43248 Epoch Time: 2.40739
# Epoch 16 Loss: 1.33315e+00 Accuracy: 0.44959 Epoch Time: 2.60014
# Epoch 17 Loss: 1.30104e+00 Accuracy: 0.46596 Epoch Time: 2.31980
# Epoch 18 Loss: 1.26800e+00 Accuracy: 0.47489 Epoch Time: 2.60448
# Epoch 19 Loss: 1.23781e+00 Accuracy: 0.49461 Epoch Time: 2.73138
# Epoch 20 Loss: 1.17319e+00 Accuracy: 0.52697 Epoch Time: 2.61659
# Epoch 21 Loss: 1.11119e+00 Accuracy: 0.55246 Epoch Time: 2.55198
# Epoch 22 Loss: 1.08560e+00 Accuracy: 0.56994 Epoch Time: 2.38436
# Epoch 23 Loss: 1.10076e+00 Accuracy: 0.56715 Epoch Time: 2.57132
# Epoch 24 Loss: 1.03318e+00 Accuracy: 0.58798 Epoch Time: 2.70551
# Epoch 25 Loss: 1.02843e+00 Accuracy: 0.59561 Epoch Time: 2.32958
# Epoch 26 Loss: 9.04612e-01 Accuracy: 0.64639 Epoch Time: 2.76999
# Epoch 27 Loss: 9.19338e-01 Accuracy: 0.63449 Epoch Time: 2.42133
# Epoch 28 Loss: 9.18300e-01 Accuracy: 0.63356 Epoch Time: 2.62637
# Epoch 29 Loss: 8.56258e-01 Accuracy: 0.65458 Epoch Time: 2.63020
# Model 2 acc: 0.6545758928571429
# "Noise Level: none | Mode: era_ensemble_lstm | Ensemble model acc: 0.7620274914089347
# Noise Level: none Mode: target_5_val
# Train-val-test lengths:  5376 1152 1164
# Epoch  0 Loss: 1.48784e+00 Accuracy: 0.24386 Epoch Time: 2.69003
# Epoch  1 Loss: 1.47578e+00 Accuracy: 0.23400 Epoch Time: 2.62172
# Epoch  2 Loss: 1.47524e+00 Accuracy: 0.24702 Epoch Time: 2.39142
# Epoch  3 Loss: 1.47379e+00 Accuracy: 0.25558 Epoch Time: 2.57738
# Epoch  4 Loss: 1.47394e+00 Accuracy: 0.24516 Epoch Time: 2.51519
# Epoch  5 Loss: 1.47482e+00 Accuracy: 0.25130 Epoch Time: 2.62943
# Epoch  6 Loss: 1.47451e+00 Accuracy: 0.24740 Epoch Time: 2.60052
# Epoch  7 Loss: 1.47423e+00 Accuracy: 0.24795 Epoch Time: 2.50647
# Epoch  8 Loss: 1.47468e+00 Accuracy: 0.24312 Epoch Time: 2.61172
# Epoch  9 Loss: 1.47408e+00 Accuracy: 0.24237 Epoch Time: 2.70030
# Epoch 10 Loss: 1.47428e+00 Accuracy: 0.24182 Epoch Time: 2.42593
# Epoch 11 Loss: 1.47396e+00 Accuracy: 0.25074 Epoch Time: 2.62300
# Epoch 12 Loss: 1.47487e+00 Accuracy: 0.23605 Epoch Time: 2.37166
# Epoch 13 Loss: 1.47372e+00 Accuracy: 0.24721 Epoch Time: 2.64774
# Epoch 14 Loss: 1.47424e+00 Accuracy: 0.24814 Epoch Time: 2.59746
# Epoch 15 Loss: 1.47408e+00 Accuracy: 0.22824 Epoch Time: 2.54932
# Epoch 16 Loss: 1.47409e+00 Accuracy: 0.24535 Epoch Time: 2.63222
# Epoch 17 Loss: 1.47402e+00 Accuracy: 0.24089 Epoch Time: 2.33447
# Epoch 18 Loss: 1.47393e+00 Accuracy: 0.24349 Epoch Time: 2.64438
# Epoch 19 Loss: 1.47374e+00 Accuracy: 0.23400 Epoch Time: 2.64358
# Epoch 20 Loss: 1.47381e+00 Accuracy: 0.24758 Epoch Time: 2.41860
# Epoch 21 Loss: 1.47434e+00 Accuracy: 0.24014 Epoch Time: 2.67384
# Epoch 22 Loss: 1.47411e+00 Accuracy: 0.24461 Epoch Time: 2.37561
# Epoch 23 Loss: 1.47410e+00 Accuracy: 0.23679 Epoch Time: 2.66148
# Epoch 24 Loss: 1.47398e+00 Accuracy: 0.24070 Epoch Time: 2.59875
# Epoch 25 Loss: 1.47412e+00 Accuracy: 0.24033 Epoch Time: 2.37343
# Epoch 26 Loss: 1.47414e+00 Accuracy: 0.23679 Epoch Time: 2.61417
# Epoch 27 Loss: 1.47384e+00 Accuracy: 0.24572 Epoch Time: 2.51890
# Epoch 28 Loss: 1.47408e+00 Accuracy: 0.23344 Epoch Time: 2.73802
# Epoch 29 Loss: 1.47301e+00 Accuracy: 0.25316 Epoch Time: 2.62296
# Model 0 acc: 0.2531622023809524
# Epoch  0 Loss: 1.48872e+00 Accuracy: 0.23270 Epoch Time: 2.42887
# Epoch  1 Loss: 1.47175e+00 Accuracy: 0.25112 Epoch Time: 2.64930
# Epoch  2 Loss: 1.46905e+00 Accuracy: 0.26004 Epoch Time: 2.44365
# Epoch  3 Loss: 1.46453e+00 Accuracy: 0.26488 Epoch Time: 2.74239
# Epoch  4 Loss: 1.45958e+00 Accuracy: 0.28330 Epoch Time: 2.57709
# Epoch  5 Loss: 1.45302e+00 Accuracy: 0.28404 Epoch Time: 2.38612
# Epoch  6 Loss: 1.40319e+00 Accuracy: 0.33464 Epoch Time: 2.61779
# Epoch  7 Loss: 1.24773e+00 Accuracy: 0.43917 Epoch Time: 2.54032
# Epoch  8 Loss: 1.13004e+00 Accuracy: 0.53404 Epoch Time: 2.62070
# Epoch  9 Loss: 1.07465e+00 Accuracy: 0.56678 Epoch Time: 2.55990
# Epoch 10 Loss: 1.00303e+00 Accuracy: 0.59821 Epoch Time: 2.49580
# Epoch 11 Loss: 9.51781e-01 Accuracy: 0.62277 Epoch Time: 2.66986
# Epoch 12 Loss: 9.13306e-01 Accuracy: 0.63560 Epoch Time: 2.66089
# Epoch 13 Loss: 8.95858e-01 Accuracy: 0.64081 Epoch Time: 2.59075
# Epoch 14 Loss: 8.49611e-01 Accuracy: 0.66146 Epoch Time: 2.60328
# Epoch 15 Loss: 8.42726e-01 Accuracy: 0.65718 Epoch Time: 2.43520
# Epoch 16 Loss: 8.14078e-01 Accuracy: 0.66797 Epoch Time: 2.69616
# Epoch 17 Loss: 7.85938e-01 Accuracy: 0.67299 Epoch Time: 2.62400
# Epoch 18 Loss: 7.92166e-01 Accuracy: 0.67299 Epoch Time: 2.44413
# Epoch 19 Loss: 7.63140e-01 Accuracy: 0.68638 Epoch Time: 2.69849
# Epoch 20 Loss: 7.32290e-01 Accuracy: 0.69568 Epoch Time: 2.48312
# Epoch 21 Loss: 7.17305e-01 Accuracy: 0.69736 Epoch Time: 2.77509
# Epoch 22 Loss: 6.91363e-01 Accuracy: 0.70647 Epoch Time: 2.57335
# Epoch 23 Loss: 6.63878e-01 Accuracy: 0.71782 Epoch Time: 2.57692
# Epoch 24 Loss: 6.52665e-01 Accuracy: 0.72396 Epoch Time: 2.70999
# Epoch 25 Loss: 6.59767e-01 Accuracy: 0.72098 Epoch Time: 2.26112
# Epoch 26 Loss: 6.26982e-01 Accuracy: 0.73940 Epoch Time: 2.67532
# Epoch 27 Loss: 6.25075e-01 Accuracy: 0.73847 Epoch Time: 2.59244
# Epoch 28 Loss: 6.30506e-01 Accuracy: 0.73568 Epoch Time: 2.48447
# Epoch 29 Loss: 5.89826e-01 Accuracy: 0.75335 Epoch Time: 2.59822
# Model 1 acc: 0.7533482142857143
# Epoch  0 Loss: 1.48392e+00 Accuracy: 0.24442 Epoch Time: 2.38723
# Epoch  1 Loss: 1.47449e+00 Accuracy: 0.25130 Epoch Time: 2.64997
# Epoch  2 Loss: 1.44211e+00 Accuracy: 0.29353 Epoch Time: 2.56730
# Epoch  3 Loss: 1.15151e+00 Accuracy: 0.53609 Epoch Time: 2.45183
# Epoch  4 Loss: 8.56721e-01 Accuracy: 0.67634 Epoch Time: 2.61357
# Epoch  5 Loss: 7.92412e-01 Accuracy: 0.69903 Epoch Time: 2.41419
# Epoch  6 Loss: 7.34006e-01 Accuracy: 0.71987 Epoch Time: 2.79187
# Epoch  7 Loss: 6.72528e-01 Accuracy: 0.74591 Epoch Time: 2.62155
# Epoch  8 Loss: 6.50008e-01 Accuracy: 0.75521 Epoch Time: 2.36367
# Epoch  9 Loss: 6.17204e-01 Accuracy: 0.76674 Epoch Time: 2.60004
# Epoch 10 Loss: 5.85979e-01 Accuracy: 0.77176 Epoch Time: 2.38026
# Epoch 11 Loss: 5.73549e-01 Accuracy: 0.77772 Epoch Time: 2.62248
# Epoch 12 Loss: 5.67598e-01 Accuracy: 0.77344 Epoch Time: 2.42204
# Epoch 13 Loss: 5.10573e-01 Accuracy: 0.79520 Epoch Time: 2.58754
# Epoch 14 Loss: 5.26308e-01 Accuracy: 0.79464 Epoch Time: 2.59434
# Epoch 15 Loss: 4.69283e-01 Accuracy: 0.80971 Epoch Time: 2.52455
# Epoch 16 Loss: 4.71777e-01 Accuracy: 0.81213 Epoch Time: 2.60749
# Epoch 17 Loss: 4.50246e-01 Accuracy: 0.82292 Epoch Time: 2.32062
# Epoch 18 Loss: 4.20450e-01 Accuracy: 0.83333 Epoch Time: 2.61130
# Epoch 19 Loss: 4.04266e-01 Accuracy: 0.84338 Epoch Time: 2.60659
# Epoch 20 Loss: 4.40263e-01 Accuracy: 0.82199 Epoch Time: 2.39806
# Epoch 21 Loss: 3.84270e-01 Accuracy: 0.84914 Epoch Time: 2.55163
# Epoch 22 Loss: 3.59384e-01 Accuracy: 0.86068 Epoch Time: 2.35466
# Epoch 23 Loss: 3.92756e-01 Accuracy: 0.84989 Epoch Time: 2.59343
# Epoch 24 Loss: 3.41578e-01 Accuracy: 0.86403 Epoch Time: 2.55762
# Epoch 25 Loss: 3.52433e-01 Accuracy: 0.85807 Epoch Time: 2.32139
# Epoch 26 Loss: 3.25439e-01 Accuracy: 0.87760 Epoch Time: 2.54657
# Epoch 27 Loss: 3.06826e-01 Accuracy: 0.88207 Epoch Time: 2.27952
# Epoch 28 Loss: 3.07183e-01 Accuracy: 0.88188 Epoch Time: 2.60620
# Epoch 29 Loss: 3.02275e-01 Accuracy: 0.88411 Epoch Time: 2.54650
# Model 2 acc: 0.8841145833333334
# "Noise Level: none | Mode: target_5_val_ensemble_lstm | Ensemble model acc: 0.8505154639175257
# Noise Level: none Mode: target_10_val
# Train-val-test lengths:  5376 1152 1164
# Epoch  0 Loss: 1.46029e+00 Accuracy: 0.23865 Epoch Time: 2.45519
# Epoch  1 Loss: 1.44852e+00 Accuracy: 0.24647 Epoch Time: 2.61367
# Epoch  2 Loss: 1.44711e+00 Accuracy: 0.25614 Epoch Time: 2.47384
# Epoch  3 Loss: 1.44820e+00 Accuracy: 0.23642 Epoch Time: 2.67287
# Epoch  4 Loss: 1.44796e+00 Accuracy: 0.24647 Epoch Time: 2.73743
# Epoch  5 Loss: 1.44683e+00 Accuracy: 0.25093 Epoch Time: 2.41609
# Epoch  6 Loss: 1.44735e+00 Accuracy: 0.24516 Epoch Time: 2.68630
# Epoch  7 Loss: 1.44771e+00 Accuracy: 0.23698 Epoch Time: 2.36035
# Epoch  8 Loss: 1.44579e+00 Accuracy: 0.25056 Epoch Time: 2.69962
# Epoch  9 Loss: 1.44652e+00 Accuracy: 0.25595 Epoch Time: 2.62491
# Epoch 10 Loss: 1.44007e+00 Accuracy: 0.27046 Epoch Time: 2.43046
# Epoch 11 Loss: 1.42128e+00 Accuracy: 0.29371 Epoch Time: 2.61322
# Epoch 12 Loss: 1.39880e+00 Accuracy: 0.32310 Epoch Time: 2.44883
# Epoch 13 Loss: 1.35036e+00 Accuracy: 0.36012 Epoch Time: 2.63098
# Epoch 14 Loss: 1.29580e+00 Accuracy: 0.41276 Epoch Time: 2.67290
# Epoch 15 Loss: 1.22390e+00 Accuracy: 0.45108 Epoch Time: 2.47700
# Epoch 16 Loss: 1.17292e+00 Accuracy: 0.48010 Epoch Time: 2.64473
# Epoch 17 Loss: 1.12727e+00 Accuracy: 0.50186 Epoch Time: 2.34144
# Epoch 18 Loss: 1.08774e+00 Accuracy: 0.53534 Epoch Time: 2.67478
# Epoch 19 Loss: 1.03290e+00 Accuracy: 0.55376 Epoch Time: 2.63246
# Epoch 20 Loss: 9.63734e-01 Accuracy: 0.59598 Epoch Time: 2.40075
# Epoch 21 Loss: 9.26608e-01 Accuracy: 0.61161 Epoch Time: 2.69261
# Epoch 22 Loss: 9.04672e-01 Accuracy: 0.61458 Epoch Time: 2.46069
# Epoch 23 Loss: 8.69667e-01 Accuracy: 0.63876 Epoch Time: 2.71416
# Epoch 24 Loss: 8.55138e-01 Accuracy: 0.63672 Epoch Time: 2.61065
# Epoch 25 Loss: 8.31275e-01 Accuracy: 0.64509 Epoch Time: 2.44077
# Epoch 26 Loss: 8.07967e-01 Accuracy: 0.65904 Epoch Time: 2.69319
# Epoch 27 Loss: 7.66200e-01 Accuracy: 0.66518 Epoch Time: 2.45300
# Epoch 28 Loss: 7.64898e-01 Accuracy: 0.67894 Epoch Time: 2.59094
# Epoch 29 Loss: 7.20544e-01 Accuracy: 0.68955 Epoch Time: 2.74047
# Model 0 acc: 0.6895461309523809
# Epoch  0 Loss: 1.46862e+00 Accuracy: 0.23865 Epoch Time: 2.62899
# Epoch  1 Loss: 1.44676e+00 Accuracy: 0.25260 Epoch Time: 2.60904
# Epoch  2 Loss: 1.44710e+00 Accuracy: 0.23977 Epoch Time: 2.34644
# Epoch  3 Loss: 1.44701e+00 Accuracy: 0.24051 Epoch Time: 2.72749
# Epoch  4 Loss: 1.44694e+00 Accuracy: 0.24330 Epoch Time: 2.54495
# Epoch  5 Loss: 1.44685e+00 Accuracy: 0.24702 Epoch Time: 2.45998
# Epoch  6 Loss: 1.44737e+00 Accuracy: 0.23847 Epoch Time: 2.65869
# Epoch  7 Loss: 1.44711e+00 Accuracy: 0.24535 Epoch Time: 2.47498
# Epoch  8 Loss: 1.44700e+00 Accuracy: 0.23810 Epoch Time: 2.63822
# Epoch  9 Loss: 1.44630e+00 Accuracy: 0.24275 Epoch Time: 2.62270
# Epoch 10 Loss: 1.44711e+00 Accuracy: 0.24014 Epoch Time: 2.33855
# Epoch 11 Loss: 1.44632e+00 Accuracy: 0.24516 Epoch Time: 2.59312
# Epoch 12 Loss: 1.44671e+00 Accuracy: 0.24795 Epoch Time: 2.44905
# Epoch 13 Loss: 1.44653e+00 Accuracy: 0.23661 Epoch Time: 2.67538
# Epoch 14 Loss: 1.44673e+00 Accuracy: 0.23977 Epoch Time: 2.82624
# Epoch 15 Loss: 1.44561e+00 Accuracy: 0.25056 Epoch Time: 2.35023
# Epoch 16 Loss: 1.44669e+00 Accuracy: 0.24126 Epoch Time: 2.65501
# Epoch 17 Loss: 1.44659e+00 Accuracy: 0.24870 Epoch Time: 2.40862
# Epoch 18 Loss: 1.44616e+00 Accuracy: 0.24814 Epoch Time: 2.65366
# Epoch 19 Loss: 1.44652e+00 Accuracy: 0.24442 Epoch Time: 2.58515
# Epoch 20 Loss: 1.44624e+00 Accuracy: 0.24498 Epoch Time: 2.43978
# Epoch 21 Loss: 1.44645e+00 Accuracy: 0.23586 Epoch Time: 2.57744
# Epoch 22 Loss: 1.44628e+00 Accuracy: 0.24777 Epoch Time: 2.37053
# Epoch 23 Loss: 1.44619e+00 Accuracy: 0.24293 Epoch Time: 2.72542
# Epoch 24 Loss: 1.44621e+00 Accuracy: 0.24479 Epoch Time: 2.69440
# Epoch 25 Loss: 1.44659e+00 Accuracy: 0.24591 Epoch Time: 2.32889
# Epoch 26 Loss: 1.44614e+00 Accuracy: 0.24740 Epoch Time: 2.62180
# Epoch 27 Loss: 1.44638e+00 Accuracy: 0.24442 Epoch Time: 2.38952
# Epoch 28 Loss: 1.44598e+00 Accuracy: 0.24423 Epoch Time: 2.59428
# Epoch 29 Loss: 1.44616e+00 Accuracy: 0.25019 Epoch Time: 2.61477
# Model 1 acc: 0.2501860119047619
# Epoch  0 Loss: 1.45985e+00 Accuracy: 0.24423 Epoch Time: 2.79137
# Epoch  1 Loss: 1.44817e+00 Accuracy: 0.24461 Epoch Time: 2.56927
# Epoch  2 Loss: 1.44772e+00 Accuracy: 0.24498 Epoch Time: 2.47724
# Epoch  3 Loss: 1.44621e+00 Accuracy: 0.25484 Epoch Time: 2.57690
# Epoch  4 Loss: 1.44319e+00 Accuracy: 0.25651 Epoch Time: 2.59943
# Epoch  5 Loss: 1.44613e+00 Accuracy: 0.25446 Epoch Time: 2.40422
# Epoch  6 Loss: 1.43687e+00 Accuracy: 0.26693 Epoch Time: 2.54266
# Epoch  7 Loss: 1.36324e+00 Accuracy: 0.36272 Epoch Time: 2.52906
# Epoch  8 Loss: 1.20956e+00 Accuracy: 0.47731 Epoch Time: 2.69282
# Epoch  9 Loss: 1.09738e+00 Accuracy: 0.51321 Epoch Time: 2.78127
# Epoch 10 Loss: 1.01247e+00 Accuracy: 0.56901 Epoch Time: 2.39076
# Epoch 11 Loss: 9.60639e-01 Accuracy: 0.59394 Epoch Time: 2.64502
# Epoch 12 Loss: 9.06464e-01 Accuracy: 0.62853 Epoch Time: 2.36140
# Epoch 13 Loss: 8.74237e-01 Accuracy: 0.64397 Epoch Time: 2.62262
# Epoch 14 Loss: 8.26433e-01 Accuracy: 0.65960 Epoch Time: 2.62572
# Epoch 15 Loss: 8.15268e-01 Accuracy: 0.66834 Epoch Time: 2.35765
# Epoch 16 Loss: 7.49558e-01 Accuracy: 0.70889 Epoch Time: 2.58376
# Epoch 17 Loss: 7.47651e-01 Accuracy: 0.70201 Epoch Time: 2.39246
# Epoch 18 Loss: 7.15149e-01 Accuracy: 0.71429 Epoch Time: 2.60068
# Epoch 19 Loss: 6.72437e-01 Accuracy: 0.73047 Epoch Time: 2.74145
# Epoch 20 Loss: 7.03643e-01 Accuracy: 0.72656 Epoch Time: 2.27467
# Epoch 21 Loss: 6.31092e-01 Accuracy: 0.75670 Epoch Time: 2.77212
# Epoch 22 Loss: 5.87858e-01 Accuracy: 0.76711 Epoch Time: 2.49266
# Epoch 23 Loss: 5.83585e-01 Accuracy: 0.76730 Epoch Time: 2.61013
# Epoch 24 Loss: 5.53760e-01 Accuracy: 0.78013 Epoch Time: 2.59950
# Epoch 25 Loss: 5.15978e-01 Accuracy: 0.79781 Epoch Time: 2.48460
# Epoch 26 Loss: 4.99992e-01 Accuracy: 0.80580 Epoch Time: 2.68657
# Epoch 27 Loss: 4.84126e-01 Accuracy: 0.80822 Epoch Time: 2.48995
# Epoch 28 Loss: 4.79484e-01 Accuracy: 0.81566 Epoch Time: 2.63069
# Epoch 29 Loss: 4.45373e-01 Accuracy: 0.82868 Epoch Time: 2.45079
# Model 2 acc: 0.8286830357142857
# "Noise Level: none | Mode: target_10_val_ensemble_lstm | Ensemble model acc: 0.6563573883161512

# %%
df_paths = ['../Datasets/df_syn_train_0_0_.csv',
            # '../Datasets/df_synA_train_shuffled.csv',
            # '../Datasets/df_synA_test_hard_shuffled_sample.csv'
            ]

# modes = ['era', 'target_5_val', 'target_10_val']
modes = ['era', 'target_5_val', 'target_10_val']
noise_levels = ['none', 'low', 'high']
epoch_num = [30, 30, 30]
batch_sizes = [16, 128, 128]

losses_arr = []
accs_arr = []

for i in range(1, 3):
    df = pd.read_csv(df_paths[i])
    df.sort_values(by=['era', 'day', 'row_num'], inplace=True)
    
    loss_per_mode = []
    acc_per_mode = []

    for j in range(len(modes)):
        mode = modes[j]
        noise_level = noise_levels[i]
        epochs = epoch_num[j]
        # lr = lrs[j]
        print("Noise Level:", noise_level, "Mode:", mode)
        loader_train, loader_val, loader_test = make_data_splits_sequential(df, mode=mode, \
                                                                       batch_size=batch_sizes[i])
        

        nets = [LSTMClassifier(26, len(df[f'{mode}'].unique())),
            LSTMClassifier(26, len(df[f'{mode}'].unique()), hidden_size= 32, num_layers= 4),
            LSTMClassifier(26, len(df[f'{mode}'].unique()), hidden_size= 64, num_layers= 3)
            ]
        
        mode += '_ensemble_lstm'
        
        for n in range(len(nets)):
            net, losses, accs, val_losses, val_accL = Train(nets[n], loader_train, mode, noise_level, \
                                      epochs=epochs, verbose=True, device=device, val_ds=loader_val, \
                                      plot_accs=True, plot_losses=True)
            plot_loss_acc(losses, accs, val_losses, val_accL, mode, noise_levels[i])
            nets[n] = net
            print(f'Model {n} acc: {accs[-1]}')

        ensemble_acc = TestEnsemble(nets, loader_test, mode, noise_level, device=device)
        print(f'"Noise Level: {noise_level} | Mode: {mode} | Ensemble model acc: {ensemble_acc}')

    # loss_per_mode.append(test_loss)
    acc_per_mode.append(ensemble_acc)

# losses_arr.append(loss_per_mode)
accs_arr.append(acc_per_mode)
# Out:
# Noise Level: low Mode: era
# Train-val-test lengths:  218316 46788 46788
# Epoch  0 Loss: 1.81446e+00 Accuracy: 0.32356 Epoch Time: 25.23212
# Epoch  1 Loss: 1.39395e+00 Accuracy: 0.44792 Epoch Time: 25.15516
# Epoch  2 Loss: 1.12076e+00 Accuracy: 0.54531 Epoch Time: 25.14329
# Epoch  3 Loss: 7.27812e-01 Accuracy: 0.69932 Epoch Time: 24.79167
# Epoch  4 Loss: 4.79485e-01 Accuracy: 0.79684 Epoch Time: 25.23117
# Epoch  5 Loss: 4.00232e-01 Accuracy: 0.82800 Epoch Time: 25.14272
# Epoch  6 Loss: 3.40778e-01 Accuracy: 0.85300 Epoch Time: 25.19660
# Epoch  7 Loss: 2.98540e-01 Accuracy: 0.87106 Epoch Time: 24.90276
# Epoch  8 Loss: 2.66553e-01 Accuracy: 0.88549 Epoch Time: 25.18156
# Epoch  9 Loss: 2.39384e-01 Accuracy: 0.89680 Epoch Time: 24.98302
# Epoch 10 Loss: 2.22211e-01 Accuracy: 0.90422 Epoch Time: 24.85665
# Epoch 11 Loss: 2.01512e-01 Accuracy: 0.91303 Epoch Time: 24.80971
# Epoch 12 Loss: 1.84422e-01 Accuracy: 0.92025 Epoch Time: 25.00451
# Epoch 13 Loss: 1.74058e-01 Accuracy: 0.92466 Epoch Time: 24.87938
# Epoch 14 Loss: 1.59697e-01 Accuracy: 0.93079 Epoch Time: 24.83084
# Epoch 15 Loss: 1.49873e-01 Accuracy: 0.93526 Epoch Time: 24.92673
# Epoch 16 Loss: 1.41635e-01 Accuracy: 0.93872 Epoch Time: 25.23738
# Epoch 17 Loss: 1.32590e-01 Accuracy: 0.94293 Epoch Time: 24.89272
# Epoch 18 Loss: 1.27714e-01 Accuracy: 0.94502 Epoch Time: 24.70197
# Epoch 19 Loss: 1.21694e-01 Accuracy: 0.94803 Epoch Time: 24.85031
# Epoch 20 Loss: 1.14759e-01 Accuracy: 0.95091 Epoch Time: 24.83461
# Epoch 21 Loss: 1.07219e-01 Accuracy: 0.95461 Epoch Time: 25.13269
# Epoch 22 Loss: 1.01306e-01 Accuracy: 0.95785 Epoch Time: 24.98889
# Epoch 23 Loss: 1.01310e-01 Accuracy: 0.95816 Epoch Time: 24.89813
# Epoch 24 Loss: 9.28765e-02 Accuracy: 0.96195 Epoch Time: 25.09916
# Epoch 25 Loss: 9.19942e-02 Accuracy: 0.96217 Epoch Time: 25.27956
# Epoch 26 Loss: 8.52448e-02 Accuracy: 0.96534 Epoch Time: 25.46645
# Epoch 27 Loss: 8.31194e-02 Accuracy: 0.96653 Epoch Time: 25.25696
# Epoch 28 Loss: 8.15084e-02 Accuracy: 0.96718 Epoch Time: 25.00501
# Epoch 29 Loss: 7.67234e-02 Accuracy: 0.96899 Epoch Time: 24.86444
# Model 0 acc: 0.9689853240257241
# Epoch  0 Loss: 2.02254e+00 Accuracy: 0.24585 Epoch Time: 24.93378
# Epoch  1 Loss: 1.55905e+00 Accuracy: 0.38432 Epoch Time: 25.30360
# Epoch  2 Loss: 1.32838e+00 Accuracy: 0.47185 Epoch Time: 25.17749
# Epoch  3 Loss: 1.09373e+00 Accuracy: 0.55972 Epoch Time: 25.63288
# Epoch  4 Loss: 8.90639e-01 Accuracy: 0.63290 Epoch Time: 25.31585
# Epoch  5 Loss: 7.76920e-01 Accuracy: 0.67991 Epoch Time: 25.35178
# Epoch  6 Loss: 6.00178e-01 Accuracy: 0.75197 Epoch Time: 25.23047
# Epoch  7 Loss: 4.85795e-01 Accuracy: 0.79536 Epoch Time: 25.53596
# Epoch  8 Loss: 4.11132e-01 Accuracy: 0.82366 Epoch Time: 25.43476
# Epoch  9 Loss: 3.75511e-01 Accuracy: 0.83836 Epoch Time: 25.38697
# Epoch 10 Loss: 3.40592e-01 Accuracy: 0.85389 Epoch Time: 25.53071
# Epoch 11 Loss: 3.21570e-01 Accuracy: 0.86148 Epoch Time: 25.45256
# Epoch 12 Loss: 2.98348e-01 Accuracy: 0.87157 Epoch Time: 25.81449
# Epoch 13 Loss: 2.81251e-01 Accuracy: 0.87967 Epoch Time: 25.51292
# Epoch 14 Loss: 2.60960e-01 Accuracy: 0.88775 Epoch Time: 25.64156
# Epoch 15 Loss: 2.51860e-01 Accuracy: 0.89173 Epoch Time: 25.65788
# Epoch 16 Loss: 2.35326e-01 Accuracy: 0.89960 Epoch Time: 25.60605
# Epoch 17 Loss: 2.20407e-01 Accuracy: 0.90569 Epoch Time: 25.51755
# Epoch 18 Loss: 2.13395e-01 Accuracy: 0.90900 Epoch Time: 25.49661
# Epoch 19 Loss: 1.96947e-01 Accuracy: 0.91645 Epoch Time: 25.58626
# Epoch 20 Loss: 1.91524e-01 Accuracy: 0.91813 Epoch Time: 25.41961
# Epoch 21 Loss: 1.78144e-01 Accuracy: 0.92393 Epoch Time: 25.27689
# Epoch 22 Loss: 1.68325e-01 Accuracy: 0.92792 Epoch Time: 25.34417
# Epoch 23 Loss: 1.60507e-01 Accuracy: 0.93121 Epoch Time: 25.29409
# Epoch 24 Loss: 1.56329e-01 Accuracy: 0.93327 Epoch Time: 25.02614
# Epoch 25 Loss: 1.50476e-01 Accuracy: 0.93581 Epoch Time: 25.17349
# Epoch 26 Loss: 1.45343e-01 Accuracy: 0.93776 Epoch Time: 25.19520
# Epoch 27 Loss: 1.37451e-01 Accuracy: 0.94186 Epoch Time: 25.23651
# Epoch 28 Loss: 1.34904e-01 Accuracy: 0.94240 Epoch Time: 25.18622
# Epoch 29 Loss: 1.28947e-01 Accuracy: 0.94579 Epoch Time: 25.25385
# Model 1 acc: 0.9457850088862017
# Epoch  0 Loss: 1.80945e+00 Accuracy: 0.32144 Epoch Time: 24.96036
# Epoch  1 Loss: 1.32564e+00 Accuracy: 0.47005 Epoch Time: 24.95658
# Epoch  2 Loss: 9.77149e-01 Accuracy: 0.59501 Epoch Time: 24.94689
# Epoch  3 Loss: 6.71593e-01 Accuracy: 0.72221 Epoch Time: 25.08869
# Epoch  4 Loss: 4.85032e-01 Accuracy: 0.79645 Epoch Time: 25.09048
# Epoch  5 Loss: 4.02167e-01 Accuracy: 0.82851 Epoch Time: 25.28632
# Epoch  6 Loss: 3.54840e-01 Accuracy: 0.84927 Epoch Time: 25.01178
# Epoch  7 Loss: 3.14871e-01 Accuracy: 0.86531 Epoch Time: 25.07949
# Epoch  8 Loss: 2.82041e-01 Accuracy: 0.87961 Epoch Time: 25.12930
# Epoch  9 Loss: 2.59541e-01 Accuracy: 0.88942 Epoch Time: 25.11421
# Epoch 10 Loss: 2.38915e-01 Accuracy: 0.89763 Epoch Time: 25.10813
# Epoch 11 Loss: 2.19171e-01 Accuracy: 0.90576 Epoch Time: 25.10468
# Epoch 12 Loss: 2.07795e-01 Accuracy: 0.91085 Epoch Time: 25.10648
# Epoch 13 Loss: 1.88621e-01 Accuracy: 0.91903 Epoch Time: 25.12060
# Epoch 14 Loss: 1.83090e-01 Accuracy: 0.92207 Epoch Time: 25.28888
# Epoch 15 Loss: 1.72435e-01 Accuracy: 0.92589 Epoch Time: 25.34833
# Epoch 16 Loss: 1.59333e-01 Accuracy: 0.93198 Epoch Time: 25.45374
# Epoch 17 Loss: 1.56501e-01 Accuracy: 0.93358 Epoch Time: 24.99544
# Epoch 18 Loss: 1.42005e-01 Accuracy: 0.94007 Epoch Time: 25.07311
# Epoch 19 Loss: 1.40793e-01 Accuracy: 0.94065 Epoch Time: 25.31255
# Epoch 20 Loss: 1.29745e-01 Accuracy: 0.94511 Epoch Time: 25.13475
# Epoch 21 Loss: 1.30165e-01 Accuracy: 0.94542 Epoch Time: 25.20739
# Epoch 22 Loss: 1.22741e-01 Accuracy: 0.94866 Epoch Time: 25.19209
# Epoch 23 Loss: 1.16557e-01 Accuracy: 0.95154 Epoch Time: 25.28073
# Epoch 24 Loss: 1.09388e-01 Accuracy: 0.95505 Epoch Time: 25.24013
# Epoch 25 Loss: 1.05154e-01 Accuracy: 0.95647 Epoch Time: 25.14332
# Epoch 26 Loss: 1.03903e-01 Accuracy: 0.95778 Epoch Time: 25.18134
# Epoch 27 Loss: 9.87835e-02 Accuracy: 0.95954 Epoch Time: 25.22072
# Epoch 28 Loss: 9.59284e-02 Accuracy: 0.96107 Epoch Time: 25.22289
# Epoch 29 Loss: 9.29854e-02 Accuracy: 0.96220 Epoch Time: 25.04714
# Model 2 acc: 0.9621969988457099
# "Noise Level: low | Mode: era_ensemble_lstm | Ensemble model acc: 0.9683252115927161
# Noise Level: low Mode: target_5_val
# Train-val-test lengths:  218316 46788 46788
# Epoch  0 Loss: 1.34386e+00 Accuracy: 0.40452 Epoch Time: 25.28769
# Epoch  1 Loss: 1.15146e+00 Accuracy: 0.51389 Epoch Time: 25.43648
# Epoch  2 Loss: 9.30227e-01 Accuracy: 0.63419 Epoch Time: 25.24739
# Epoch  3 Loss: 7.80773e-01 Accuracy: 0.69136 Epoch Time: 25.37215
# Epoch  4 Loss: 7.35778e-01 Accuracy: 0.70598 Epoch Time: 25.16863
# Epoch  5 Loss: 6.92790e-01 Accuracy: 0.72528 Epoch Time: 25.23126
# Epoch  6 Loss: 6.49270e-01 Accuracy: 0.74412 Epoch Time: 25.33960
# Epoch  7 Loss: 6.13821e-01 Accuracy: 0.75822 Epoch Time: 25.41416
# Epoch  8 Loss: 5.90931e-01 Accuracy: 0.76741 Epoch Time: 25.30709
# Epoch  9 Loss: 5.72359e-01 Accuracy: 0.77324 Epoch Time: 25.42340
# Epoch 10 Loss: 5.58263e-01 Accuracy: 0.77884 Epoch Time: 25.42205
# Epoch 11 Loss: 5.46145e-01 Accuracy: 0.78208 Epoch Time: 25.18384
# Epoch 12 Loss: 5.35451e-01 Accuracy: 0.78738 Epoch Time: 25.50818
# Epoch 13 Loss: 5.25155e-01 Accuracy: 0.79090 Epoch Time: 25.54500
# Epoch 14 Loss: 5.17925e-01 Accuracy: 0.79317 Epoch Time: 25.50446
# Epoch 15 Loss: 5.08717e-01 Accuracy: 0.79598 Epoch Time: 25.36315
# Epoch 16 Loss: 5.02189e-01 Accuracy: 0.79870 Epoch Time: 25.48748
# Epoch 17 Loss: 4.95241e-01 Accuracy: 0.80181 Epoch Time: 25.57915
# Epoch 18 Loss: 4.90452e-01 Accuracy: 0.80333 Epoch Time: 25.35593
# Epoch 19 Loss: 4.83684e-01 Accuracy: 0.80618 Epoch Time: 25.53328
# Epoch 20 Loss: 4.78915e-01 Accuracy: 0.80727 Epoch Time: 25.22564
# Epoch 21 Loss: 4.73499e-01 Accuracy: 0.80961 Epoch Time: 25.48020
# Epoch 22 Loss: 4.68309e-01 Accuracy: 0.81226 Epoch Time: 25.43459
# Epoch 23 Loss: 4.63630e-01 Accuracy: 0.81371 Epoch Time: 25.43801
# Epoch 24 Loss: 4.58618e-01 Accuracy: 0.81672 Epoch Time: 25.43178
# Epoch 25 Loss: 4.55070e-01 Accuracy: 0.81735 Epoch Time: 25.46724
# Epoch 26 Loss: 4.52473e-01 Accuracy: 0.81825 Epoch Time: 25.44876
# Epoch 27 Loss: 4.48101e-01 Accuracy: 0.82053 Epoch Time: 25.35342
# Epoch 28 Loss: 4.44084e-01 Accuracy: 0.82231 Epoch Time: 25.35380
# Epoch 29 Loss: 4.41475e-01 Accuracy: 0.82300 Epoch Time: 25.21376
# Model 0 acc: 0.8230042690412063
# Epoch  0 Loss: 1.42067e+00 Accuracy: 0.35138 Epoch Time: 25.41241
# Epoch  1 Loss: 1.24287e+00 Accuracy: 0.47026 Epoch Time: 25.31100
# Epoch  2 Loss: 1.16967e+00 Accuracy: 0.51611 Epoch Time: 25.40859
# Epoch  3 Loss: 1.09962e+00 Accuracy: 0.54608 Epoch Time: 25.23274
# Epoch  4 Loss: 1.04425e+00 Accuracy: 0.58826 Epoch Time: 25.56116
# Epoch  5 Loss: 8.99314e-01 Accuracy: 0.66167 Epoch Time: 25.25113
# Epoch  6 Loss: 8.24511e-01 Accuracy: 0.68243 Epoch Time: 25.39140
# Epoch  7 Loss: 7.92536e-01 Accuracy: 0.69271 Epoch Time: 25.52754
# Epoch  8 Loss: 7.70900e-01 Accuracy: 0.69983 Epoch Time: 25.22998
# Epoch  9 Loss: 7.52000e-01 Accuracy: 0.70672 Epoch Time: 25.26219
# Epoch 10 Loss: 7.34356e-01 Accuracy: 0.71162 Epoch Time: 25.35657
# Epoch 11 Loss: 7.16175e-01 Accuracy: 0.71719 Epoch Time: 25.21468
# Epoch 12 Loss: 7.00491e-01 Accuracy: 0.72185 Epoch Time: 25.23941
# Epoch 13 Loss: 6.81927e-01 Accuracy: 0.72865 Epoch Time: 25.21503
# Epoch 14 Loss: 6.69461e-01 Accuracy: 0.73395 Epoch Time: 25.28231
# Epoch 15 Loss: 6.54046e-01 Accuracy: 0.74046 Epoch Time: 25.37538
# Epoch 16 Loss: 6.36966e-01 Accuracy: 0.74862 Epoch Time: 25.26995
# Epoch 17 Loss: 6.22213e-01 Accuracy: 0.75493 Epoch Time: 25.19958
# Epoch 18 Loss: 6.12814e-01 Accuracy: 0.75890 Epoch Time: 25.36065
# Epoch 19 Loss: 6.00803e-01 Accuracy: 0.76409 Epoch Time: 25.15806
# Epoch 20 Loss: 5.90895e-01 Accuracy: 0.76874 Epoch Time: 25.33780
# Epoch 21 Loss: 5.82938e-01 Accuracy: 0.77146 Epoch Time: 25.46396
# Epoch 22 Loss: 5.75268e-01 Accuracy: 0.77375 Epoch Time: 25.19585
# Epoch 23 Loss: 5.70990e-01 Accuracy: 0.77684 Epoch Time: 25.49554
# Epoch 24 Loss: 5.64889e-01 Accuracy: 0.77830 Epoch Time: 25.50206
# Epoch 25 Loss: 5.60018e-01 Accuracy: 0.77996 Epoch Time: 25.48354
# Epoch 26 Loss: 5.56429e-01 Accuracy: 0.78146 Epoch Time: 25.74327
# Epoch 27 Loss: 5.50636e-01 Accuracy: 0.78393 Epoch Time: 25.32504
# Epoch 28 Loss: 5.45798e-01 Accuracy: 0.78540 Epoch Time: 25.30800
# Epoch 29 Loss: 5.42060e-01 Accuracy: 0.78706 Epoch Time: 25.45611
# Model 1 acc: 0.7870563769948149
# Epoch  0 Loss: 1.37665e+00 Accuracy: 0.37807 Epoch Time: 25.20696
# Epoch  1 Loss: 1.17794e+00 Accuracy: 0.50308 Epoch Time: 25.27903
# Epoch  2 Loss: 9.74150e-01 Accuracy: 0.62590 Epoch Time: 25.33836
# Epoch  3 Loss: 8.45494e-01 Accuracy: 0.67196 Epoch Time: 25.19235
# Epoch  4 Loss: 7.97517e-01 Accuracy: 0.69001 Epoch Time: 25.15680
# Epoch  5 Loss: 7.61318e-01 Accuracy: 0.70268 Epoch Time: 25.59115
# Epoch  6 Loss: 7.21279e-01 Accuracy: 0.71868 Epoch Time: 25.45037
# Epoch  7 Loss: 6.74146e-01 Accuracy: 0.73770 Epoch Time: 25.09456
# Epoch  8 Loss: 6.33781e-01 Accuracy: 0.75273 Epoch Time: 24.99893
# Epoch  9 Loss: 6.05813e-01 Accuracy: 0.76262 Epoch Time: 25.04788
# Epoch 10 Loss: 5.84724e-01 Accuracy: 0.76972 Epoch Time: 25.05176
# Epoch 11 Loss: 5.67269e-01 Accuracy: 0.77573 Epoch Time: 24.71793
# Epoch 12 Loss: 5.53545e-01 Accuracy: 0.78107 Epoch Time: 24.60086
# Epoch 13 Loss: 5.41876e-01 Accuracy: 0.78567 Epoch Time: 24.53391
# Epoch 14 Loss: 5.29767e-01 Accuracy: 0.78995 Epoch Time: 24.57944
# Epoch 15 Loss: 5.21839e-01 Accuracy: 0.79309 Epoch Time: 24.56367
# Epoch 16 Loss: 5.12937e-01 Accuracy: 0.79549 Epoch Time: 24.47549
# Epoch 17 Loss: 5.07584e-01 Accuracy: 0.79688 Epoch Time: 24.20955
# Epoch 18 Loss: 5.02569e-01 Accuracy: 0.79944 Epoch Time: 24.04426
# Epoch 19 Loss: 4.97553e-01 Accuracy: 0.80095 Epoch Time: 23.98424
# Epoch 20 Loss: 4.92278e-01 Accuracy: 0.80303 Epoch Time: 24.14363
# Epoch 21 Loss: 4.87773e-01 Accuracy: 0.80426 Epoch Time: 24.08267
# Epoch 22 Loss: 4.82750e-01 Accuracy: 0.80659 Epoch Time: 24.30977
# Epoch 23 Loss: 4.78700e-01 Accuracy: 0.80824 Epoch Time: 24.29246
# Epoch 24 Loss: 4.76245e-01 Accuracy: 0.80914 Epoch Time: 24.01731
# Epoch 25 Loss: 4.71696e-01 Accuracy: 0.81129 Epoch Time: 24.09858
# Epoch 26 Loss: 4.68862e-01 Accuracy: 0.81234 Epoch Time: 24.02660
# Epoch 27 Loss: 4.65826e-01 Accuracy: 0.81344 Epoch Time: 24.26264
# Epoch 28 Loss: 4.63872e-01 Accuracy: 0.81414 Epoch Time: 24.13787
# Epoch 29 Loss: 4.59795e-01 Accuracy: 0.81554 Epoch Time: 24.07002
# Model 2 acc: 0.8155426079627696
# "Noise Level: low | Mode: target_5_val_ensemble_lstm | Ensemble model acc: 0.8141831238779175
# Noise Level: low Mode: target_10_val
# Train-val-test lengths:  218316 46788 46788
# Epoch  0 Loss: 1.44396e+00 Accuracy: 0.26839 Epoch Time: 24.56831
# Epoch  1 Loss: 1.30688e+00 Accuracy: 0.40350 Epoch Time: 24.51943
# Epoch  2 Loss: 9.20829e-01 Accuracy: 0.67580 Epoch Time: 24.87068
# Epoch  3 Loss: 7.43604e-01 Accuracy: 0.72205 Epoch Time: 24.56628
# Epoch  4 Loss: 6.58285e-01 Accuracy: 0.75285 Epoch Time: 24.47991
# Epoch  5 Loss: 5.95586e-01 Accuracy: 0.77576 Epoch Time: 24.56636
# Epoch  6 Loss: 5.41088e-01 Accuracy: 0.79557 Epoch Time: 24.93281
# Epoch  7 Loss: 4.98018e-01 Accuracy: 0.81024 Epoch Time: 24.51800
# Epoch  8 Loss: 4.67684e-01 Accuracy: 0.82037 Epoch Time: 24.65349
# Epoch  9 Loss: 4.50172e-01 Accuracy: 0.82734 Epoch Time: 24.51103
# Epoch 10 Loss: 4.34634e-01 Accuracy: 0.83217 Epoch Time: 24.72651
# Epoch 11 Loss: 4.24095e-01 Accuracy: 0.83570 Epoch Time: 24.49922
# Epoch 12 Loss: 4.12727e-01 Accuracy: 0.83986 Epoch Time: 24.62991
# Epoch 13 Loss: 4.08545e-01 Accuracy: 0.84137 Epoch Time: 25.00266
# Epoch 14 Loss: 3.99919e-01 Accuracy: 0.84454 Epoch Time: 25.40564
# Epoch 15 Loss: 3.94550e-01 Accuracy: 0.84605 Epoch Time: 25.42487
# Epoch 16 Loss: 3.88040e-01 Accuracy: 0.84839 Epoch Time: 25.26308
# Epoch 17 Loss: 3.84228e-01 Accuracy: 0.85029 Epoch Time: 25.51575
# Epoch 18 Loss: 3.80161e-01 Accuracy: 0.85195 Epoch Time: 25.32618
# Epoch 19 Loss: 3.75396e-01 Accuracy: 0.85317 Epoch Time: 25.00928
# Epoch 20 Loss: 3.68562e-01 Accuracy: 0.85612 Epoch Time: 24.98719
# Epoch 21 Loss: 3.66791e-01 Accuracy: 0.85651 Epoch Time: 25.26151
# Epoch 22 Loss: 3.62071e-01 Accuracy: 0.85791 Epoch Time: 25.18110
# Epoch 23 Loss: 3.60188e-01 Accuracy: 0.85946 Epoch Time: 25.26310
# Epoch 24 Loss: 3.56799e-01 Accuracy: 0.86061 Epoch Time: 25.28601
# Epoch 25 Loss: 3.52812e-01 Accuracy: 0.86226 Epoch Time: 25.20090
# Epoch 26 Loss: 3.51687e-01 Accuracy: 0.86235 Epoch Time: 25.16210
# Epoch 27 Loss: 3.48122e-01 Accuracy: 0.86427 Epoch Time: 25.34198
# Epoch 28 Loss: 3.44499e-01 Accuracy: 0.86481 Epoch Time: 25.50555
# Epoch 29 Loss: 3.43838e-01 Accuracy: 0.86588 Epoch Time: 25.33456
# Model 0 acc: 0.865877901757086
# Epoch  0 Loss: 1.33246e+00 Accuracy: 0.38067 Epoch Time: 25.13722
# Epoch  1 Loss: 1.09255e+00 Accuracy: 0.55296 Epoch Time: 25.14181
# Epoch  2 Loss: 9.96703e-01 Accuracy: 0.59407 Epoch Time: 25.02676
# Epoch  3 Loss: 9.24182e-01 Accuracy: 0.65335 Epoch Time: 25.04133
# Epoch  4 Loss: 8.20310e-01 Accuracy: 0.71004 Epoch Time: 25.00999
# Epoch  5 Loss: 7.54127e-01 Accuracy: 0.73094 Epoch Time: 24.92658
# Epoch  6 Loss: 6.99679e-01 Accuracy: 0.74768 Epoch Time: 25.04215
# Epoch  7 Loss: 6.57504e-01 Accuracy: 0.75710 Epoch Time: 25.15702
# Epoch  8 Loss: 6.27477e-01 Accuracy: 0.76500 Epoch Time: 24.90591
# Epoch  9 Loss: 6.01741e-01 Accuracy: 0.77295 Epoch Time: 25.02089
# Epoch 10 Loss: 5.81565e-01 Accuracy: 0.77903 Epoch Time: 25.01908
# Epoch 11 Loss: 5.62574e-01 Accuracy: 0.78550 Epoch Time: 25.06216
# Epoch 12 Loss: 5.49029e-01 Accuracy: 0.79046 Epoch Time: 25.35055
# Epoch 13 Loss: 5.32652e-01 Accuracy: 0.79657 Epoch Time: 25.09800
# Epoch 14 Loss: 5.15993e-01 Accuracy: 0.80352 Epoch Time: 25.23864
# Epoch 15 Loss: 5.02055e-01 Accuracy: 0.80804 Epoch Time: 25.06773
# Epoch 16 Loss: 4.87199e-01 Accuracy: 0.81384 Epoch Time: 24.90076
# Epoch 17 Loss: 4.78381e-01 Accuracy: 0.81693 Epoch Time: 24.97172
# Epoch 18 Loss: 4.68218e-01 Accuracy: 0.81957 Epoch Time: 25.12697
# Epoch 19 Loss: 4.62122e-01 Accuracy: 0.82254 Epoch Time: 25.10093
# Epoch 20 Loss: 4.53774e-01 Accuracy: 0.82526 Epoch Time: 25.24246
# Epoch 21 Loss: 4.50968e-01 Accuracy: 0.82652 Epoch Time: 25.15096
# Epoch 22 Loss: 4.45403e-01 Accuracy: 0.82851 Epoch Time: 25.14608
# Epoch 23 Loss: 4.40342e-01 Accuracy: 0.82972 Epoch Time: 25.04024
# Epoch 24 Loss: 4.36349e-01 Accuracy: 0.83193 Epoch Time: 25.18543
# Epoch 25 Loss: 4.31731e-01 Accuracy: 0.83382 Epoch Time: 25.06680
# Epoch 26 Loss: 4.29149e-01 Accuracy: 0.83495 Epoch Time: 25.20961
# Epoch 27 Loss: 4.23752e-01 Accuracy: 0.83614 Epoch Time: 24.93828
# Epoch 28 Loss: 4.20726e-01 Accuracy: 0.83740 Epoch Time: 24.84428
# Epoch 29 Loss: 4.17650e-01 Accuracy: 0.83873 Epoch Time: 25.19394
# Model 1 acc: 0.8387337620696604
# Epoch  0 Loss: 1.29445e+00 Accuracy: 0.41671 Epoch Time: 24.69233
# Epoch  1 Loss: 1.01882e+00 Accuracy: 0.62913 Epoch Time: 24.88165
# Epoch  2 Loss: 8.70008e-01 Accuracy: 0.69329 Epoch Time: 24.77162
# Epoch  3 Loss: 7.66248e-01 Accuracy: 0.72277 Epoch Time: 25.01464
# Epoch  4 Loss: 6.96345e-01 Accuracy: 0.74306 Epoch Time: 24.91213
# Epoch  5 Loss: 6.54518e-01 Accuracy: 0.75682 Epoch Time: 24.84933
# Epoch  6 Loss: 6.14448e-01 Accuracy: 0.77061 Epoch Time: 24.81422
# Epoch  7 Loss: 5.75456e-01 Accuracy: 0.78410 Epoch Time: 24.76263
# Epoch  8 Loss: 5.38193e-01 Accuracy: 0.79699 Epoch Time: 24.48957
# Epoch  9 Loss: 5.04312e-01 Accuracy: 0.80792 Epoch Time: 24.76863
# Epoch 10 Loss: 4.81930e-01 Accuracy: 0.81538 Epoch Time: 24.48154
# Epoch 11 Loss: 4.65306e-01 Accuracy: 0.82105 Epoch Time: 24.61348
# Epoch 12 Loss: 4.51949e-01 Accuracy: 0.82628 Epoch Time: 24.60405
# Epoch 13 Loss: 4.40994e-01 Accuracy: 0.83024 Epoch Time: 24.98161
# Epoch 14 Loss: 4.31471e-01 Accuracy: 0.83356 Epoch Time: 24.87179
# Epoch 15 Loss: 4.24726e-01 Accuracy: 0.83563 Epoch Time: 24.81311
# Epoch 16 Loss: 4.18070e-01 Accuracy: 0.83893 Epoch Time: 24.83463
# Epoch 17 Loss: 4.11852e-01 Accuracy: 0.84093 Epoch Time: 24.60193
# Epoch 18 Loss: 4.05554e-01 Accuracy: 0.84350 Epoch Time: 24.59701
# Epoch 19 Loss: 4.00356e-01 Accuracy: 0.84477 Epoch Time: 24.83063
# Epoch 20 Loss: 3.96709e-01 Accuracy: 0.84623 Epoch Time: 24.95588
# Epoch 21 Loss: 3.93462e-01 Accuracy: 0.84786 Epoch Time: 24.61004
# Epoch 22 Loss: 3.87023e-01 Accuracy: 0.84996 Epoch Time: 24.72249
# Epoch 23 Loss: 3.85286e-01 Accuracy: 0.85068 Epoch Time: 24.61018
# Epoch 24 Loss: 3.81820e-01 Accuracy: 0.85199 Epoch Time: 24.67751
# Epoch 25 Loss: 3.78705e-01 Accuracy: 0.85332 Epoch Time: 24.75200
# Epoch 26 Loss: 3.75092e-01 Accuracy: 0.85403 Epoch Time: 24.60617
# Epoch 27 Loss: 3.72127e-01 Accuracy: 0.85471 Epoch Time: 24.58349
# Epoch 28 Loss: 3.69381e-01 Accuracy: 0.85608 Epoch Time: 24.90661
# Epoch 29 Loss: 3.73259e-01 Accuracy: 0.85554 Epoch Time: 24.55415
# Model 2 acc: 0.8555350959160116
# "Noise Level: low | Mode: target_10_val_ensemble_lstm | Ensemble model acc: 0.857313841155852
# Noise Level: high Mode: era
# Train-val-test lengths:  174640 37422 37430
# Epoch  0 Loss: 2.19457e+00 Accuracy: 0.19721 Epoch Time: 20.41819
# Epoch  1 Loss: 1.82751e+00 Accuracy: 0.31338 Epoch Time: 20.51920
# Epoch  2 Loss: 1.42147e+00 Accuracy: 0.45744 Epoch Time: 20.38382
# Epoch  3 Loss: 1.08125e+00 Accuracy: 0.57055 Epoch Time: 20.08620
# Epoch  4 Loss: 8.61930e-01 Accuracy: 0.64754 Epoch Time: 20.23155
# Epoch  5 Loss: 7.42477e-01 Accuracy: 0.69201 Epoch Time: 20.07945
# Epoch  6 Loss: 6.56745e-01 Accuracy: 0.72769 Epoch Time: 20.12726
# Epoch  7 Loss: 5.69085e-01 Accuracy: 0.76503 Epoch Time: 20.05280
# Epoch  8 Loss: 4.89015e-01 Accuracy: 0.79737 Epoch Time: 20.36073
# Epoch  9 Loss: 4.28058e-01 Accuracy: 0.82298 Epoch Time: 20.08442
# Epoch 10 Loss: 3.86228e-01 Accuracy: 0.83919 Epoch Time: 20.09901
# Epoch 11 Loss: 3.53461e-01 Accuracy: 0.85223 Epoch Time: 20.08358
# Epoch 12 Loss: 3.25414e-01 Accuracy: 0.86544 Epoch Time: 20.10319
# Epoch 13 Loss: 3.10519e-01 Accuracy: 0.87155 Epoch Time: 20.29830
# Epoch 14 Loss: 2.94683e-01 Accuracy: 0.87770 Epoch Time: 20.11685
# Epoch 15 Loss: 2.74229e-01 Accuracy: 0.88684 Epoch Time: 20.26127
# Epoch 16 Loss: 2.57602e-01 Accuracy: 0.89337 Epoch Time: 20.26408
# Epoch 17 Loss: 2.47403e-01 Accuracy: 0.89865 Epoch Time: 20.09567
# Epoch 18 Loss: 2.34587e-01 Accuracy: 0.90357 Epoch Time: 20.11568
# Epoch 19 Loss: 2.23231e-01 Accuracy: 0.90814 Epoch Time: 20.15727
# Epoch 20 Loss: 2.11010e-01 Accuracy: 0.91286 Epoch Time: 20.19955
# Epoch 21 Loss: 1.99458e-01 Accuracy: 0.91896 Epoch Time: 20.03278
# Epoch 22 Loss: 1.90641e-01 Accuracy: 0.92221 Epoch Time: 20.22830
# Epoch 23 Loss: 1.87205e-01 Accuracy: 0.92349 Epoch Time: 20.13454
# Epoch 24 Loss: 1.73919e-01 Accuracy: 0.92858 Epoch Time: 20.22419
# Epoch 25 Loss: 1.66464e-01 Accuracy: 0.93300 Epoch Time: 20.23302
# Epoch 26 Loss: 1.64996e-01 Accuracy: 0.93378 Epoch Time: 20.57997
# Epoch 27 Loss: 1.55198e-01 Accuracy: 0.93814 Epoch Time: 20.44667
# Epoch 28 Loss: 1.46681e-01 Accuracy: 0.94146 Epoch Time: 20.47954
# Epoch 29 Loss: 1.40800e-01 Accuracy: 0.94423 Epoch Time: 20.21365
# Model 0 acc: 0.9442338524965643
# Epoch  0 Loss: 2.28004e+00 Accuracy: 0.16541 Epoch Time: 20.20981
# Epoch  1 Loss: 1.89921e+00 Accuracy: 0.28502 Epoch Time: 20.10115
# Epoch  2 Loss: 1.69596e+00 Accuracy: 0.35350 Epoch Time: 20.14374
# Epoch  3 Loss: 1.47775e+00 Accuracy: 0.42527 Epoch Time: 20.24265
# Epoch  4 Loss: 1.26370e+00 Accuracy: 0.49880 Epoch Time: 20.11976
# Epoch  5 Loss: 1.08385e+00 Accuracy: 0.56202 Epoch Time: 20.11151
# Epoch  6 Loss: 9.67707e-01 Accuracy: 0.60345 Epoch Time: 20.12420
# Epoch  7 Loss: 8.87584e-01 Accuracy: 0.63590 Epoch Time: 20.14227
# Epoch  8 Loss: 8.13236e-01 Accuracy: 0.66592 Epoch Time: 20.05387
# Epoch  9 Loss: 7.58622e-01 Accuracy: 0.68897 Epoch Time: 20.15482
# Epoch 10 Loss: 6.97582e-01 Accuracy: 0.71477 Epoch Time: 19.96805
# Epoch 11 Loss: 6.49639e-01 Accuracy: 0.73506 Epoch Time: 19.75023
# Epoch 12 Loss: 5.94454e-01 Accuracy: 0.75819 Epoch Time: 19.98621
# Epoch 13 Loss: 5.54066e-01 Accuracy: 0.77516 Epoch Time: 19.96290
# Epoch 14 Loss: 5.21295e-01 Accuracy: 0.78874 Epoch Time: 19.87562
# Epoch 15 Loss: 4.92718e-01 Accuracy: 0.79987 Epoch Time: 20.28296
# Epoch 16 Loss: 4.69689e-01 Accuracy: 0.80827 Epoch Time: 19.92434
# Epoch 17 Loss: 4.37937e-01 Accuracy: 0.82102 Epoch Time: 19.85724
# Epoch 18 Loss: 4.21208e-01 Accuracy: 0.82886 Epoch Time: 19.97435
# Epoch 19 Loss: 4.09623e-01 Accuracy: 0.83232 Epoch Time: 19.80879
# Epoch 20 Loss: 3.88002e-01 Accuracy: 0.84125 Epoch Time: 20.12156
# Epoch 21 Loss: 3.76190e-01 Accuracy: 0.84630 Epoch Time: 19.95254
# Epoch 22 Loss: 3.63327e-01 Accuracy: 0.85100 Epoch Time: 20.06944
# Epoch 23 Loss: 3.49408e-01 Accuracy: 0.85681 Epoch Time: 20.07628
# Epoch 24 Loss: 3.36491e-01 Accuracy: 0.86189 Epoch Time: 19.99201
# Epoch 25 Loss: 3.30755e-01 Accuracy: 0.86461 Epoch Time: 20.00760
# Epoch 26 Loss: 3.22828e-01 Accuracy: 0.86789 Epoch Time: 19.82123
# Epoch 27 Loss: 3.09265e-01 Accuracy: 0.87335 Epoch Time: 19.89315
# Epoch 28 Loss: 3.03568e-01 Accuracy: 0.87525 Epoch Time: 19.99478
# Epoch 29 Loss: 2.99547e-01 Accuracy: 0.87712 Epoch Time: 19.98651
# Model 1 acc: 0.8771186440677966
# Epoch  0 Loss: 2.14963e+00 Accuracy: 0.21641 Epoch Time: 19.73483
# Epoch  1 Loss: 1.84769e+00 Accuracy: 0.30630 Epoch Time: 19.63081
# Epoch  2 Loss: 1.45442e+00 Accuracy: 0.44038 Epoch Time: 19.21738
# Epoch  3 Loss: 1.09536e+00 Accuracy: 0.56178 Epoch Time: 19.36080
# Epoch  4 Loss: 8.97013e-01 Accuracy: 0.63569 Epoch Time: 19.19590
# Epoch  5 Loss: 7.59686e-01 Accuracy: 0.68721 Epoch Time: 19.30714
# Epoch  6 Loss: 6.58095e-01 Accuracy: 0.72892 Epoch Time: 19.42919
# Epoch  7 Loss: 5.72701e-01 Accuracy: 0.76381 Epoch Time: 19.30128
# Epoch  8 Loss: 5.22396e-01 Accuracy: 0.78357 Epoch Time: 19.17979
# Epoch  9 Loss: 4.77081e-01 Accuracy: 0.80236 Epoch Time: 19.23158
# Epoch 10 Loss: 4.29256e-01 Accuracy: 0.82275 Epoch Time: 19.36889
# Epoch 11 Loss: 4.06837e-01 Accuracy: 0.83137 Epoch Time: 19.29093
# Epoch 12 Loss: 3.79365e-01 Accuracy: 0.84407 Epoch Time: 19.35018
# Epoch 13 Loss: 3.53476e-01 Accuracy: 0.85500 Epoch Time: 19.32764
# Epoch 14 Loss: 3.36345e-01 Accuracy: 0.86174 Epoch Time: 19.30710
# Epoch 15 Loss: 3.21016e-01 Accuracy: 0.86825 Epoch Time: 19.25598
# Epoch 16 Loss: 2.98714e-01 Accuracy: 0.87643 Epoch Time: 19.26544
# Epoch 17 Loss: 2.87212e-01 Accuracy: 0.88198 Epoch Time: 19.42043
# Epoch 18 Loss: 2.77624e-01 Accuracy: 0.88543 Epoch Time: 19.34388
# Epoch 19 Loss: 2.63066e-01 Accuracy: 0.89168 Epoch Time: 19.38766
# Epoch 20 Loss: 2.55403e-01 Accuracy: 0.89406 Epoch Time: 19.29007
# Epoch 21 Loss: 2.39750e-01 Accuracy: 0.90079 Epoch Time: 19.25070
# Epoch 22 Loss: 2.30288e-01 Accuracy: 0.90522 Epoch Time: 19.39282
# Epoch 23 Loss: 2.24082e-01 Accuracy: 0.90770 Epoch Time: 19.32799
# Epoch 24 Loss: 2.14617e-01 Accuracy: 0.91126 Epoch Time: 19.29405
# Epoch 25 Loss: 2.08343e-01 Accuracy: 0.91366 Epoch Time: 19.41742
# Epoch 26 Loss: 2.02185e-01 Accuracy: 0.91703 Epoch Time: 19.28148
# Epoch 27 Loss: 1.91458e-01 Accuracy: 0.92128 Epoch Time: 19.19150
# Epoch 28 Loss: 1.84974e-01 Accuracy: 0.92398 Epoch Time: 19.38923
# Epoch 29 Loss: 1.81555e-01 Accuracy: 0.92541 Epoch Time: 19.29040
# Model 2 acc: 0.925406550618415
# "Noise Level: high | Mode: era_ensemble_lstm | Ensemble model acc: 0.9305102858669516
# Noise Level: high Mode: target_5_val
# Train-val-test lengths:  174640 37422 37430
# Epoch  0 Loss: 1.48982e+00 Accuracy: 0.23945 Epoch Time: 19.61007
# Epoch  1 Loss: 1.48782e+00 Accuracy: 0.24497 Epoch Time: 19.74710
# Epoch  2 Loss: 1.43424e+00 Accuracy: 0.34229 Epoch Time: 19.74972
# Epoch  3 Loss: 1.32146e+00 Accuracy: 0.44369 Epoch Time: 19.60366
# Epoch  4 Loss: 1.23479e+00 Accuracy: 0.46954 Epoch Time: 19.70777
# Epoch  5 Loss: 1.18608e+00 Accuracy: 0.48854 Epoch Time: 19.75902
# Epoch  6 Loss: 1.14637e+00 Accuracy: 0.50917 Epoch Time: 19.63267
# Epoch  7 Loss: 1.12066e+00 Accuracy: 0.51992 Epoch Time: 19.62957
# Epoch  8 Loss: 1.09356e+00 Accuracy: 0.53294 Epoch Time: 19.75941
# Epoch  9 Loss: 1.05166e+00 Accuracy: 0.55586 Epoch Time: 19.75745
# Epoch 10 Loss: 1.00428e+00 Accuracy: 0.57753 Epoch Time: 19.77150
# Epoch 11 Loss: 9.77915e-01 Accuracy: 0.58945 Epoch Time: 20.00803
# Epoch 12 Loss: 9.60839e-01 Accuracy: 0.59646 Epoch Time: 19.97360
# Epoch 13 Loss: 9.46475e-01 Accuracy: 0.60217 Epoch Time: 20.20478
# Epoch 14 Loss: 9.34705e-01 Accuracy: 0.60860 Epoch Time: 20.19538
# Epoch 15 Loss: 9.25400e-01 Accuracy: 0.61176 Epoch Time: 20.15527
# Epoch 16 Loss: 9.17981e-01 Accuracy: 0.61564 Epoch Time: 20.20335
# Epoch 17 Loss: 9.11266e-01 Accuracy: 0.61765 Epoch Time: 20.20000
# Epoch 18 Loss: 9.04871e-01 Accuracy: 0.61987 Epoch Time: 20.12721
# Epoch 19 Loss: 8.99131e-01 Accuracy: 0.62189 Epoch Time: 20.16600
# Epoch 20 Loss: 8.93879e-01 Accuracy: 0.62435 Epoch Time: 20.09160
# Epoch 21 Loss: 8.91651e-01 Accuracy: 0.62394 Epoch Time: 20.10930
# Epoch 22 Loss: 8.87966e-01 Accuracy: 0.62619 Epoch Time: 19.99618
# Epoch 23 Loss: 8.81677e-01 Accuracy: 0.62921 Epoch Time: 20.02051
# Epoch 24 Loss: 8.77707e-01 Accuracy: 0.63077 Epoch Time: 20.03824
# Epoch 25 Loss: 8.74815e-01 Accuracy: 0.63145 Epoch Time: 20.08592
# Epoch 26 Loss: 8.72030e-01 Accuracy: 0.63188 Epoch Time: 20.05529
# Epoch 27 Loss: 8.68996e-01 Accuracy: 0.63446 Epoch Time: 20.24134
# Epoch 28 Loss: 8.64017e-01 Accuracy: 0.63669 Epoch Time: 20.09103
# Epoch 29 Loss: 8.62137e-01 Accuracy: 0.63599 Epoch Time: 20.13607
# Model 0 acc: 0.63599404489235
# Epoch  0 Loss: 1.49070e+00 Accuracy: 0.24289 Epoch Time: 20.15841
# Epoch  1 Loss: 1.48748e+00 Accuracy: 0.24500 Epoch Time: 20.06054
# Epoch  2 Loss: 1.43542e+00 Accuracy: 0.34753 Epoch Time: 20.11782
# Epoch  3 Loss: 1.32303e+00 Accuracy: 0.44350 Epoch Time: 20.10580
# Epoch  4 Loss: 1.27941e+00 Accuracy: 0.45829 Epoch Time: 19.94235
# Epoch  5 Loss: 1.25103e+00 Accuracy: 0.46642 Epoch Time: 20.04501
# Epoch  6 Loss: 1.22098e+00 Accuracy: 0.47371 Epoch Time: 20.12472
# Epoch  7 Loss: 1.19483e+00 Accuracy: 0.48508 Epoch Time: 20.26128
# Epoch  8 Loss: 1.16924e+00 Accuracy: 0.50193 Epoch Time: 20.03138
# Epoch  9 Loss: 1.14691e+00 Accuracy: 0.51340 Epoch Time: 20.24201
# Epoch 10 Loss: 1.12637e+00 Accuracy: 0.52254 Epoch Time: 20.00842
# Epoch 11 Loss: 1.11025e+00 Accuracy: 0.52998 Epoch Time: 19.94061
# Epoch 12 Loss: 1.09188e+00 Accuracy: 0.53813 Epoch Time: 19.97808
# Epoch 13 Loss: 1.07653e+00 Accuracy: 0.54528 Epoch Time: 20.05936
# Epoch 14 Loss: 1.06038e+00 Accuracy: 0.55271 Epoch Time: 19.96469
# Epoch 15 Loss: 1.04046e+00 Accuracy: 0.56373 Epoch Time: 20.40453
# Epoch 16 Loss: 1.01664e+00 Accuracy: 0.57513 Epoch Time: 20.13615
# Epoch 17 Loss: 1.00180e+00 Accuracy: 0.58037 Epoch Time: 19.93401
# Epoch 18 Loss: 9.88360e-01 Accuracy: 0.58662 Epoch Time: 20.11184
# Epoch 19 Loss: 9.78863e-01 Accuracy: 0.59036 Epoch Time: 20.16120
# Epoch 20 Loss: 9.71562e-01 Accuracy: 0.59331 Epoch Time: 20.14356
# Epoch 21 Loss: 9.63486e-01 Accuracy: 0.59746 Epoch Time: 20.20705
# Epoch 22 Loss: 9.58428e-01 Accuracy: 0.59881 Epoch Time: 19.93864
# Epoch 23 Loss: 9.51708e-01 Accuracy: 0.60096 Epoch Time: 20.12606
# Epoch 24 Loss: 9.46674e-01 Accuracy: 0.60290 Epoch Time: 19.95515
# Epoch 25 Loss: 9.42228e-01 Accuracy: 0.60532 Epoch Time: 20.11468
# Epoch 26 Loss: 9.38323e-01 Accuracy: 0.60596 Epoch Time: 20.11575
# Epoch 27 Loss: 9.34315e-01 Accuracy: 0.60838 Epoch Time: 19.91830
# Epoch 28 Loss: 9.30954e-01 Accuracy: 0.60902 Epoch Time: 20.05482
# Epoch 29 Loss: 9.26609e-01 Accuracy: 0.61078 Epoch Time: 20.03104
# Model 1 acc: 0.6107764544205222
# Epoch  0 Loss: 1.48944e+00 Accuracy: 0.24460 Epoch Time: 19.69130
# Epoch  1 Loss: 1.37550e+00 Accuracy: 0.41339 Epoch Time: 19.85297
# Epoch  2 Loss: 1.30970e+00 Accuracy: 0.44887 Epoch Time: 19.84726
# Epoch  3 Loss: 1.24398e+00 Accuracy: 0.47031 Epoch Time: 19.70477
# Epoch  4 Loss: 1.21224e+00 Accuracy: 0.48041 Epoch Time: 19.85395
# Epoch  5 Loss: 1.18689e+00 Accuracy: 0.49063 Epoch Time: 19.67557
# Epoch  6 Loss: 1.16320e+00 Accuracy: 0.50065 Epoch Time: 19.81785
# Epoch  7 Loss: 1.13829e+00 Accuracy: 0.51332 Epoch Time: 19.77302
# Epoch  8 Loss: 1.11144e+00 Accuracy: 0.52589 Epoch Time: 19.94164
# Epoch  9 Loss: 1.08711e+00 Accuracy: 0.53674 Epoch Time: 19.61209
# Epoch 10 Loss: 1.05849e+00 Accuracy: 0.55140 Epoch Time: 19.79184
# Epoch 11 Loss: 1.02446e+00 Accuracy: 0.56829 Epoch Time: 20.05937
# Epoch 12 Loss: 9.93563e-01 Accuracy: 0.58187 Epoch Time: 19.65280
# Epoch 13 Loss: 9.74719e-01 Accuracy: 0.59225 Epoch Time: 19.70071
# Epoch 14 Loss: 9.59150e-01 Accuracy: 0.59861 Epoch Time: 19.95673
# Epoch 15 Loss: 9.49142e-01 Accuracy: 0.60253 Epoch Time: 19.71133
# Epoch 16 Loss: 9.38309e-01 Accuracy: 0.60657 Epoch Time: 19.78054
# Epoch 17 Loss: 9.30289e-01 Accuracy: 0.61008 Epoch Time: 19.83937
# Epoch 18 Loss: 9.21217e-01 Accuracy: 0.61259 Epoch Time: 19.66586
# Epoch 19 Loss: 9.12293e-01 Accuracy: 0.61631 Epoch Time: 19.93378
# Epoch 20 Loss: 9.07695e-01 Accuracy: 0.61845 Epoch Time: 19.61236
# Epoch 21 Loss: 9.00064e-01 Accuracy: 0.62235 Epoch Time: 19.82365
# Epoch 22 Loss: 8.94868e-01 Accuracy: 0.62365 Epoch Time: 19.76403
# Epoch 23 Loss: 8.89397e-01 Accuracy: 0.62580 Epoch Time: 19.85247
# Epoch 24 Loss: 8.83575e-01 Accuracy: 0.62808 Epoch Time: 19.77181
# Epoch 25 Loss: 8.80694e-01 Accuracy: 0.62920 Epoch Time: 19.80873
# Epoch 26 Loss: 8.74649e-01 Accuracy: 0.63108 Epoch Time: 19.85744
# Epoch 27 Loss: 8.71452e-01 Accuracy: 0.63267 Epoch Time: 19.65974
# Epoch 28 Loss: 8.68040e-01 Accuracy: 0.63452 Epoch Time: 19.71977
# Epoch 29 Loss: 8.65361e-01 Accuracy: 0.63462 Epoch Time: 19.71232
# Model 2 acc: 0.6346197892808062
# "Noise Level: high | Mode: target_5_val_ensemble_lstm | Ensemble model acc: 0.6320331285065456
# Noise Level: high Mode: target_10_val
# Train-val-test lengths:  174640 37422 37430
# Epoch  0 Loss: 1.43651e+00 Accuracy: 0.25369 Epoch Time: 20.08471
# Epoch  1 Loss: 1.36577e+00 Accuracy: 0.34455 Epoch Time: 19.91613
# Epoch  2 Loss: 1.21612e+00 Accuracy: 0.49990 Epoch Time: 19.97133
# Epoch  3 Loss: 1.17101e+00 Accuracy: 0.51770 Epoch Time: 19.98240
# Epoch  4 Loss: 1.13570e+00 Accuracy: 0.53280 Epoch Time: 19.96239
# Epoch  5 Loss: 1.10713e+00 Accuracy: 0.54715 Epoch Time: 20.00029
# Epoch  6 Loss: 1.07311e+00 Accuracy: 0.55728 Epoch Time: 20.01546
# Epoch  7 Loss: 1.04605e+00 Accuracy: 0.56631 Epoch Time: 19.95412
# Epoch  8 Loss: 1.02369e+00 Accuracy: 0.57565 Epoch Time: 20.04333
# Epoch  9 Loss: 1.00277e+00 Accuracy: 0.58382 Epoch Time: 19.99047
# Epoch 10 Loss: 9.84548e-01 Accuracy: 0.59139 Epoch Time: 20.17424
# Epoch 11 Loss: 9.68583e-01 Accuracy: 0.59902 Epoch Time: 20.00947
# Epoch 12 Loss: 9.52564e-01 Accuracy: 0.60547 Epoch Time: 19.97968
# Epoch 13 Loss: 9.39488e-01 Accuracy: 0.61198 Epoch Time: 20.17738
# Epoch 14 Loss: 9.25345e-01 Accuracy: 0.61855 Epoch Time: 20.05427
# Epoch 15 Loss: 9.10810e-01 Accuracy: 0.62511 Epoch Time: 20.00984
# Epoch 16 Loss: 9.01073e-01 Accuracy: 0.62903 Epoch Time: 20.02194
# Epoch 17 Loss: 8.89328e-01 Accuracy: 0.63432 Epoch Time: 19.99308
# Epoch 18 Loss: 8.82171e-01 Accuracy: 0.63704 Epoch Time: 20.20327
# Epoch 19 Loss: 8.73484e-01 Accuracy: 0.64029 Epoch Time: 20.17439
# Epoch 20 Loss: 8.63539e-01 Accuracy: 0.64355 Epoch Time: 20.28963
# Epoch 21 Loss: 8.54218e-01 Accuracy: 0.64845 Epoch Time: 20.07674
# Epoch 22 Loss: 8.44097e-01 Accuracy: 0.65096 Epoch Time: 20.03007
# Epoch 23 Loss: 8.32571e-01 Accuracy: 0.65579 Epoch Time: 20.25258
# Epoch 24 Loss: 8.23360e-01 Accuracy: 0.65882 Epoch Time: 20.04140
# Epoch 25 Loss: 8.15791e-01 Accuracy: 0.66138 Epoch Time: 20.28844
# Epoch 26 Loss: 8.07825e-01 Accuracy: 0.66377 Epoch Time: 20.25343
# Epoch 27 Loss: 8.01830e-01 Accuracy: 0.66649 Epoch Time: 20.13578
# Epoch 28 Loss: 7.96761e-01 Accuracy: 0.66892 Epoch Time: 20.12921
# Epoch 29 Loss: 7.90533e-01 Accuracy: 0.67091 Epoch Time: 20.25870
# Model 0 acc: 0.6709115895556573
# Epoch  0 Loss: 1.43797e+00 Accuracy: 0.25322 Epoch Time: 20.18356
# Epoch  1 Loss: 1.43337e+00 Accuracy: 0.25536 Epoch Time: 20.22012
# Epoch  2 Loss: 1.43337e+00 Accuracy: 0.25438 Epoch Time: 20.22089
# Epoch  3 Loss: 1.43324e+00 Accuracy: 0.25678 Epoch Time: 20.02543
# Epoch  4 Loss: 1.43331e+00 Accuracy: 0.25518 Epoch Time: 20.09793
# Epoch  5 Loss: 1.43326e+00 Accuracy: 0.25518 Epoch Time: 20.09778
# Epoch  6 Loss: 1.43327e+00 Accuracy: 0.25581 Epoch Time: 19.91550
# Epoch  7 Loss: 1.43321e+00 Accuracy: 0.25688 Epoch Time: 19.93637
# Epoch  8 Loss: 1.43321e+00 Accuracy: 0.25658 Epoch Time: 20.04305
# Epoch  9 Loss: 1.43320e+00 Accuracy: 0.25570 Epoch Time: 19.88949
# Epoch 10 Loss: 1.43316e+00 Accuracy: 0.25693 Epoch Time: 19.91217
# Epoch 11 Loss: 1.43322e+00 Accuracy: 0.25642 Epoch Time: 19.97179
# Epoch 12 Loss: 1.43320e+00 Accuracy: 0.25683 Epoch Time: 20.11453
# Epoch 13 Loss: 1.43321e+00 Accuracy: 0.25694 Epoch Time: 19.99531
# Epoch 14 Loss: 1.43321e+00 Accuracy: 0.25676 Epoch Time: 20.07337
# Epoch 15 Loss: 1.43320e+00 Accuracy: 0.25627 Epoch Time: 19.95159
# Epoch 16 Loss: 1.43314e+00 Accuracy: 0.25644 Epoch Time: 20.18598
# Epoch 17 Loss: 1.43317e+00 Accuracy: 0.25693 Epoch Time: 20.20059
# Epoch 18 Loss: 1.31814e+00 Accuracy: 0.40803 Epoch Time: 20.07450
# Epoch 19 Loss: 1.17838e+00 Accuracy: 0.51386 Epoch Time: 19.86478
# Epoch 20 Loss: 1.13784e+00 Accuracy: 0.53389 Epoch Time: 20.09074
# Epoch 21 Loss: 1.12223e+00 Accuracy: 0.54008 Epoch Time: 19.99634
# Epoch 22 Loss: 1.10783e+00 Accuracy: 0.54647 Epoch Time: 20.21139
# Epoch 23 Loss: 1.09322e+00 Accuracy: 0.55036 Epoch Time: 20.20542
# Epoch 24 Loss: 1.08143e+00 Accuracy: 0.55321 Epoch Time: 20.13765
# Epoch 25 Loss: 1.06649e+00 Accuracy: 0.55665 Epoch Time: 19.89185
# Epoch 26 Loss: 1.05009e+00 Accuracy: 0.56161 Epoch Time: 20.05262
# Epoch 27 Loss: 1.03657e+00 Accuracy: 0.56564 Epoch Time: 20.02976
# Epoch 28 Loss: 1.02759e+00 Accuracy: 0.56966 Epoch Time: 19.81497
# Epoch 29 Loss: 1.01674e+00 Accuracy: 0.57400 Epoch Time: 19.83022
# Model 1 acc: 0.5740036646816308
# Epoch  0 Loss: 1.41736e+00 Accuracy: 0.28543 Epoch Time: 19.77371
# Epoch  1 Loss: 1.22368e+00 Accuracy: 0.49480 Epoch Time: 19.70788
# Epoch  2 Loss: 1.14436e+00 Accuracy: 0.53472 Epoch Time: 19.78156
# Epoch  3 Loss: 1.10995e+00 Accuracy: 0.54445 Epoch Time: 19.74305
# Epoch  4 Loss: 1.08872e+00 Accuracy: 0.55067 Epoch Time: 19.63926
# Epoch  5 Loss: 1.06356e+00 Accuracy: 0.55995 Epoch Time: 19.69105
# Epoch  6 Loss: 1.03494e+00 Accuracy: 0.56887 Epoch Time: 19.63837
# Epoch  7 Loss: 1.01145e+00 Accuracy: 0.57865 Epoch Time: 19.51282
# Epoch  8 Loss: 9.89223e-01 Accuracy: 0.59022 Epoch Time: 19.78906
# Epoch  9 Loss: 9.64755e-01 Accuracy: 0.60234 Epoch Time: 19.79653
# Epoch 10 Loss: 9.39015e-01 Accuracy: 0.61465 Epoch Time: 19.63478
# Epoch 11 Loss: 9.11760e-01 Accuracy: 0.62613 Epoch Time: 19.75602
# Epoch 12 Loss: 8.89183e-01 Accuracy: 0.63503 Epoch Time: 19.85988
# Epoch 13 Loss: 8.73108e-01 Accuracy: 0.64167 Epoch Time: 19.63691
# Epoch 14 Loss: 8.57953e-01 Accuracy: 0.64515 Epoch Time: 19.61625
# Epoch 15 Loss: 8.44894e-01 Accuracy: 0.65042 Epoch Time: 19.90187
# Epoch 16 Loss: 8.35711e-01 Accuracy: 0.65393 Epoch Time: 19.56765
# Epoch 17 Loss: 8.24968e-01 Accuracy: 0.65768 Epoch Time: 19.50918
# Epoch 18 Loss: 8.17132e-01 Accuracy: 0.66050 Epoch Time: 19.77276
# Epoch 19 Loss: 8.10218e-01 Accuracy: 0.66278 Epoch Time: 19.32999
# Epoch 20 Loss: 8.03797e-01 Accuracy: 0.66600 Epoch Time: 19.04031
# Epoch 21 Loss: 7.98554e-01 Accuracy: 0.66708 Epoch Time: 19.44988
# Epoch 22 Loss: 7.93986e-01 Accuracy: 0.66918 Epoch Time: 19.38266
# Epoch 23 Loss: 7.89141e-01 Accuracy: 0.67104 Epoch Time: 18.99925
# Epoch 24 Loss: 7.84116e-01 Accuracy: 0.67353 Epoch Time: 19.19166
# Epoch 25 Loss: 7.81272e-01 Accuracy: 0.67420 Epoch Time: 19.16062
# Epoch 26 Loss: 7.76237e-01 Accuracy: 0.67623 Epoch Time: 19.02835
# Epoch 27 Loss: 7.73586e-01 Accuracy: 0.67759 Epoch Time: 19.33949
# Epoch 28 Loss: 7.71432e-01 Accuracy: 0.67897 Epoch Time: 19.17792
# Epoch 29 Loss: 7.67288e-01 Accuracy: 0.67965 Epoch Time: 19.26116
# Model 2 acc: 0.6796495648190564
# "Noise Level: high | Mode: target_10_val_ensemble_lstm | Ensemble model acc: 0.6613946032594176

# %%
with open(f'{prefix}/losses_dump.pkl', 'wb') as f:
    pkl.dump(losses_arr, f)

with open(f'{prefix}/accs_dump.pkl', 'wb') as f:
    pkl.dump(accs_arr, f)
