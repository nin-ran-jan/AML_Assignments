# %%
# !gdown https://drive.google.com/file/d/1Hv4RAltBumSfOkRacoX8qrfDYfd_NDss/view?usp=drive_link --fuzzy
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Hv4RAltBumSfOkRacoX8qrfDYfd_NDss
# To: /content/Dataset_AML_Assignment1_Part1.zip
# 100% 11.2M/11.2M [00:00<00:00, 134MB/s]

# %%
# !unzip Dataset_AML_Assignment1_Part1.zip
# Out:
# Archive:  Dataset_AML_Assignment1_Part1.zip
#   inflating: df_syn_train_0_0_.csv
#   inflating: df_synA_test_hard_shuffled_sample.csv
#   inflating: df_synA_train_shuffled.csv

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import torch
from torch import nn
from torch import optim
from torch.utils.data import Dataset, DataLoader, random_split
import torch.nn.functional as F
from IPython import display
from tqdm.notebook import tqdm
import random
import math, time, os
from matplotlib import pyplot as plt

device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')
prefix = './data_dump_ensemble'

# %%
# NAL
# Ensemble
# Autoencoder
# SubTab
# Meta Learning - clean+dirty

# %%
class SinusodialDataset(Dataset):
    def __init__(self, df, mode='era'):
        """ creating label columns of eras and targets """
        self.X = df.iloc[:, :24]
        if mode == 'era':
          self.y = df['era_label']
        else:
          self.y = df[f'{mode}']

    def __len__(self):
        return self.X.shape[0]

    def __getitem__(self, idx):
        X = torch.tensor(self.X.iloc[idx].values, dtype=torch.float32)
        y = torch.tensor(int(self.y.iloc[idx]), dtype=torch.long)
        return X, y

# %%
def make_data_splits(df, mode, batch_size=32, train_perc=0.7, val_test_perc=0.5):

    def encode(v, class_values):
        return class_values.index(v)

    #adding new era_label column indexed 0, 1,...
    class_values = df['era'].unique().tolist()
    df['era_label'] = df['era'].apply(lambda x: encode(x, class_values))
    df.reset_index(drop=True, inplace=True)

    train_samples = int(len(df)*train_perc)
    val_test_samples = len(df)-train_samples

    data = SinusodialDataset(df, mode=mode)
    data_train, data_test = random_split(data, [train_samples, val_test_samples])

    val_samples = int(len(data_test)*0.5)
    test_samples = len(data_test)-val_samples
    data_val, data_test = random_split(data_test, [val_samples, test_samples])

    print("Train-val-test lengths: ", len(data_train), len(data_val), len(data_test))

    loader_train = DataLoader(data_train, batch_size=batch_size, shuffle=True)
    loader_val = DataLoader(data_val, batch_size=batch_size, shuffle=False)
    loader_test = DataLoader(data_test, batch_size=batch_size, shuffle=False)

    return loader_train, loader_val, loader_test, data

# %%
class MLP(nn.Module):
    def __init__(self, dims, task='classification', lr=1e-3, weight_decay=0):
        super(MLP,self).__init__()
        self.dims=dims
        self.task=task
        self.layers=nn.ModuleList()
        for i in range(len(self.dims)-2):
            self.layers.append(nn.Linear(dims[i],dims[i+1]))
            self.layers.append(nn.ReLU())
        self.layers.append(nn.Linear(dims[i+1],dims[i+2]))
        self.layers.append(nn.LogSoftmax(dim=1))
        self.optimizer = optim.Adam(self.parameters(), lr=lr, weight_decay=weight_decay)

    def forward(self,x):
        x = x.float()
        for l in self.layers:
            x = l(x)
        return x

# %%
def accuracy(Net, X_test, y_test, verbose=True):
    Net.eval()
    m = X_test.shape[0]
    y_pred = Net(X_test)
    predicted = torch.max(y_pred, 1)[1]
    correct = (predicted == y_test).float().sum().item()
    if verbose:
        print(correct,m)
    accuracy = correct/m
    Net.train()
    return accuracy, correct

# %%
def Test(net, loader_test, mode, noise_level, \
         device='cpu', Loss=nn.NLLLoss(reduction='sum')):
    net.eval()
    total_samples = 0
    correct_samples = 0
    loss = 0.0
    for (X, y) in loader_test:
        X=X.to(device)
        y=y.to(device)
        total_samples += y.shape[0]
        _, i_cor_sam = accuracy(net,X,y,verbose=False)
        correct_samples += i_cor_sam
        loss += Loss(net(X), y).cpu().detach().item()
    acc = correct_samples / total_samples
    loss /= total_samples
    return loss, acc

# %%
def Train(Net, data, mode, noise_level, epochs=20, lr=5e-2, Loss=nn.NLLLoss(reduction='sum'), verbose=False, device='cpu',
          val_ds=None, plot_accs=False, plot_losses=False):
    model_save_time = time.time()
    losses = []
    accs = []
    val_losses=[]
    val_accL=[]
    Net.to(device)
    for e in range(epochs):
        Net.train()
        step=0
        tot_loss=0.0
        start_time = time.time()
        correct_samples = 0
        total_samples = 0
        for (X,y) in data:
            X=X.to(device)
            y=y.to(device)
            total_samples += y.shape[0]
            y_pred = Net(X)
            loss = Loss(y_pred,y)
            Net.optimizer.zero_grad()
            loss.backward()
            Net.optimizer.step()
            step+=1
            tot_loss+=loss
            if verbose:
                _, i_cor_sam = accuracy(Net,X,y,verbose=False)
                correct_samples += i_cor_sam
        end_time = time.time()
        t = end_time-start_time
        l = tot_loss.item()/total_samples
        losses += [l]
        a = correct_samples/total_samples
        accs += [a]

        if verbose:
            print('Epoch %2d Loss: %2.5e Accuracy: %2.5f Epoch Time: %2.5f' %(e,l,a,t))

        val_loss, val_acc = Test(Net, val_ds, mode, noise_level, device)
        val_losses.append(val_loss)
        val_accL.append(val_acc)

        torch.save(Net.state_dict(), f'{prefix}/net_{noise_level}_{mode}_{str(model_save_time)}.pth')

    return Net, losses, accs, val_losses, val_accL

# %%
def plot_loss_acc(losses, accs, val_losses, val_accs, mode, noise_level):

    plt.plot(np.array(accs),color='red', label='Train accuracy')
    plt.plot(np.array(val_accs),color='blue', label='Val accuracy')
    plt.legend()
    plt.savefig(f'{prefix}/acc_{mode}_{noise_level}.png')
    plt.clf()

    plt.plot(np.array(losses),color='red', label='Train loss')
    plt.plot(np.array(val_losses),color='blue', label='Val loss')
    plt.legend()
    plt.savefig(f'{prefix}/loss_{mode}_{noise_level}.png')
    plt.clf()
    return

# %%
def checkModel(net, mode, noise_level, loader_train, loader_val, loader_test):
  net, losses, accs, val_losses, val_accL = Train(net, loader_train, mode, noise_level, \
                              epochs=15, verbose=True, device=device, val_ds=loader_val, \
                              plot_accs=True, plot_losses=True)

  plot_loss_acc(losses, accs, val_losses, val_accL, mode, noise_level)
  #Testing code
  test_loss, test_acc = Test(net, loader_test, mode, noise_level, device=device)
  return net, accs[-1]

# %%
def TestEnsemble(nets, loader_test, mode, noise_level, \
         device='cpu', Loss=nn.NLLLoss(reduction='sum')):
    total_samples = 0
    correct_samples = 0

    for (X, y) in loader_test:
        X=X.to(device)
        y=y.to(device)
        sample_size = y.shape[0]
        total_samples += sample_size

        y_preds = []
        all_classes = 0

        for net in nets:
          net.eval()
          __y_pred = net(X)
          all_classes = __y_pred.shape[-1]
          predicted = torch.max(__y_pred, 1)[1]
          y_preds.append(predicted.cpu().detach().numpy())


        predicted = []

        for i in range(sample_size):
          voting_array = [0] * all_classes
          for model_num in range(len(nets)):
            voting_array[y_preds[model_num][i]] += 1
          max_val = -1
          max_ind = -1
          for ind in range(len(voting_array)):
            if voting_array[ind] > max_val:
              max_val = voting_array[ind]
              max_ind = ind

          predicted.append(max_ind)

        predicted = torch.tensor(predicted).to(device)
        i_cor_sam = (predicted == y).float().sum().item()
        correct_samples += i_cor_sam

    acc = correct_samples / total_samples
    return acc

# %%
df_paths = ['./df_syn_train_0_0_.csv',
            './df_synA_train_shuffled.csv',
            './df_synA_test_hard_shuffled_sample.csv']

noise_levels = ['none', 'low', 'high']
batch_sizes = [32, 128, 128]

losses_arr = []
accs_arr = []

for i in range(0, 3):
  df = pd.read_csv(df_paths[i])

  modes = ['era', 'target_5_val', 'target_10_val']

  loss_per_mode = []
  acc_per_mode = []

  for mode in modes:
    noise_level = noise_levels[i]
    print("Noise Level:", noise_level, "| Mode:", mode)
    loader_train, loader_val, loader_test, data = make_data_splits(df, mode=mode, \
                                                                    batch_size=batch_sizes[i])

    nets = [MLP(dims=[data.X.shape[1], 64, 32, len(data.y.unique())]),
            MLP(dims=[data.X.shape[1], 128, 64, 32, 16, len(data.y.unique())]),
            MLP(dims=[data.X.shape[1], 32, len(data.y.unique())]),
            MLP(dims=[data.X.shape[1], 64, 128, 64, 24, len(data.y.unique())]),
            MLP(dims=[data.X.shape[1], 32, 64, 128, len(data.y.unique())])
            ]

    mode += '_ensemble'
    check_accs = []
    counter = 0
    for net in nets:
      net = net.to(device)
      net, _acc = checkModel(net, mode, noise_level, loader_train, loader_val, loader_test)
      check_accs.append(_acc)
      # print(f'Model {counter} finished - {_acc}%')
      counter += 1

    # for j in range(len(nets)):
      # print(print(f'Model {j} accuracy - {check_accs[j]}%'))

    ensemble_acc = TestEnsemble(nets, loader_test, mode, noise_level, device=device)
    print(f'"Noise Level: {noise_level} | Mode: {mode} | Ensemble model acc: {ensemble_acc}')

    # loss_per_mode.append(test_loss)
    acc_per_mode.append(ensemble_acc)

  # losses_arr.append(loss_per_mode)
  accs_arr.append(acc_per_mode)
# Out:
# Noise Level: none | Mode: era
# Train-val-test lengths:  5460 1170 1170
# Epoch  0 Loss: 2.25870e+00 Accuracy: 0.27491 Epoch Time: 1.53230
# Epoch  1 Loss: 1.43765e+00 Accuracy: 0.51758 Epoch Time: 1.32880
# Epoch  2 Loss: 1.01301e+00 Accuracy: 0.67601 Epoch Time: 1.57535
# Epoch  3 Loss: 8.29714e-01 Accuracy: 0.73352 Epoch Time: 1.19665
# Epoch  4 Loss: 7.32480e-01 Accuracy: 0.76099 Epoch Time: 1.48896
# Epoch  5 Loss: 6.67785e-01 Accuracy: 0.77930 Epoch Time: 1.28448
# Epoch  6 Loss: 6.25810e-01 Accuracy: 0.78846 Epoch Time: 1.41319
# Epoch  7 Loss: 6.01186e-01 Accuracy: 0.79267 Epoch Time: 1.45912
# Epoch  8 Loss: 5.67833e-01 Accuracy: 0.80421 Epoch Time: 1.44920
# Epoch  9 Loss: 5.45934e-01 Accuracy: 0.81154 Epoch Time: 1.36424
# Epoch 10 Loss: 5.28950e-01 Accuracy: 0.81593 Epoch Time: 1.32280
# Epoch 11 Loss: 5.10320e-01 Accuracy: 0.82179 Epoch Time: 1.43477
# Epoch 12 Loss: 4.92391e-01 Accuracy: 0.82326 Epoch Time: 1.47191
# Epoch 13 Loss: 4.73109e-01 Accuracy: 0.83297 Epoch Time: 1.21850
# Epoch 14 Loss: 4.61220e-01 Accuracy: 0.83974 Epoch Time: 1.37437
# Epoch  0 Loss: 2.13466e+00 Accuracy: 0.23919 Epoch Time: 1.57337
# Epoch  1 Loss: 1.20956e+00 Accuracy: 0.57033 Epoch Time: 1.54161
# Epoch  2 Loss: 8.18351e-01 Accuracy: 0.71429 Epoch Time: 1.58024
# Epoch  3 Loss: 6.78822e-01 Accuracy: 0.76722 Epoch Time: 1.25985
# Epoch  4 Loss: 6.04021e-01 Accuracy: 0.78956 Epoch Time: 1.43858
# Epoch  5 Loss: 5.54436e-01 Accuracy: 0.80476 Epoch Time: 1.65525
# Epoch  6 Loss: 5.24637e-01 Accuracy: 0.81136 Epoch Time: 1.57211
# Epoch  7 Loss: 4.94173e-01 Accuracy: 0.82015 Epoch Time: 1.69804
# Epoch  8 Loss: 4.55342e-01 Accuracy: 0.83388 Epoch Time: 1.53600
# Epoch  9 Loss: 4.31141e-01 Accuracy: 0.84267 Epoch Time: 1.63981
# Epoch 10 Loss: 4.15331e-01 Accuracy: 0.85220 Epoch Time: 1.43193
# Epoch 11 Loss: 4.02306e-01 Accuracy: 0.85586 Epoch Time: 1.70822
# Epoch 12 Loss: 3.88045e-01 Accuracy: 0.86044 Epoch Time: 1.75577
# Epoch 13 Loss: 3.75937e-01 Accuracy: 0.86740 Epoch Time: 1.40638
# Epoch 14 Loss: 3.45248e-01 Accuracy: 0.87601 Epoch Time: 1.64579
# Epoch  0 Loss: 2.40919e+00 Accuracy: 0.20403 Epoch Time: 1.24337
# Epoch  1 Loss: 2.10731e+00 Accuracy: 0.34615 Epoch Time: 1.25227
# Epoch  2 Loss: 1.77583e+00 Accuracy: 0.43150 Epoch Time: 1.38664
# Epoch  3 Loss: 1.54074e+00 Accuracy: 0.53150 Epoch Time: 1.02631
# Epoch  4 Loss: 1.37779e+00 Accuracy: 0.60458 Epoch Time: 1.29565
# Epoch  5 Loss: 1.25260e+00 Accuracy: 0.64542 Epoch Time: 1.19424
# Epoch  6 Loss: 1.15664e+00 Accuracy: 0.67143 Epoch Time: 1.34190
# Epoch  7 Loss: 1.07881e+00 Accuracy: 0.67766 Epoch Time: 1.62268
# Epoch  8 Loss: 1.01498e+00 Accuracy: 0.70055 Epoch Time: 1.44008
# Epoch  9 Loss: 9.60283e-01 Accuracy: 0.71538 Epoch Time: 1.46703
# Epoch 10 Loss: 9.13363e-01 Accuracy: 0.73278 Epoch Time: 1.27485
# Epoch 11 Loss: 8.74274e-01 Accuracy: 0.74396 Epoch Time: 1.37312
# Epoch 12 Loss: 8.42387e-01 Accuracy: 0.74927 Epoch Time: 1.36550
# Epoch 13 Loss: 8.10432e-01 Accuracy: 0.75476 Epoch Time: 1.32280
# Epoch 14 Loss: 7.84831e-01 Accuracy: 0.76007 Epoch Time: 1.20224
# Epoch  0 Loss: 2.07730e+00 Accuracy: 0.30385 Epoch Time: 1.30935
# Epoch  1 Loss: 9.33851e-01 Accuracy: 0.67179 Epoch Time: 1.41584
# Epoch  2 Loss: 7.04452e-01 Accuracy: 0.74927 Epoch Time: 1.53232
# Epoch  3 Loss: 6.27526e-01 Accuracy: 0.77656 Epoch Time: 1.51164
# Epoch  4 Loss: 5.76900e-01 Accuracy: 0.78718 Epoch Time: 1.14743
# Epoch  5 Loss: 5.32984e-01 Accuracy: 0.80714 Epoch Time: 1.48667
# Epoch  6 Loss: 4.96953e-01 Accuracy: 0.81667 Epoch Time: 1.76919
# Epoch  7 Loss: 4.77907e-01 Accuracy: 0.82582 Epoch Time: 1.44400
# Epoch  8 Loss: 4.54242e-01 Accuracy: 0.83626 Epoch Time: 1.39716
# Epoch  9 Loss: 4.26990e-01 Accuracy: 0.84524 Epoch Time: 1.46002
# Epoch 10 Loss: 4.11303e-01 Accuracy: 0.85476 Epoch Time: 1.55134
# Epoch 11 Loss: 3.84521e-01 Accuracy: 0.85806 Epoch Time: 1.69102
# Epoch 12 Loss: 3.83653e-01 Accuracy: 0.86502 Epoch Time: 1.36234
# Epoch 13 Loss: 3.48272e-01 Accuracy: 0.87619 Epoch Time: 1.32548
# Epoch 14 Loss: 3.44937e-01 Accuracy: 0.87949 Epoch Time: 1.86795
# Epoch  0 Loss: 2.10890e+00 Accuracy: 0.27033 Epoch Time: 1.46602
# Epoch  1 Loss: 1.07825e+00 Accuracy: 0.61484 Epoch Time: 1.59450
# Epoch  2 Loss: 8.10833e-01 Accuracy: 0.71630 Epoch Time: 1.82768
# Epoch  3 Loss: 7.01619e-01 Accuracy: 0.75421 Epoch Time: 1.36628
# Epoch  4 Loss: 6.33798e-01 Accuracy: 0.77930 Epoch Time: 1.42508
# Epoch  5 Loss: 5.90066e-01 Accuracy: 0.79103 Epoch Time: 1.55876
# Epoch  6 Loss: 5.53307e-01 Accuracy: 0.80311 Epoch Time: 1.26690
# Epoch  7 Loss: 5.26195e-01 Accuracy: 0.80495 Epoch Time: 1.36959
# Epoch  8 Loss: 4.93316e-01 Accuracy: 0.81978 Epoch Time: 1.38169
# Epoch  9 Loss: 4.70923e-01 Accuracy: 0.83333 Epoch Time: 1.49087
# Epoch 10 Loss: 4.51392e-01 Accuracy: 0.84121 Epoch Time: 1.36003
# Epoch 11 Loss: 4.39645e-01 Accuracy: 0.83755 Epoch Time: 1.65730
# Epoch 12 Loss: 4.08515e-01 Accuracy: 0.85201 Epoch Time: 1.54822
# Epoch 13 Loss: 4.03660e-01 Accuracy: 0.85495 Epoch Time: 1.26601
# Epoch 14 Loss: 3.83782e-01 Accuracy: 0.85952 Epoch Time: 1.28157
# "Noise Level: none | Mode: era_ensemble | Ensemble model acc: 0.841025641025641
# Noise Level: none | Mode: target_5_val
# Train-val-test lengths:  5460 1170 1170
# Epoch  0 Loss: 6.67870e-01 Accuracy: 0.76740 Epoch Time: 1.22633
# Epoch  1 Loss: 2.80891e-01 Accuracy: 0.87015 Epoch Time: 1.39140
# Epoch  2 Loss: 2.32503e-01 Accuracy: 0.89469 Epoch Time: 1.40297
# Epoch  3 Loss: 2.12530e-01 Accuracy: 0.90403 Epoch Time: 1.43653
# Epoch  4 Loss: 1.94231e-01 Accuracy: 0.91484 Epoch Time: 1.71711
# Epoch  5 Loss: 1.79852e-01 Accuracy: 0.91832 Epoch Time: 1.67847
# Epoch  6 Loss: 1.71988e-01 Accuracy: 0.92326 Epoch Time: 1.08080
# Epoch  7 Loss: 1.60270e-01 Accuracy: 0.93223 Epoch Time: 1.25596
# Epoch  8 Loss: 1.49607e-01 Accuracy: 0.93791 Epoch Time: 1.33846
# Epoch  9 Loss: 1.42547e-01 Accuracy: 0.94212 Epoch Time: 1.33431
# Epoch 10 Loss: 1.34092e-01 Accuracy: 0.94799 Epoch Time: 1.23747
# Epoch 11 Loss: 1.25649e-01 Accuracy: 0.95165 Epoch Time: 1.60286
# Epoch 12 Loss: 1.23984e-01 Accuracy: 0.95549 Epoch Time: 1.48436
# Epoch 13 Loss: 1.15541e-01 Accuracy: 0.95916 Epoch Time: 1.55099
# Epoch 14 Loss: 1.16277e-01 Accuracy: 0.95751 Epoch Time: 1.18675
# Epoch  0 Loss: 5.81486e-01 Accuracy: 0.81044 Epoch Time: 1.95434
# Epoch  1 Loss: 2.21515e-01 Accuracy: 0.89359 Epoch Time: 1.32210
# Epoch  2 Loss: 1.88259e-01 Accuracy: 0.91667 Epoch Time: 1.36465
# Epoch  3 Loss: 1.62319e-01 Accuracy: 0.93645 Epoch Time: 1.44205
# Epoch  4 Loss: 1.45334e-01 Accuracy: 0.94414 Epoch Time: 1.64661
# Epoch  5 Loss: 1.41946e-01 Accuracy: 0.94322 Epoch Time: 1.24578
# Epoch  6 Loss: 1.33313e-01 Accuracy: 0.95275 Epoch Time: 1.61666
# Epoch  7 Loss: 1.16973e-01 Accuracy: 0.95604 Epoch Time: 1.17937
# Epoch  8 Loss: 1.15172e-01 Accuracy: 0.95659 Epoch Time: 1.58481
# Epoch  9 Loss: 1.05477e-01 Accuracy: 0.96007 Epoch Time: 1.72234
# Epoch 10 Loss: 1.07392e-01 Accuracy: 0.95861 Epoch Time: 1.45925
# Epoch 11 Loss: 9.71988e-02 Accuracy: 0.96465 Epoch Time: 1.56103
# Epoch 12 Loss: 1.02226e-01 Accuracy: 0.96154 Epoch Time: 1.51024
# Epoch 13 Loss: 9.23118e-02 Accuracy: 0.96685 Epoch Time: 1.50868
# Epoch 14 Loss: 9.15894e-02 Accuracy: 0.96538 Epoch Time: 1.65120
# Epoch  0 Loss: 6.65353e-01 Accuracy: 0.76429 Epoch Time: 1.10999
# Epoch  1 Loss: 3.43501e-01 Accuracy: 0.84799 Epoch Time: 1.27067
# Epoch  2 Loss: 2.72162e-01 Accuracy: 0.87601 Epoch Time: 1.76571
# Epoch  3 Loss: 2.36129e-01 Accuracy: 0.89505 Epoch Time: 1.62251
# Epoch  4 Loss: 2.18958e-01 Accuracy: 0.90073 Epoch Time: 1.28697
# Epoch  5 Loss: 2.07510e-01 Accuracy: 0.90641 Epoch Time: 1.45929
# Epoch  6 Loss: 1.97517e-01 Accuracy: 0.90733 Epoch Time: 1.66973
# Epoch  7 Loss: 1.87716e-01 Accuracy: 0.91575 Epoch Time: 1.09883
# Epoch  8 Loss: 1.80482e-01 Accuracy: 0.92033 Epoch Time: 1.27390
# Epoch  9 Loss: 1.76318e-01 Accuracy: 0.92308 Epoch Time: 1.22402
# Epoch 10 Loss: 1.69223e-01 Accuracy: 0.92711 Epoch Time: 1.11950
# Epoch 11 Loss: 1.64765e-01 Accuracy: 0.93315 Epoch Time: 1.53157
# Epoch 12 Loss: 1.61212e-01 Accuracy: 0.93352 Epoch Time: 1.47177
# Epoch 13 Loss: 1.55516e-01 Accuracy: 0.93919 Epoch Time: 1.54068
# Epoch 14 Loss: 1.52085e-01 Accuracy: 0.94121 Epoch Time: 1.32668
# Epoch  0 Loss: 6.15724e-01 Accuracy: 0.75788 Epoch Time: 1.65199
# Epoch  1 Loss: 2.32583e-01 Accuracy: 0.89707 Epoch Time: 1.47615
# Epoch  2 Loss: 1.93314e-01 Accuracy: 0.91282 Epoch Time: 1.63319
# Epoch  3 Loss: 1.79393e-01 Accuracy: 0.92399 Epoch Time: 1.51234
# Epoch  4 Loss: 1.60766e-01 Accuracy: 0.93352 Epoch Time: 1.34357
# Epoch  5 Loss: 1.55955e-01 Accuracy: 0.93791 Epoch Time: 1.39399
# Epoch  6 Loss: 1.40499e-01 Accuracy: 0.94835 Epoch Time: 1.38179
# Epoch  7 Loss: 1.36189e-01 Accuracy: 0.95147 Epoch Time: 1.47946
# Epoch  8 Loss: 1.23100e-01 Accuracy: 0.95531 Epoch Time: 1.84737
# Epoch  9 Loss: 1.16895e-01 Accuracy: 0.95824 Epoch Time: 1.72013
# Epoch 10 Loss: 1.19587e-01 Accuracy: 0.95806 Epoch Time: 1.66908
# Epoch 11 Loss: 1.13679e-01 Accuracy: 0.95879 Epoch Time: 1.70058
# Epoch 12 Loss: 1.06346e-01 Accuracy: 0.96355 Epoch Time: 1.30556
# Epoch 13 Loss: 1.04827e-01 Accuracy: 0.96337 Epoch Time: 1.50676
# Epoch 14 Loss: 1.04699e-01 Accuracy: 0.96044 Epoch Time: 1.44867
# Epoch  0 Loss: 5.00472e-01 Accuracy: 0.81795 Epoch Time: 1.63459
# Epoch  1 Loss: 2.15452e-01 Accuracy: 0.89817 Epoch Time: 1.53020
# Epoch  2 Loss: 1.88814e-01 Accuracy: 0.91447 Epoch Time: 1.58091
# Epoch  3 Loss: 1.68308e-01 Accuracy: 0.92839 Epoch Time: 1.80664
# Epoch  4 Loss: 1.59187e-01 Accuracy: 0.93462 Epoch Time: 1.46728
# Epoch  5 Loss: 1.48084e-01 Accuracy: 0.94212 Epoch Time: 1.53945
# Epoch  6 Loss: 1.32494e-01 Accuracy: 0.94817 Epoch Time: 1.40882
# Epoch  7 Loss: 1.19998e-01 Accuracy: 0.95531 Epoch Time: 1.40899
# Epoch  8 Loss: 1.21171e-01 Accuracy: 0.95513 Epoch Time: 1.40398
# Epoch  9 Loss: 1.11672e-01 Accuracy: 0.95806 Epoch Time: 1.48043
# Epoch 10 Loss: 1.09824e-01 Accuracy: 0.95916 Epoch Time: 1.66737
# Epoch 11 Loss: 1.03887e-01 Accuracy: 0.96026 Epoch Time: 1.90658
# Epoch 12 Loss: 9.90332e-02 Accuracy: 0.96300 Epoch Time: 1.69167
# Epoch 13 Loss: 9.84283e-02 Accuracy: 0.96429 Epoch Time: 1.47569
# Epoch 14 Loss: 9.84771e-02 Accuracy: 0.96264 Epoch Time: 1.40749
# "Noise Level: none | Mode: target_5_val_ensemble | Ensemble model acc: 0.9658119658119658
# Noise Level: none | Mode: target_10_val
# Train-val-test lengths:  5460 1170 1170
# Epoch  0 Loss: 5.56128e-01 Accuracy: 0.80879 Epoch Time: 1.21980
# Epoch  1 Loss: 3.14196e-01 Accuracy: 0.86575 Epoch Time: 1.25155
# Epoch  2 Loss: 2.74256e-01 Accuracy: 0.88700 Epoch Time: 1.00569
# Epoch  3 Loss: 2.47699e-01 Accuracy: 0.89872 Epoch Time: 1.52976
# Epoch  4 Loss: 2.34216e-01 Accuracy: 0.90073 Epoch Time: 1.38674
# Epoch  5 Loss: 2.13911e-01 Accuracy: 0.91172 Epoch Time: 1.23980
# Epoch  6 Loss: 2.02770e-01 Accuracy: 0.91685 Epoch Time: 1.54486
# Epoch  7 Loss: 1.96275e-01 Accuracy: 0.92216 Epoch Time: 1.63023
# Epoch  8 Loss: 1.83577e-01 Accuracy: 0.92802 Epoch Time: 1.40393
# Epoch  9 Loss: 1.80171e-01 Accuracy: 0.92875 Epoch Time: 1.46291
# Epoch 10 Loss: 1.72345e-01 Accuracy: 0.93370 Epoch Time: 1.37445
# Epoch 11 Loss: 1.65881e-01 Accuracy: 0.93571 Epoch Time: 1.83178
# Epoch 12 Loss: 1.55926e-01 Accuracy: 0.94341 Epoch Time: 1.51716
# Epoch 13 Loss: 1.50977e-01 Accuracy: 0.94432 Epoch Time: 1.45351
# Epoch 14 Loss: 1.46324e-01 Accuracy: 0.94469 Epoch Time: 1.73170
# Epoch  0 Loss: 7.14879e-01 Accuracy: 0.70989 Epoch Time: 1.54831
# Epoch  1 Loss: 3.21645e-01 Accuracy: 0.86557 Epoch Time: 1.46788
# Epoch  2 Loss: 2.74666e-01 Accuracy: 0.88480 Epoch Time: 1.61493
# Epoch  3 Loss: 2.35170e-01 Accuracy: 0.90714 Epoch Time: 1.59541
# Epoch  4 Loss: 2.12762e-01 Accuracy: 0.91813 Epoch Time: 1.59782
# Epoch  5 Loss: 1.82674e-01 Accuracy: 0.93187 Epoch Time: 1.53192
# Epoch  6 Loss: 1.71732e-01 Accuracy: 0.93645 Epoch Time: 1.53828
# Epoch  7 Loss: 1.58223e-01 Accuracy: 0.94011 Epoch Time: 1.66708
# Epoch  8 Loss: 1.44866e-01 Accuracy: 0.94670 Epoch Time: 1.66503
# Epoch  9 Loss: 1.46807e-01 Accuracy: 0.94707 Epoch Time: 1.40904
# Epoch 10 Loss: 1.28150e-01 Accuracy: 0.95586 Epoch Time: 1.72878
# Epoch 11 Loss: 1.21777e-01 Accuracy: 0.96026 Epoch Time: 1.60505
# Epoch 12 Loss: 1.15007e-01 Accuracy: 0.96007 Epoch Time: 1.40656
# Epoch 13 Loss: 1.06960e-01 Accuracy: 0.96319 Epoch Time: 1.49231
# Epoch 14 Loss: 1.05105e-01 Accuracy: 0.96520 Epoch Time: 1.35678
# Epoch  0 Loss: 7.34405e-01 Accuracy: 0.75458 Epoch Time: 1.26634
# Epoch  1 Loss: 3.91645e-01 Accuracy: 0.83205 Epoch Time: 1.60137
# Epoch  2 Loss: 3.28799e-01 Accuracy: 0.86923 Epoch Time: 1.46898
# Epoch  3 Loss: 2.97698e-01 Accuracy: 0.87821 Epoch Time: 1.64527
# Epoch  4 Loss: 2.76738e-01 Accuracy: 0.88645 Epoch Time: 1.43817
# Epoch  5 Loss: 2.61672e-01 Accuracy: 0.89432 Epoch Time: 1.49235
# Epoch  6 Loss: 2.48344e-01 Accuracy: 0.90165 Epoch Time: 1.50818
# Epoch  7 Loss: 2.38267e-01 Accuracy: 0.90751 Epoch Time: 1.24303
# Epoch  8 Loss: 2.30088e-01 Accuracy: 0.90714 Epoch Time: 1.16785
# Epoch  9 Loss: 2.22348e-01 Accuracy: 0.90989 Epoch Time: 1.20295
# Epoch 10 Loss: 2.17066e-01 Accuracy: 0.91117 Epoch Time: 1.38533
# Epoch 11 Loss: 2.12841e-01 Accuracy: 0.91209 Epoch Time: 1.33347
# Epoch 12 Loss: 2.08357e-01 Accuracy: 0.91685 Epoch Time: 1.31501
# Epoch 13 Loss: 2.03466e-01 Accuracy: 0.91996 Epoch Time: 1.34386
# Epoch 14 Loss: 1.98878e-01 Accuracy: 0.91941 Epoch Time: 1.31156
# Epoch  0 Loss: 5.92177e-01 Accuracy: 0.80696 Epoch Time: 1.58909
# Epoch  1 Loss: 2.98269e-01 Accuracy: 0.87546 Epoch Time: 1.30471
# Epoch  2 Loss: 2.40098e-01 Accuracy: 0.89762 Epoch Time: 1.41227
# Epoch  3 Loss: 2.06546e-01 Accuracy: 0.91868 Epoch Time: 1.30321
# Epoch  4 Loss: 1.83320e-01 Accuracy: 0.92766 Epoch Time: 1.24481
# Epoch  5 Loss: 1.64440e-01 Accuracy: 0.93846 Epoch Time: 1.35707
# Epoch  6 Loss: 1.53873e-01 Accuracy: 0.94359 Epoch Time: 1.38767
# Epoch  7 Loss: 1.40142e-01 Accuracy: 0.95037 Epoch Time: 1.43783
# Epoch  8 Loss: 1.31539e-01 Accuracy: 0.95165 Epoch Time: 1.43947
# Epoch  9 Loss: 1.25485e-01 Accuracy: 0.95568 Epoch Time: 1.48438
# Epoch 10 Loss: 1.20497e-01 Accuracy: 0.95824 Epoch Time: 1.53970
# Epoch 11 Loss: 1.08853e-01 Accuracy: 0.96374 Epoch Time: 1.67285
# Epoch 12 Loss: 1.02686e-01 Accuracy: 0.96557 Epoch Time: 1.45273
# Epoch 13 Loss: 1.01080e-01 Accuracy: 0.96667 Epoch Time: 1.41570
# Epoch 14 Loss: 9.29498e-02 Accuracy: 0.96886 Epoch Time: 1.57519
# Epoch  0 Loss: 5.48665e-01 Accuracy: 0.79945 Epoch Time: 1.33846
# Epoch  1 Loss: 2.97417e-01 Accuracy: 0.87857 Epoch Time: 1.71120
# Epoch  2 Loss: 2.51311e-01 Accuracy: 0.89597 Epoch Time: 1.70217
# Epoch  3 Loss: 2.20464e-01 Accuracy: 0.91026 Epoch Time: 1.62817
# Epoch  4 Loss: 1.95770e-01 Accuracy: 0.92381 Epoch Time: 1.55692
# Epoch  5 Loss: 1.82213e-01 Accuracy: 0.93022 Epoch Time: 1.59712
# Epoch  6 Loss: 1.66365e-01 Accuracy: 0.93846 Epoch Time: 1.32342
# Epoch  7 Loss: 1.57925e-01 Accuracy: 0.94176 Epoch Time: 1.72447
# Epoch  8 Loss: 1.42441e-01 Accuracy: 0.94872 Epoch Time: 1.41972
# Epoch  9 Loss: 1.37981e-01 Accuracy: 0.95183 Epoch Time: 1.29046
# Epoch 10 Loss: 1.26249e-01 Accuracy: 0.95348 Epoch Time: 1.47552
# Epoch 11 Loss: 1.26411e-01 Accuracy: 0.95421 Epoch Time: 1.60637
# Epoch 12 Loss: 1.17351e-01 Accuracy: 0.95806 Epoch Time: 1.44809
# Epoch 13 Loss: 1.09288e-01 Accuracy: 0.96154 Epoch Time: 1.48754
# Epoch 14 Loss: 1.02727e-01 Accuracy: 0.96593 Epoch Time: 1.73810
# "Noise Level: none | Mode: target_10_val_ensemble | Ensemble model acc: 0.976068376068376
# Noise Level: low | Mode: era
# Train-val-test lengths:  218400 46800 46800
# Epoch  0 Loss: 1.22120e+00 Accuracy: 0.56016 Epoch Time: 26.47761
# Epoch  1 Loss: 8.55004e-01 Accuracy: 0.67711 Epoch Time: 25.37258
# Epoch  2 Loss: 7.77522e-01 Accuracy: 0.70346 Epoch Time: 25.44653
# Epoch  3 Loss: 7.35540e-01 Accuracy: 0.71630 Epoch Time: 25.31623
# Epoch  4 Loss: 7.05564e-01 Accuracy: 0.72678 Epoch Time: 25.50622
# Epoch  5 Loss: 6.84777e-01 Accuracy: 0.73461 Epoch Time: 25.42214
# Epoch  6 Loss: 6.69072e-01 Accuracy: 0.74088 Epoch Time: 26.65048
# Epoch  7 Loss: 6.57138e-01 Accuracy: 0.74449 Epoch Time: 26.59914
# Epoch  8 Loss: 6.46695e-01 Accuracy: 0.74776 Epoch Time: 26.22451
# Epoch  9 Loss: 6.38283e-01 Accuracy: 0.75132 Epoch Time: 25.17189
# Epoch 10 Loss: 6.31589e-01 Accuracy: 0.75274 Epoch Time: 25.64259
# Epoch 11 Loss: 6.25143e-01 Accuracy: 0.75505 Epoch Time: 26.93121
# Epoch 12 Loss: 6.18195e-01 Accuracy: 0.75745 Epoch Time: 24.76930
# Epoch 13 Loss: 6.14114e-01 Accuracy: 0.75790 Epoch Time: 26.16894
# Epoch 14 Loss: 6.08375e-01 Accuracy: 0.76071 Epoch Time: 27.03355
# Epoch  0 Loss: 1.14667e+00 Accuracy: 0.57044 Epoch Time: 27.56697
# Epoch  1 Loss: 8.12184e-01 Accuracy: 0.69261 Epoch Time: 27.17927
# Epoch  2 Loss: 7.22478e-01 Accuracy: 0.72609 Epoch Time: 26.84275
# Epoch  3 Loss: 6.70978e-01 Accuracy: 0.74283 Epoch Time: 26.67029
# Epoch  4 Loss: 6.40799e-01 Accuracy: 0.75206 Epoch Time: 26.38851
# Epoch  5 Loss: 6.21292e-01 Accuracy: 0.75817 Epoch Time: 26.56124
# Epoch  6 Loss: 6.04758e-01 Accuracy: 0.76411 Epoch Time: 26.87602
# Epoch  7 Loss: 5.91749e-01 Accuracy: 0.76786 Epoch Time: 26.23127
# Epoch  8 Loss: 5.80681e-01 Accuracy: 0.77160 Epoch Time: 25.30861
# Epoch  9 Loss: 5.71121e-01 Accuracy: 0.77471 Epoch Time: 25.04438
# Epoch 10 Loss: 5.62282e-01 Accuracy: 0.77767 Epoch Time: 26.31612
# Epoch 11 Loss: 5.56949e-01 Accuracy: 0.77936 Epoch Time: 27.97547
# Epoch 12 Loss: 5.49779e-01 Accuracy: 0.78170 Epoch Time: 26.03019
# Epoch 13 Loss: 5.42147e-01 Accuracy: 0.78499 Epoch Time: 26.30385
# Epoch 14 Loss: 5.36398e-01 Accuracy: 0.78649 Epoch Time: 26.34774
# Epoch  0 Loss: 1.57886e+00 Accuracy: 0.45631 Epoch Time: 24.36893
# Epoch  1 Loss: 1.09825e+00 Accuracy: 0.59781 Epoch Time: 25.36190
# Epoch  2 Loss: 9.96464e-01 Accuracy: 0.62746 Epoch Time: 24.01805
# Epoch  3 Loss: 9.36401e-01 Accuracy: 0.64773 Epoch Time: 25.54900
# Epoch  4 Loss: 8.95508e-01 Accuracy: 0.66117 Epoch Time: 24.58145
# Epoch  5 Loss: 8.65781e-01 Accuracy: 0.67131 Epoch Time: 24.71131
# Epoch  6 Loss: 8.43610e-01 Accuracy: 0.67891 Epoch Time: 25.07783
# Epoch  7 Loss: 8.26647e-01 Accuracy: 0.68541 Epoch Time: 24.23693
# Epoch  8 Loss: 8.13213e-01 Accuracy: 0.69103 Epoch Time: 24.92743
# Epoch  9 Loss: 8.01692e-01 Accuracy: 0.69593 Epoch Time: 24.62466
# Epoch 10 Loss: 7.91251e-01 Accuracy: 0.69941 Epoch Time: 24.35744
# Epoch 11 Loss: 7.82215e-01 Accuracy: 0.70261 Epoch Time: 24.73242
# Epoch 12 Loss: 7.74456e-01 Accuracy: 0.70582 Epoch Time: 24.22613
# Epoch 13 Loss: 7.68131e-01 Accuracy: 0.70708 Epoch Time: 24.61796
# Epoch 14 Loss: 7.62187e-01 Accuracy: 0.70897 Epoch Time: 24.11693
# Epoch  0 Loss: 1.10114e+00 Accuracy: 0.58793 Epoch Time: 25.74376
# Epoch  1 Loss: 8.04322e-01 Accuracy: 0.69076 Epoch Time: 25.57881
# Epoch  2 Loss: 7.26780e-01 Accuracy: 0.71690 Epoch Time: 25.82828
# Epoch  3 Loss: 6.80362e-01 Accuracy: 0.73320 Epoch Time: 25.69651
# Epoch  4 Loss: 6.51712e-01 Accuracy: 0.74435 Epoch Time: 26.05092
# Epoch  5 Loss: 6.27370e-01 Accuracy: 0.75306 Epoch Time: 25.04509
# Epoch  6 Loss: 6.09593e-01 Accuracy: 0.75929 Epoch Time: 26.36960
# Epoch  7 Loss: 5.94554e-01 Accuracy: 0.76356 Epoch Time: 26.44634
# Epoch  8 Loss: 5.81867e-01 Accuracy: 0.76856 Epoch Time: 25.91730
# Epoch  9 Loss: 5.72105e-01 Accuracy: 0.77151 Epoch Time: 26.63289
# Epoch 10 Loss: 5.61452e-01 Accuracy: 0.77623 Epoch Time: 26.72213
# Epoch 11 Loss: 5.55351e-01 Accuracy: 0.77741 Epoch Time: 26.33035
# Epoch 12 Loss: 5.46644e-01 Accuracy: 0.78094 Epoch Time: 26.41595
# Epoch 13 Loss: 5.39195e-01 Accuracy: 0.78418 Epoch Time: 26.27194
# Epoch 14 Loss: 5.32292e-01 Accuracy: 0.78675 Epoch Time: 25.13111
# Epoch  0 Loss: 1.11165e+00 Accuracy: 0.58839 Epoch Time: 26.14919
# Epoch  1 Loss: 7.89964e-01 Accuracy: 0.69652 Epoch Time: 25.99682
# Epoch  2 Loss: 7.17875e-01 Accuracy: 0.72227 Epoch Time: 26.76050
# Epoch  3 Loss: 6.75129e-01 Accuracy: 0.73688 Epoch Time: 26.19652
# Epoch  4 Loss: 6.48706e-01 Accuracy: 0.74545 Epoch Time: 27.20245
# Epoch  5 Loss: 6.28322e-01 Accuracy: 0.75334 Epoch Time: 26.15684
# Epoch  6 Loss: 6.14299e-01 Accuracy: 0.75682 Epoch Time: 26.11283
# Epoch  7 Loss: 6.00908e-01 Accuracy: 0.76219 Epoch Time: 26.40652
# Epoch  8 Loss: 5.90976e-01 Accuracy: 0.76490 Epoch Time: 27.37326
# Epoch  9 Loss: 5.82101e-01 Accuracy: 0.76802 Epoch Time: 26.59962
# Epoch 10 Loss: 5.74414e-01 Accuracy: 0.76995 Epoch Time: 26.69728
# Epoch 11 Loss: 5.66217e-01 Accuracy: 0.77349 Epoch Time: 26.23654
# Epoch 12 Loss: 5.60694e-01 Accuracy: 0.77587 Epoch Time: 25.56359
# Epoch 13 Loss: 5.53650e-01 Accuracy: 0.77817 Epoch Time: 27.24840
# Epoch 14 Loss: 5.47772e-01 Accuracy: 0.78021 Epoch Time: 26.43162
# "Noise Level: low | Mode: era_ensemble | Ensemble model acc: 0.7830128205128205
# Noise Level: low | Mode: target_5_val
# Train-val-test lengths:  218400 46800 46800
# Epoch  0 Loss: 3.20930e-01 Accuracy: 0.87741 Epoch Time: 24.59997
# Epoch  1 Loss: 2.31079e-01 Accuracy: 0.91261 Epoch Time: 26.10108
# Epoch  2 Loss: 2.12000e-01 Accuracy: 0.91867 Epoch Time: 26.40920
# Epoch  3 Loss: 2.01541e-01 Accuracy: 0.92239 Epoch Time: 25.89492
# Epoch  4 Loss: 1.93043e-01 Accuracy: 0.92545 Epoch Time: 27.02427
# Epoch  5 Loss: 1.85560e-01 Accuracy: 0.92877 Epoch Time: 25.74167
# Epoch  6 Loss: 1.79789e-01 Accuracy: 0.93109 Epoch Time: 25.85298
# Epoch  7 Loss: 1.75943e-01 Accuracy: 0.93273 Epoch Time: 25.30454
# Epoch  8 Loss: 1.72743e-01 Accuracy: 0.93351 Epoch Time: 26.23875
# Epoch  9 Loss: 1.70086e-01 Accuracy: 0.93494 Epoch Time: 26.45965
# Epoch 10 Loss: 1.68024e-01 Accuracy: 0.93551 Epoch Time: 25.66913
# Epoch 11 Loss: 1.65813e-01 Accuracy: 0.93606 Epoch Time: 25.49326
# Epoch 12 Loss: 1.64408e-01 Accuracy: 0.93692 Epoch Time: 26.64496
# Epoch 13 Loss: 1.62447e-01 Accuracy: 0.93738 Epoch Time: 26.86824
# Epoch 14 Loss: 1.60853e-01 Accuracy: 0.93792 Epoch Time: 28.09253
# Epoch  0 Loss: 2.92122e-01 Accuracy: 0.89212 Epoch Time: 26.36101
# Epoch  1 Loss: 2.01314e-01 Accuracy: 0.92509 Epoch Time: 28.25952
# Epoch  2 Loss: 1.83534e-01 Accuracy: 0.93004 Epoch Time: 27.02888
# Epoch  3 Loss: 1.73798e-01 Accuracy: 0.93358 Epoch Time: 27.15521
# Epoch  4 Loss: 1.67409e-01 Accuracy: 0.93586 Epoch Time: 26.09694
# Epoch  5 Loss: 1.62558e-01 Accuracy: 0.93794 Epoch Time: 27.84893
# Epoch  6 Loss: 1.57750e-01 Accuracy: 0.93935 Epoch Time: 24.98045
# Epoch  7 Loss: 1.54755e-01 Accuracy: 0.94071 Epoch Time: 26.41544
# Epoch  8 Loss: 1.52725e-01 Accuracy: 0.94131 Epoch Time: 26.95377
# Epoch  9 Loss: 1.50064e-01 Accuracy: 0.94244 Epoch Time: 27.56051
# Epoch 10 Loss: 1.48209e-01 Accuracy: 0.94261 Epoch Time: 24.63181
# Epoch 11 Loss: 1.46358e-01 Accuracy: 0.94333 Epoch Time: 26.78365
# Epoch 12 Loss: 1.45019e-01 Accuracy: 0.94354 Epoch Time: 27.12257
# Epoch 13 Loss: 1.43533e-01 Accuracy: 0.94418 Epoch Time: 26.88147
# Epoch 14 Loss: 1.42314e-01 Accuracy: 0.94461 Epoch Time: 27.12454
# Epoch  0 Loss: 3.75240e-01 Accuracy: 0.85611 Epoch Time: 25.61290
# Epoch  1 Loss: 2.67960e-01 Accuracy: 0.90262 Epoch Time: 26.00681
# Epoch  2 Loss: 2.45252e-01 Accuracy: 0.91056 Epoch Time: 25.14150
# Epoch  3 Loss: 2.32797e-01 Accuracy: 0.91404 Epoch Time: 25.36325
# Epoch  4 Loss: 2.24714e-01 Accuracy: 0.91648 Epoch Time: 25.26419
# Epoch  5 Loss: 2.18718e-01 Accuracy: 0.91845 Epoch Time: 25.82988
# Epoch  6 Loss: 2.14347e-01 Accuracy: 0.91969 Epoch Time: 25.34470
# Epoch  7 Loss: 2.10523e-01 Accuracy: 0.92082 Epoch Time: 26.47645
# Epoch  8 Loss: 2.07239e-01 Accuracy: 0.92147 Epoch Time: 25.65415
# Epoch  9 Loss: 2.04114e-01 Accuracy: 0.92241 Epoch Time: 24.82798
# Epoch 10 Loss: 2.01098e-01 Accuracy: 0.92373 Epoch Time: 25.76060
# Epoch 11 Loss: 1.98510e-01 Accuracy: 0.92451 Epoch Time: 25.04968
# Epoch 12 Loss: 1.97334e-01 Accuracy: 0.92515 Epoch Time: 26.95813
# Epoch 13 Loss: 1.95682e-01 Accuracy: 0.92564 Epoch Time: 24.99072
# Epoch 14 Loss: 1.94807e-01 Accuracy: 0.92569 Epoch Time: 25.16409
# Epoch  0 Loss: 3.03965e-01 Accuracy: 0.88537 Epoch Time: 26.67218
# Epoch  1 Loss: 2.08549e-01 Accuracy: 0.92192 Epoch Time: 27.60670
# Epoch  2 Loss: 1.86650e-01 Accuracy: 0.92831 Epoch Time: 27.29646
# Epoch  3 Loss: 1.72674e-01 Accuracy: 0.93399 Epoch Time: 26.98356
# Epoch  4 Loss: 1.64840e-01 Accuracy: 0.93699 Epoch Time: 26.92081
# Epoch  5 Loss: 1.60214e-01 Accuracy: 0.93836 Epoch Time: 27.44838
# Epoch  6 Loss: 1.55571e-01 Accuracy: 0.93997 Epoch Time: 24.52569
# Epoch  7 Loss: 1.51778e-01 Accuracy: 0.94135 Epoch Time: 26.73150
# Epoch  8 Loss: 1.49507e-01 Accuracy: 0.94216 Epoch Time: 27.61471
# Epoch  9 Loss: 1.46731e-01 Accuracy: 0.94308 Epoch Time: 26.86651
# Epoch 10 Loss: 1.44423e-01 Accuracy: 0.94359 Epoch Time: 28.05717
# Epoch 11 Loss: 1.42702e-01 Accuracy: 0.94413 Epoch Time: 26.76223
# Epoch 12 Loss: 1.41171e-01 Accuracy: 0.94505 Epoch Time: 26.28295
# Epoch 13 Loss: 1.39711e-01 Accuracy: 0.94520 Epoch Time: 28.25650
# Epoch 14 Loss: 1.38686e-01 Accuracy: 0.94574 Epoch Time: 27.60695
# Epoch  0 Loss: 2.90564e-01 Accuracy: 0.89242 Epoch Time: 27.03467
# Epoch  1 Loss: 2.14403e-01 Accuracy: 0.92002 Epoch Time: 27.27076
# Epoch  2 Loss: 1.95308e-01 Accuracy: 0.92578 Epoch Time: 26.01590
# Epoch  3 Loss: 1.82881e-01 Accuracy: 0.93021 Epoch Time: 26.43765
# Epoch  4 Loss: 1.75174e-01 Accuracy: 0.93266 Epoch Time: 27.34164
# Epoch  5 Loss: 1.69614e-01 Accuracy: 0.93526 Epoch Time: 25.44032
# Epoch  6 Loss: 1.66017e-01 Accuracy: 0.93621 Epoch Time: 25.25150
# Epoch  7 Loss: 1.62599e-01 Accuracy: 0.93731 Epoch Time: 26.41520
# Epoch  8 Loss: 1.59864e-01 Accuracy: 0.93854 Epoch Time: 26.46986
# Epoch  9 Loss: 1.58273e-01 Accuracy: 0.93902 Epoch Time: 27.18501
# Epoch 10 Loss: 1.55551e-01 Accuracy: 0.93997 Epoch Time: 25.06797
# Epoch 11 Loss: 1.54049e-01 Accuracy: 0.94048 Epoch Time: 25.48952
# Epoch 12 Loss: 1.52473e-01 Accuracy: 0.94096 Epoch Time: 24.52313
# Epoch 13 Loss: 1.51037e-01 Accuracy: 0.94149 Epoch Time: 25.56987
# Epoch 14 Loss: 1.49852e-01 Accuracy: 0.94199 Epoch Time: 25.84415
# "Noise Level: low | Mode: target_5_val_ensemble | Ensemble model acc: 0.9435470085470086
# Noise Level: low | Mode: target_10_val
# Train-val-test lengths:  218400 46800 46800
# Epoch  0 Loss: 3.16829e-01 Accuracy: 0.87795 Epoch Time: 25.77581
# Epoch  1 Loss: 2.26423e-01 Accuracy: 0.91386 Epoch Time: 23.25835
# Epoch  2 Loss: 1.99031e-01 Accuracy: 0.92480 Epoch Time: 25.41940
# Epoch  3 Loss: 1.86222e-01 Accuracy: 0.92972 Epoch Time: 25.72189
# Epoch  4 Loss: 1.77258e-01 Accuracy: 0.93334 Epoch Time: 26.40113
# Epoch  5 Loss: 1.70284e-01 Accuracy: 0.93648 Epoch Time: 26.08618
# Epoch  6 Loss: 1.65298e-01 Accuracy: 0.93835 Epoch Time: 26.81606
# Epoch  7 Loss: 1.60902e-01 Accuracy: 0.93988 Epoch Time: 24.91023
# Epoch  8 Loss: 1.57536e-01 Accuracy: 0.94108 Epoch Time: 26.17174
# Epoch  9 Loss: 1.54696e-01 Accuracy: 0.94227 Epoch Time: 26.43005
# Epoch 10 Loss: 1.52060e-01 Accuracy: 0.94345 Epoch Time: 26.27936
# Epoch 11 Loss: 1.49275e-01 Accuracy: 0.94449 Epoch Time: 24.98866
# Epoch 12 Loss: 1.47175e-01 Accuracy: 0.94586 Epoch Time: 26.68070
# Epoch 13 Loss: 1.45009e-01 Accuracy: 0.94640 Epoch Time: 26.27244
# Epoch 14 Loss: 1.43495e-01 Accuracy: 0.94710 Epoch Time: 25.89938
# Epoch  0 Loss: 3.18092e-01 Accuracy: 0.87334 Epoch Time: 26.16787
# Epoch  1 Loss: 2.07551e-01 Accuracy: 0.92538 Epoch Time: 25.78519
# Epoch  2 Loss: 1.79593e-01 Accuracy: 0.93512 Epoch Time: 26.74773
# Epoch  3 Loss: 1.62654e-01 Accuracy: 0.94017 Epoch Time: 26.17974
# Epoch  4 Loss: 1.52164e-01 Accuracy: 0.94429 Epoch Time: 26.73280
# Epoch  5 Loss: 1.45099e-01 Accuracy: 0.94733 Epoch Time: 26.31873
# Epoch  6 Loss: 1.39615e-01 Accuracy: 0.94913 Epoch Time: 27.53612
# Epoch  7 Loss: 1.35325e-01 Accuracy: 0.95043 Epoch Time: 25.84944
# Epoch  8 Loss: 1.32884e-01 Accuracy: 0.95141 Epoch Time: 25.82202
# Epoch  9 Loss: 1.29826e-01 Accuracy: 0.95246 Epoch Time: 26.32878
# Epoch 10 Loss: 1.26974e-01 Accuracy: 0.95309 Epoch Time: 26.53223
# Epoch 11 Loss: 1.24625e-01 Accuracy: 0.95347 Epoch Time: 25.36629
# Epoch 12 Loss: 1.23606e-01 Accuracy: 0.95445 Epoch Time: 25.99036
# Epoch 13 Loss: 1.21507e-01 Accuracy: 0.95505 Epoch Time: 27.40735
# Epoch 14 Loss: 1.19496e-01 Accuracy: 0.95558 Epoch Time: 28.20262
# Epoch  0 Loss: 3.88111e-01 Accuracy: 0.84580 Epoch Time: 25.17585
# Epoch  1 Loss: 2.69198e-01 Accuracy: 0.89368 Epoch Time: 26.13542
# Epoch  2 Loss: 2.45465e-01 Accuracy: 0.90620 Epoch Time: 25.96931
# Epoch  3 Loss: 2.33705e-01 Accuracy: 0.91173 Epoch Time: 24.82651
# Epoch  4 Loss: 2.25202e-01 Accuracy: 0.91469 Epoch Time: 25.56748
# Epoch  5 Loss: 2.17027e-01 Accuracy: 0.91785 Epoch Time: 24.91678
# Epoch  6 Loss: 2.10871e-01 Accuracy: 0.92095 Epoch Time: 24.79137
# Epoch  7 Loss: 2.05971e-01 Accuracy: 0.92271 Epoch Time: 25.16031
# Epoch  8 Loss: 2.02283e-01 Accuracy: 0.92434 Epoch Time: 24.96907
# Epoch  9 Loss: 1.99346e-01 Accuracy: 0.92581 Epoch Time: 24.72337
# Epoch 10 Loss: 1.96225e-01 Accuracy: 0.92687 Epoch Time: 23.23968
# Epoch 11 Loss: 1.93382e-01 Accuracy: 0.92754 Epoch Time: 24.44630
# Epoch 12 Loss: 1.91548e-01 Accuracy: 0.92840 Epoch Time: 24.97087
# Epoch 13 Loss: 1.89407e-01 Accuracy: 0.92914 Epoch Time: 25.29946
# Epoch 14 Loss: 1.87196e-01 Accuracy: 0.92973 Epoch Time: 24.75236
# Epoch  0 Loss: 3.17712e-01 Accuracy: 0.87414 Epoch Time: 27.65066
# Epoch  1 Loss: 2.18000e-01 Accuracy: 0.91941 Epoch Time: 27.76349
# Epoch  2 Loss: 1.84848e-01 Accuracy: 0.93158 Epoch Time: 27.11326
# Epoch  3 Loss: 1.64447e-01 Accuracy: 0.93979 Epoch Time: 26.83509
# Epoch  4 Loss: 1.53495e-01 Accuracy: 0.94355 Epoch Time: 26.66465
# Epoch  5 Loss: 1.44613e-01 Accuracy: 0.94666 Epoch Time: 27.20594
# Epoch  6 Loss: 1.37722e-01 Accuracy: 0.94908 Epoch Time: 26.91782
# Epoch  7 Loss: 1.32804e-01 Accuracy: 0.95114 Epoch Time: 25.56095
# Epoch  8 Loss: 1.28622e-01 Accuracy: 0.95256 Epoch Time: 26.48282
# Epoch  9 Loss: 1.25305e-01 Accuracy: 0.95399 Epoch Time: 27.25130
# Epoch 10 Loss: 1.22920e-01 Accuracy: 0.95435 Epoch Time: 25.83813
# Epoch 11 Loss: 1.20096e-01 Accuracy: 0.95532 Epoch Time: 27.27330
# Epoch 12 Loss: 1.17409e-01 Accuracy: 0.95645 Epoch Time: 25.80190
# Epoch 13 Loss: 1.15877e-01 Accuracy: 0.95691 Epoch Time: 26.27233
# Epoch 14 Loss: 1.14029e-01 Accuracy: 0.95770 Epoch Time: 25.09976
# Epoch  0 Loss: 2.88356e-01 Accuracy: 0.89067 Epoch Time: 26.13320
# Epoch  1 Loss: 2.09869e-01 Accuracy: 0.92221 Epoch Time: 26.31911
# Epoch  2 Loss: 1.88842e-01 Accuracy: 0.92967 Epoch Time: 26.71417
# Epoch  3 Loss: 1.75747e-01 Accuracy: 0.93449 Epoch Time: 26.92619
# Epoch  4 Loss: 1.64862e-01 Accuracy: 0.93902 Epoch Time: 27.39114
# Epoch  5 Loss: 1.56993e-01 Accuracy: 0.94216 Epoch Time: 26.41837
# Epoch  6 Loss: 1.50738e-01 Accuracy: 0.94427 Epoch Time: 27.24423
# Epoch  7 Loss: 1.45680e-01 Accuracy: 0.94667 Epoch Time: 28.24027
# Epoch  8 Loss: 1.43313e-01 Accuracy: 0.94705 Epoch Time: 26.72207
# Epoch  9 Loss: 1.39549e-01 Accuracy: 0.94852 Epoch Time: 26.36030
# Epoch 10 Loss: 1.36507e-01 Accuracy: 0.95011 Epoch Time: 26.75142
# Epoch 11 Loss: 1.34455e-01 Accuracy: 0.95065 Epoch Time: 27.69685
# Epoch 12 Loss: 1.31520e-01 Accuracy: 0.95194 Epoch Time: 26.21206
# Epoch 13 Loss: 1.29818e-01 Accuracy: 0.95264 Epoch Time: 26.27637
# Epoch 14 Loss: 1.27312e-01 Accuracy: 0.95321 Epoch Time: 27.03373
# "Noise Level: low | Mode: target_10_val_ensemble | Ensemble model acc: 0.9542521367521367
# Noise Level: high | Mode: era
# Train-val-test lengths:  174720 37440 37440
# Epoch  0 Loss: 1.77408e+00 Accuracy: 0.36885 Epoch Time: 21.81569
# Epoch  1 Loss: 1.51416e+00 Accuracy: 0.45606 Epoch Time: 21.58925
# Epoch  2 Loss: 1.45847e+00 Accuracy: 0.47355 Epoch Time: 21.64490
# Epoch  3 Loss: 1.42378e+00 Accuracy: 0.48468 Epoch Time: 19.99294
# Epoch  4 Loss: 1.39808e+00 Accuracy: 0.49276 Epoch Time: 21.47250
# Epoch  5 Loss: 1.37885e+00 Accuracy: 0.49920 Epoch Time: 21.68689
# Epoch  6 Loss: 1.36378e+00 Accuracy: 0.50378 Epoch Time: 20.35980
# Epoch  7 Loss: 1.35154e+00 Accuracy: 0.50577 Epoch Time: 20.55774
# Epoch  8 Loss: 1.34122e+00 Accuracy: 0.51007 Epoch Time: 20.90670
# Epoch  9 Loss: 1.33275e+00 Accuracy: 0.51238 Epoch Time: 21.86784
# Epoch 10 Loss: 1.32617e+00 Accuracy: 0.51480 Epoch Time: 20.68406
# Epoch 11 Loss: 1.31787e+00 Accuracy: 0.51743 Epoch Time: 22.11567
# Epoch 12 Loss: 1.31179e+00 Accuracy: 0.51908 Epoch Time: 20.01546
# Epoch 13 Loss: 1.30552e+00 Accuracy: 0.52026 Epoch Time: 19.90454
# Epoch 14 Loss: 1.30044e+00 Accuracy: 0.52300 Epoch Time: 21.16104
# Epoch  0 Loss: 1.72397e+00 Accuracy: 0.37926 Epoch Time: 21.27103
# Epoch  1 Loss: 1.48783e+00 Accuracy: 0.45901 Epoch Time: 21.37312
# Epoch  2 Loss: 1.40535e+00 Accuracy: 0.48364 Epoch Time: 21.24141
# Epoch  3 Loss: 1.35662e+00 Accuracy: 0.49987 Epoch Time: 21.94464
# Epoch  4 Loss: 1.32465e+00 Accuracy: 0.51008 Epoch Time: 22.54190
# Epoch  5 Loss: 1.30104e+00 Accuracy: 0.51910 Epoch Time: 22.36210
# Epoch  6 Loss: 1.28383e+00 Accuracy: 0.52483 Epoch Time: 22.73914
# Epoch  7 Loss: 1.26802e+00 Accuracy: 0.52958 Epoch Time: 21.77968
# Epoch  8 Loss: 1.25829e+00 Accuracy: 0.53349 Epoch Time: 22.29132
# Epoch  9 Loss: 1.24964e+00 Accuracy: 0.53673 Epoch Time: 22.05013
# Epoch 10 Loss: 1.24139e+00 Accuracy: 0.53954 Epoch Time: 23.07451
# Epoch 11 Loss: 1.23374e+00 Accuracy: 0.54100 Epoch Time: 21.80727
# Epoch 12 Loss: 1.22470e+00 Accuracy: 0.54599 Epoch Time: 22.18434
# Epoch 13 Loss: 1.21984e+00 Accuracy: 0.54723 Epoch Time: 21.35008
# Epoch 14 Loss: 1.21334e+00 Accuracy: 0.54952 Epoch Time: 22.57072
# Epoch  0 Loss: 2.03478e+00 Accuracy: 0.28402 Epoch Time: 20.13700
# Epoch  1 Loss: 1.68999e+00 Accuracy: 0.39946 Epoch Time: 19.80282
# Epoch  2 Loss: 1.60144e+00 Accuracy: 0.43004 Epoch Time: 20.43614
# Epoch  3 Loss: 1.55801e+00 Accuracy: 0.44365 Epoch Time: 22.05343
# Epoch  4 Loss: 1.53183e+00 Accuracy: 0.45133 Epoch Time: 18.67346
# Epoch  5 Loss: 1.51365e+00 Accuracy: 0.45642 Epoch Time: 21.22409
# Epoch  6 Loss: 1.49982e+00 Accuracy: 0.46132 Epoch Time: 22.20751
# Epoch  7 Loss: 1.48905e+00 Accuracy: 0.46413 Epoch Time: 21.71875
# Epoch  8 Loss: 1.47994e+00 Accuracy: 0.46587 Epoch Time: 20.85549
# Epoch  9 Loss: 1.47253e+00 Accuracy: 0.46922 Epoch Time: 20.63310
# Epoch 10 Loss: 1.46497e+00 Accuracy: 0.47149 Epoch Time: 21.34790
# Epoch 11 Loss: 1.45825e+00 Accuracy: 0.47430 Epoch Time: 21.48901
# Epoch 12 Loss: 1.45195e+00 Accuracy: 0.47726 Epoch Time: 21.02227
# Epoch 13 Loss: 1.44622e+00 Accuracy: 0.47768 Epoch Time: 22.03178
# Epoch 14 Loss: 1.44129e+00 Accuracy: 0.47975 Epoch Time: 21.65391
# Epoch  0 Loss: 1.73407e+00 Accuracy: 0.37565 Epoch Time: 20.90420
# Epoch  1 Loss: 1.46350e+00 Accuracy: 0.46593 Epoch Time: 21.78144
# Epoch  2 Loss: 1.39081e+00 Accuracy: 0.48810 Epoch Time: 21.86750
# Epoch  3 Loss: 1.34369e+00 Accuracy: 0.50346 Epoch Time: 20.76110
# Epoch  4 Loss: 1.31172e+00 Accuracy: 0.51437 Epoch Time: 19.71593
# Epoch  5 Loss: 1.28689e+00 Accuracy: 0.52166 Epoch Time: 22.51125
# Epoch  6 Loss: 1.26961e+00 Accuracy: 0.52834 Epoch Time: 22.59463
# Epoch  7 Loss: 1.25549e+00 Accuracy: 0.53325 Epoch Time: 22.13269
# Epoch  8 Loss: 1.24382e+00 Accuracy: 0.53741 Epoch Time: 21.01662
# Epoch  9 Loss: 1.23482e+00 Accuracy: 0.54073 Epoch Time: 22.08118
# Epoch 10 Loss: 1.22754e+00 Accuracy: 0.54246 Epoch Time: 20.85837
# Epoch 11 Loss: 1.21974e+00 Accuracy: 0.54621 Epoch Time: 20.73529
# Epoch 12 Loss: 1.21276e+00 Accuracy: 0.54914 Epoch Time: 22.39685
# Epoch 13 Loss: 1.20673e+00 Accuracy: 0.55116 Epoch Time: 21.01963
# Epoch 14 Loss: 1.20112e+00 Accuracy: 0.55193 Epoch Time: 21.86939
# Epoch  0 Loss: 1.72341e+00 Accuracy: 0.38303 Epoch Time: 22.01439
# Epoch  1 Loss: 1.46427e+00 Accuracy: 0.47071 Epoch Time: 21.11607
# Epoch  2 Loss: 1.40493e+00 Accuracy: 0.48912 Epoch Time: 21.91918
# Epoch  3 Loss: 1.37092e+00 Accuracy: 0.49811 Epoch Time: 21.90696
# Epoch  4 Loss: 1.34434e+00 Accuracy: 0.50646 Epoch Time: 21.85965
# Epoch  5 Loss: 1.32097e+00 Accuracy: 0.51279 Epoch Time: 21.78221
# Epoch  6 Loss: 1.30083e+00 Accuracy: 0.51979 Epoch Time: 19.84771
# Epoch  7 Loss: 1.28651e+00 Accuracy: 0.52482 Epoch Time: 21.97219
# Epoch  8 Loss: 1.27555e+00 Accuracy: 0.52913 Epoch Time: 21.29614
# Epoch  9 Loss: 1.26716e+00 Accuracy: 0.53078 Epoch Time: 20.52363
# Epoch 10 Loss: 1.25704e+00 Accuracy: 0.53393 Epoch Time: 20.12993
# Epoch 11 Loss: 1.25130e+00 Accuracy: 0.53693 Epoch Time: 22.84430
# Epoch 12 Loss: 1.24509e+00 Accuracy: 0.53915 Epoch Time: 20.97243
# Epoch 13 Loss: 1.23990e+00 Accuracy: 0.54025 Epoch Time: 22.40812
# Epoch 14 Loss: 1.23514e+00 Accuracy: 0.54056 Epoch Time: 20.41007
# "Noise Level: high | Mode: era_ensemble | Ensemble model acc: 0.5469017094017095
# Noise Level: high | Mode: target_5_val
# Train-val-test lengths:  174720 37440 37440
# Epoch  0 Loss: 4.38539e-01 Accuracy: 0.81229 Epoch Time: 19.07053
# Epoch  1 Loss: 3.63328e-01 Accuracy: 0.84114 Epoch Time: 21.28002
# Epoch  2 Loss: 3.48055e-01 Accuracy: 0.84882 Epoch Time: 21.23948
# Epoch  3 Loss: 3.40378e-01 Accuracy: 0.85165 Epoch Time: 20.78295
# Epoch  4 Loss: 3.35631e-01 Accuracy: 0.85433 Epoch Time: 20.41966
# Epoch  5 Loss: 3.31138e-01 Accuracy: 0.85537 Epoch Time: 20.21581
# Epoch  6 Loss: 3.28301e-01 Accuracy: 0.85647 Epoch Time: 20.91138
# Epoch  7 Loss: 3.25080e-01 Accuracy: 0.85768 Epoch Time: 20.34519
# Epoch  8 Loss: 3.23414e-01 Accuracy: 0.85779 Epoch Time: 21.52784
# Epoch  9 Loss: 3.21041e-01 Accuracy: 0.85916 Epoch Time: 20.71071
# Epoch 10 Loss: 3.19502e-01 Accuracy: 0.85971 Epoch Time: 20.76062
# Epoch 11 Loss: 3.18034e-01 Accuracy: 0.86071 Epoch Time: 20.90327
# Epoch 12 Loss: 3.16322e-01 Accuracy: 0.86116 Epoch Time: 20.65117
# Epoch 13 Loss: 3.15182e-01 Accuracy: 0.86118 Epoch Time: 22.06056
# Epoch 14 Loss: 3.13759e-01 Accuracy: 0.86180 Epoch Time: 20.34610
# Epoch  0 Loss: 4.38874e-01 Accuracy: 0.81181 Epoch Time: 21.84561
# Epoch  1 Loss: 3.53306e-01 Accuracy: 0.84712 Epoch Time: 22.05500
# Epoch  2 Loss: 3.38292e-01 Accuracy: 0.85235 Epoch Time: 21.55842
# Epoch  3 Loss: 3.29315e-01 Accuracy: 0.85660 Epoch Time: 21.32600
# Epoch  4 Loss: 3.23793e-01 Accuracy: 0.85801 Epoch Time: 21.33859
# Epoch  5 Loss: 3.18213e-01 Accuracy: 0.86045 Epoch Time: 22.32894
# Epoch  6 Loss: 3.14918e-01 Accuracy: 0.86190 Epoch Time: 21.97141
# Epoch  7 Loss: 3.11563e-01 Accuracy: 0.86368 Epoch Time: 20.90522
# Epoch  8 Loss: 3.08845e-01 Accuracy: 0.86406 Epoch Time: 20.72591
# Epoch  9 Loss: 3.06149e-01 Accuracy: 0.86488 Epoch Time: 21.34416
# Epoch 10 Loss: 3.04905e-01 Accuracy: 0.86620 Epoch Time: 21.26380
# Epoch 11 Loss: 3.02838e-01 Accuracy: 0.86678 Epoch Time: 22.30350
# Epoch 12 Loss: 3.01385e-01 Accuracy: 0.86751 Epoch Time: 20.51714
# Epoch 13 Loss: 2.99985e-01 Accuracy: 0.86808 Epoch Time: 21.36138
# Epoch 14 Loss: 2.98834e-01 Accuracy: 0.86838 Epoch Time: 20.57726
# Epoch  0 Loss: 4.95951e-01 Accuracy: 0.79097 Epoch Time: 20.37067
# Epoch  1 Loss: 4.02139e-01 Accuracy: 0.82268 Epoch Time: 20.47831
# Epoch  2 Loss: 3.84087e-01 Accuracy: 0.82965 Epoch Time: 21.15156
# Epoch  3 Loss: 3.74525e-01 Accuracy: 0.83381 Epoch Time: 21.13757
# Epoch  4 Loss: 3.67537e-01 Accuracy: 0.83731 Epoch Time: 22.11427
# Epoch  5 Loss: 3.63517e-01 Accuracy: 0.83859 Epoch Time: 21.03031
# Epoch  6 Loss: 3.60912e-01 Accuracy: 0.83961 Epoch Time: 21.84677
# Epoch  7 Loss: 3.58402e-01 Accuracy: 0.84024 Epoch Time: 21.81939
# Epoch  8 Loss: 3.55960e-01 Accuracy: 0.84168 Epoch Time: 21.47223
# Epoch  9 Loss: 3.54136e-01 Accuracy: 0.84288 Epoch Time: 21.70913
# Epoch 10 Loss: 3.52479e-01 Accuracy: 0.84351 Epoch Time: 22.24567
# Epoch 11 Loss: 3.50233e-01 Accuracy: 0.84472 Epoch Time: 20.85798
# Epoch 12 Loss: 3.48708e-01 Accuracy: 0.84509 Epoch Time: 20.94192
# Epoch 13 Loss: 3.46461e-01 Accuracy: 0.84678 Epoch Time: 19.91972
# Epoch 14 Loss: 3.45356e-01 Accuracy: 0.84725 Epoch Time: 20.70270
# Epoch  0 Loss: 4.30714e-01 Accuracy: 0.81734 Epoch Time: 21.28352
# Epoch  1 Loss: 3.55938e-01 Accuracy: 0.84622 Epoch Time: 22.28523
# Epoch  2 Loss: 3.39130e-01 Accuracy: 0.85249 Epoch Time: 22.07791
# Epoch  3 Loss: 3.29766e-01 Accuracy: 0.85612 Epoch Time: 23.24135
# Epoch  4 Loss: 3.23505e-01 Accuracy: 0.85849 Epoch Time: 21.77934
# Epoch  5 Loss: 3.18716e-01 Accuracy: 0.86014 Epoch Time: 20.95026
# Epoch  6 Loss: 3.15910e-01 Accuracy: 0.86138 Epoch Time: 22.24385
# Epoch  7 Loss: 3.12529e-01 Accuracy: 0.86244 Epoch Time: 22.99214
# Epoch  8 Loss: 3.09900e-01 Accuracy: 0.86390 Epoch Time: 21.78614
# Epoch  9 Loss: 3.07788e-01 Accuracy: 0.86438 Epoch Time: 20.10792
# Epoch 10 Loss: 3.05766e-01 Accuracy: 0.86502 Epoch Time: 20.98354
# Epoch 11 Loss: 3.03850e-01 Accuracy: 0.86589 Epoch Time: 22.59664
# Epoch 12 Loss: 3.02362e-01 Accuracy: 0.86642 Epoch Time: 21.93840
# Epoch 13 Loss: 3.00919e-01 Accuracy: 0.86799 Epoch Time: 22.31601
# Epoch 14 Loss: 2.99239e-01 Accuracy: 0.86815 Epoch Time: 21.69756
# Epoch  0 Loss: 4.28298e-01 Accuracy: 0.81410 Epoch Time: 21.14935
# Epoch  1 Loss: 3.60792e-01 Accuracy: 0.84234 Epoch Time: 21.20088
# Epoch  2 Loss: 3.47762e-01 Accuracy: 0.84856 Epoch Time: 21.42096
# Epoch  3 Loss: 3.40270e-01 Accuracy: 0.85120 Epoch Time: 21.88686
# Epoch  4 Loss: 3.34547e-01 Accuracy: 0.85382 Epoch Time: 21.49748
# Epoch  5 Loss: 3.28849e-01 Accuracy: 0.85578 Epoch Time: 21.08562
# Epoch  6 Loss: 3.25246e-01 Accuracy: 0.85799 Epoch Time: 22.11944
# Epoch  7 Loss: 3.21412e-01 Accuracy: 0.85920 Epoch Time: 20.87556
# Epoch  8 Loss: 3.18865e-01 Accuracy: 0.86010 Epoch Time: 22.10862
# Epoch  9 Loss: 3.16123e-01 Accuracy: 0.86174 Epoch Time: 22.53470
# Epoch 10 Loss: 3.13984e-01 Accuracy: 0.86220 Epoch Time: 21.82164
# Epoch 11 Loss: 3.12000e-01 Accuracy: 0.86330 Epoch Time: 22.02904
# Epoch 12 Loss: 3.10475e-01 Accuracy: 0.86427 Epoch Time: 19.39833
# Epoch 13 Loss: 3.09005e-01 Accuracy: 0.86399 Epoch Time: 21.61233
# Epoch 14 Loss: 3.07857e-01 Accuracy: 0.86449 Epoch Time: 24.06183
# "Noise Level: high | Mode: target_5_val_ensemble | Ensemble model acc: 0.8647970085470086
# Noise Level: high | Mode: target_10_val
# Train-val-test lengths:  174720 37440 37440
# Epoch  0 Loss: 4.43330e-01 Accuracy: 0.81164 Epoch Time: 22.68267
# Epoch  1 Loss: 3.55668e-01 Accuracy: 0.84852 Epoch Time: 23.34091
# Epoch  2 Loss: 3.41330e-01 Accuracy: 0.85454 Epoch Time: 23.67283
# Epoch  3 Loss: 3.35404e-01 Accuracy: 0.85714 Epoch Time: 20.27722
# Epoch  4 Loss: 3.30315e-01 Accuracy: 0.85916 Epoch Time: 20.65333
# Epoch  5 Loss: 3.25716e-01 Accuracy: 0.86145 Epoch Time: 21.16681
# Epoch  6 Loss: 3.19468e-01 Accuracy: 0.86410 Epoch Time: 21.67677
# Epoch  7 Loss: 3.13664e-01 Accuracy: 0.86641 Epoch Time: 20.40043
# Epoch  8 Loss: 3.09557e-01 Accuracy: 0.86818 Epoch Time: 20.51144
# Epoch  9 Loss: 3.05240e-01 Accuracy: 0.86976 Epoch Time: 19.75847
# Epoch 10 Loss: 3.01846e-01 Accuracy: 0.87200 Epoch Time: 19.49174
# Epoch 11 Loss: 2.99264e-01 Accuracy: 0.87255 Epoch Time: 19.10908
# Epoch 12 Loss: 2.96009e-01 Accuracy: 0.87361 Epoch Time: 18.40029
# Epoch 13 Loss: 2.94140e-01 Accuracy: 0.87443 Epoch Time: 18.42351
# Epoch 14 Loss: 2.91668e-01 Accuracy: 0.87566 Epoch Time: 18.78362
# Epoch  0 Loss: 4.49192e-01 Accuracy: 0.80319 Epoch Time: 19.62930
# Epoch  1 Loss: 3.51038e-01 Accuracy: 0.85254 Epoch Time: 19.78738
# Epoch  2 Loss: 3.33374e-01 Accuracy: 0.85943 Epoch Time: 19.04582
# Epoch  3 Loss: 3.18992e-01 Accuracy: 0.86465 Epoch Time: 20.77192
# Epoch  4 Loss: 3.09277e-01 Accuracy: 0.86865 Epoch Time: 20.73898
# Epoch  5 Loss: 3.02298e-01 Accuracy: 0.87068 Epoch Time: 20.02263
# Epoch  6 Loss: 2.96304e-01 Accuracy: 0.87308 Epoch Time: 19.58048
# Epoch  7 Loss: 2.92744e-01 Accuracy: 0.87500 Epoch Time: 19.78953
# Epoch  8 Loss: 2.88801e-01 Accuracy: 0.87677 Epoch Time: 19.30135
# Epoch  9 Loss: 2.85820e-01 Accuracy: 0.87780 Epoch Time: 20.22820
# Epoch 10 Loss: 2.83322e-01 Accuracy: 0.87891 Epoch Time: 19.58077
# Epoch 11 Loss: 2.81623e-01 Accuracy: 0.87900 Epoch Time: 19.30381
# Epoch 12 Loss: 2.79534e-01 Accuracy: 0.88050 Epoch Time: 19.00483
# Epoch 13 Loss: 2.77986e-01 Accuracy: 0.88076 Epoch Time: 19.60868
# Epoch 14 Loss: 2.76306e-01 Accuracy: 0.88151 Epoch Time: 19.67682
# Epoch  0 Loss: 4.78719e-01 Accuracy: 0.79907 Epoch Time: 18.52141
# Epoch  1 Loss: 4.03269e-01 Accuracy: 0.82602 Epoch Time: 18.60730
# Epoch  2 Loss: 3.83202e-01 Accuracy: 0.83624 Epoch Time: 17.96311
# Epoch  3 Loss: 3.65279e-01 Accuracy: 0.84476 Epoch Time: 17.63608
# Epoch  4 Loss: 3.57792e-01 Accuracy: 0.84836 Epoch Time: 18.09905
# Epoch  5 Loss: 3.53581e-01 Accuracy: 0.84974 Epoch Time: 18.00082
# Epoch  6 Loss: 3.50178e-01 Accuracy: 0.85116 Epoch Time: 19.45412
# Epoch  7 Loss: 3.47461e-01 Accuracy: 0.85277 Epoch Time: 18.44337
# Epoch  8 Loss: 3.44775e-01 Accuracy: 0.85397 Epoch Time: 18.56302
# Epoch  9 Loss: 3.41884e-01 Accuracy: 0.85496 Epoch Time: 18.50192
# Epoch 10 Loss: 3.39762e-01 Accuracy: 0.85524 Epoch Time: 18.07621
# Epoch 11 Loss: 3.37736e-01 Accuracy: 0.85645 Epoch Time: 18.29993
# Epoch 12 Loss: 3.35826e-01 Accuracy: 0.85669 Epoch Time: 17.32165
# Epoch 13 Loss: 3.34590e-01 Accuracy: 0.85735 Epoch Time: 18.58543
# Epoch 14 Loss: 3.33304e-01 Accuracy: 0.85780 Epoch Time: 18.92572
# Epoch  0 Loss: 4.29913e-01 Accuracy: 0.81865 Epoch Time: 18.70748
# Epoch  1 Loss: 3.48042e-01 Accuracy: 0.85380 Epoch Time: 19.79893
# Epoch  2 Loss: 3.29308e-01 Accuracy: 0.86083 Epoch Time: 19.71748
# Epoch  3 Loss: 3.14511e-01 Accuracy: 0.86670 Epoch Time: 19.70927
# Epoch  4 Loss: 3.04768e-01 Accuracy: 0.87043 Epoch Time: 19.93116
# Epoch  5 Loss: 2.97820e-01 Accuracy: 0.87284 Epoch Time: 19.77179
# Epoch  6 Loss: 2.91436e-01 Accuracy: 0.87557 Epoch Time: 19.17209
# Epoch  7 Loss: 2.87395e-01 Accuracy: 0.87750 Epoch Time: 19.47317
# Epoch  8 Loss: 2.83785e-01 Accuracy: 0.87858 Epoch Time: 21.82965
# Epoch  9 Loss: 2.80917e-01 Accuracy: 0.87952 Epoch Time: 19.51774
# Epoch 10 Loss: 2.79012e-01 Accuracy: 0.88066 Epoch Time: 18.88126
# Epoch 11 Loss: 2.76564e-01 Accuracy: 0.88172 Epoch Time: 19.43596
# Epoch 12 Loss: 2.73893e-01 Accuracy: 0.88284 Epoch Time: 19.53323
# Epoch 13 Loss: 2.72557e-01 Accuracy: 0.88301 Epoch Time: 19.97288
# Epoch 14 Loss: 2.70509e-01 Accuracy: 0.88388 Epoch Time: 18.65645
# Epoch  0 Loss: 4.16666e-01 Accuracy: 0.82390 Epoch Time: 18.64965
# Epoch  1 Loss: 3.42680e-01 Accuracy: 0.85525 Epoch Time: 18.73278
# Epoch  2 Loss: 3.26798e-01 Accuracy: 0.86136 Epoch Time: 19.26885
# Epoch  3 Loss: 3.17807e-01 Accuracy: 0.86499 Epoch Time: 18.71053
# Epoch  4 Loss: 3.09481e-01 Accuracy: 0.86909 Epoch Time: 19.03687
# Epoch  5 Loss: 3.03589e-01 Accuracy: 0.87100 Epoch Time: 18.99662
# Epoch  6 Loss: 2.97730e-01 Accuracy: 0.87331 Epoch Time: 19.40677
# Epoch  7 Loss: 2.93570e-01 Accuracy: 0.87461 Epoch Time: 19.85231
# Epoch  8 Loss: 2.90119e-01 Accuracy: 0.87655 Epoch Time: 18.15920
# Epoch  9 Loss: 2.87833e-01 Accuracy: 0.87748 Epoch Time: 18.97047
# Epoch 10 Loss: 2.85222e-01 Accuracy: 0.87858 Epoch Time: 19.29713
# Epoch 11 Loss: 2.83521e-01 Accuracy: 0.87893 Epoch Time: 19.10515
# Epoch 12 Loss: 2.82376e-01 Accuracy: 0.88001 Epoch Time: 19.71044
# Epoch 13 Loss: 2.80636e-01 Accuracy: 0.87990 Epoch Time: 18.58884
# Epoch 14 Loss: 2.79131e-01 Accuracy: 0.88075 Epoch Time: 19.35588
# "Noise Level: high | Mode: target_10_val_ensemble | Ensemble model acc: 0.8851495726495726
